# %% [markdown]
# # CS 584-A: Natural Language Processing
#
# ## Student information
# - Full name: Thanapoom Phatthanaphan
# - CWID: 20011296
#
# ## Homework 3
# ### Goals
# The goal of HW3 is for you to get hands-on experience of utilizing Seq2Seq model for machine translation task. You will get a deeper understanding of how the input sequence is translated to the output sequence with the Seq2Seq model. The skills of you learnt in this homework will benefit your understanding of a wide range of NLP tasks beyond machine translation. Please feel free to use any packages or libraries in your implementation.
#
# Similar to HW1 and HW2, all questions are open questions and there is no fixed solution. The difference in data selection and processing, parameter initialization, data split, etc., will lead to the differences in predictions and evaluation results. Therefore, during the grading, the specific values in the results are not required. It is important that you focus on implementing and setting up the pipelines of applying these models to solve the tasks.

# %% [markdown]
# ## Task: Machine Translation

# %% [markdown]
# ### 1. Data preparation

# %%
# Install datasets library
# !pip install datasets
# !pip install transformers
# !pip install torchtext
# !pip install torch
# !pip install tensorflow
# !pip install sentencepiece
# !pip install sacremoses
# !pip install sacrebleu
# !pip install ctranslate2
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.10/dist-packages (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.31.0)
# Requirement already satisfied: torch==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.1.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext) (1.23.5)
# Requirement already satisfied: torchdata==0.7.0 in /usr/local/lib/python3.10/dist-packages (from torchtext) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->torchtext) (2.1.0)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.7.0->torchtext) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0->torchtext) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0->torchtext) (1.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2023.6.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.3.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.66.1)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (1.23.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.3)
# Requirement already satisfied: ctranslate2 in /usr/local/lib/python3.10/dist-packages (3.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2) (1.23.5)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2) (6.0.1)

# %%
# Download the Flores200 dataset
from datasets import load_dataset
dataset = load_dataset("Muennighoff/flores200", 'all')

# %%
# Import random library for randomly selecting sentence pairs
import random

# Select Thai as source language and English as target language for translation
source_language = dataset['dev']['sentence_tha_Thai']
target_language = dataset['dev']['sentence_eng_Latn']

# Combine source and target sentences into pairs
sentence_pairs = list(zip(source_language, target_language))

# Randomly select 100 sentence pairs
random.seed(50)
selected_pairs = random.sample(sentence_pairs, 100)

# Define the list for source and target sentences
source_sentences = []
target_sentences = []

# Display the selected sentence pairs
for idx, (source, target) in enumerate(selected_pairs):
    source_sentences.append(source)
    target_sentences.append(target)
    print(f"Pair {idx + 1} - Source: {source}\n         Target: {target}\n")
# Out:
# Pair 1 - Source: นี่ไม่ใช่กลุ่มอาการขาดทักษะด้านการเรียนรู้ แต่เป็นความผิดปกติทางการเรียนรู้ โรคนี้ "ส่งผลกระทบต่อเด็กร้อยละ 3 ถึง 5 ซึ่งอาจเป็นเด็กอเมริกันมากถึง 2 ล้านคน"
#          Target: It is not a learning disability, it is a learning disorder; it "affects 3 to 5 percent of all children, perhaps as many as 2 million American children".
#
# Pair 2 - Source: ผู้ที่ไม่คุ้นเคยกับศัพท์เฉพาะทางการแพทย์คิดว่า คำว่าติดเชื้อและโรคติดต่อนั้นมีความหมายต่างกัน
#          Target: For those unfamiliar with medical jargon, the words infectious and contagious have distinct meanings.
#
# Pair 3 - Source: เขาตั้งข้อสังเกตว่า งานวิจัยบางชิ้นชี้ให้เห็นว่าโรคนี้จำเป็นต้องมีอันตรายน้อยลงก่อนที่มันจะแพร่ระบาดไปทั่วโลก
#          Target: Some studies suggest that the disease must become less lethal before it can cause a global epidemic, he noted.
#
# Pair 4 - Source: นักวิทยาศาสตร์รายอื่น ๆ แย้งว่าพืชเหล่านี้มีพิษร้ายแรง จึงไม่น่าเป็นไปได้ที่จะมีไดโนเสาร์ตัวใดกินพวกมันได้ แม้ว่าในปัจจุบันสลอธและสัตว์อื่น ๆ เช่น นกแก้ว (ลูกหลานของไดโนเสาร์) จะสามารถกินใบไม้หรือผลไม้มีพิษได้ก็ตาม
#          Target: Other scientists argue that these plants are very poisonous so it is unlikely that any dinosaur ate them, even though today the sloth and other animals like the parrot (a descendant of the dinosaurs) can eat poisonous leaves or fruit.
#
# Pair 5 - Source: ถึงแม้คุณอาจเคยได้ยินชาวกรีนแลนด์ใช้คำนี้ แต่ชาวต่างชาติไม่ควรใช้
#          Target: While you may hear the word used by Greenlandic Natives, its use should be avoided by foreigners.
#
# Pair 6 - Source: นอกจากนี้ยังไม่มีข้อกำหนดว่าคุณจะต้องwfhรับหมายเลขท้องถิ่นจากชุมชนที่คุณอาศัยอยู่ คุณสามารถรับการเชื่อมต่ออินเทอร์เน็ตผ่านดาวเทียมในชิกเก้นซึ่งเป็นเมืองที่ห่างไกลความเจริญในอลาสก้า และเลือกหมายเลขที่บ่งบอกว่าคุณอยู่ในแอริโซนาที่มีแสงแดดจ้า
#          Target: There is also no requirement that you obtain a local number from the community in which you live; you can obtain a satellite Internet connection in the wilds of Chicken, Alaska and select a number which claims you're in sunny Arizona.
#
# Pair 7 - Source: โฮสเทลแห่งหนึ่งถล่มในเมกกะซึ่งเป็นเมืองศักดิ์สิทธิ์ของศาสนาอิสลามเมื่อเวลาประมาณ 10 นาฬิกาของเช้าวันนี้ตามเวลาท้องถิ่น
#          Target: A hostel collapsed in Mecca, the holy city of Islam at about 10 o'clock this morning local time.
#
# Pair 8 - Source: ถึงอย่างนั้นก็คาดได้เลยว่าจะต้องหายใจหอบ และต้องระวังในส่วนที่ลาดชันกว่าโดยเฉพาะเมื่อเปียก เนื่องจากอาจเกิดอันตรายได้อย่างรวดเร็ว
#          Target: That said, expect to be out of breath, and take care in the steeper portions, especially when wet, as it can become dangerous quickly.
#
# Pair 9 - Source: ความเชื่อทางไสยศาสตร์สามารถจำแนกออกจากรูปแบบความเชื่อทางศาสนาและการบูชาอื่น ๆ ด้วยลักษณะที่เน้นในเรื่องประสบการณ์ตรงของการตระหนักรู้ในภาวะต่าง ๆ โดยเฉพาะภาวะของความรู้สึกสงบ การหยั่งรู้ ความผาสุก หรือแม้แต่ความปิติยินดีเหลือล้น
#          Target: Mysticism can be distinguished from other forms of religious belief and worship by its emphasis on the direct personal experience of a unique state of consciousness, particularly those of a peaceful, insightful, blissful, or even ecstatic character.
#
# Pair 10 - Source: สัตว์ป่าอาจขี้อายหรือก้าวร้าวก็ได้ สภาพแวดล้อมอาจเย็น ร้อน หรือยากลำบาก
#          Target: Wild animals might either be shy or aggressive. The environment might be cold, hot, or otherwise hostile.
#
# Pair 11 - Source: ปีเตอร์ เลนซ์ นักแข่งรถมอเตอร์ไซค์วัย 13 ปี เสียชีวิตหลังจากอยู่ในอุบัติเหตุรถชนกันที่อินเดียนาโปลิสมอเตอร์สปีดเวย์
#          Target: Peter Lenz, a 13-year-old motorcycle racer, has died after being involved in a crash at the Indianapolis Motor Speedway.
#
# Pair 12 - Source: ข่าวแพร่สะพัดในชุมชนเรดเลคในวันนี้ว่ามีนักเรียนอีกคนถูกจับุมจากการก่อเหตุกราดยิงในโรงเรียนเมื่อวันที่ 21 มีนาคม ขณะที่งานศพของ Jeff Weise และเหยื่อ 3 ใน 9 คนดำเนินอยู่
#          Target: News spread in the Red Lake community today as funerals for Jeff Weise and three of the nine victims were held that another student was arrested in connection with the school shootings of March 21.
#
# Pair 13 - Source: การปฏิบัติตามหลักการโภชนาการที่เหมาะสมแค่อย่างเดียวไม่สามารถช่วยให้เกิดสมรรถภาพระดับดีเลิศได้ แต่อาจส่งผลอย่างมากต่อสุขภาพโดยรวมของนักกีฬารุ่นเยาว์
#          Target: Proper nutritional practices alone cannot generate elite performances, but they can significantly affect young athletes' overall wellness.
#
# Pair 14 - Source: พายุลูกนี้อยู่ห่างจากเมืองไมอามี่ในรัฐฟลอริดาราว 3,000 ไมล์โดยมีแรงลมสูงสุดอยู่ที่ 40 ไมล์/ชม. (64 กม./ชม.)
#          Target: The storm, located approximately 3,000 miles from Miami, Florida, has maximum sustained winds of 40 mph (64 kph).
#
# Pair 15 - Source: ทฤษฎีนี้ย้อนแย้งกับคำกล่าวอ้างที่ว่า ดวงจันทร์นั้นไม่มีความเคลื่อนไหวทางธรณีวิทยาเลยแม้แต่น้อย
#          Target: This theory contradicts the claim that the moon is completely devoid of geologic activity.
#
# Pair 16 - Source: การเข้าวัดจะต้องใช้บัตร Angkor Pass ดังนั้นเมื่อจะเดินทางไปโตนเลสาบ โปรดอย่าลืมนำหนังสือเดินทางติดตัวไปด้วย
#          Target: The Angkor Pass is needed to enter the temple so do not forget to bring your passport along when heading to Tonle Sap.
#
# Pair 17 - Source: เมื่อประชากรทั้งหมดมีลักษณะทางพันธุกรรมอย่างหนึ่งที่เหมือนกันก็จะถูกเรียกว่าโมโนมอร์ฟิก
#          Target: When all individuals in a population are identical with regard to a particular phenotypic trait they are known as monomorphic.
#
# Pair 18 - Source: ส่วนใหญ่แล้วจะเกิดขึ้นกับคนที่ทำงานเกี่ยวข้องกับสัตว์ปีกมากกว่า แต่นักดูนกก็มีความเสี่ยงเช่นกัน
#          Target: Most have involved people who work with poultry, but there is also some risk to birdwatchers.
#
# Pair 19 - Source: แม้คุณอาจจะคิดว่าเป็นเรื่องดีที่จะใช้บริการสายการบินเดิม ๆ ที่คุณบินด้วยบ่อยที่สุด แต่ควรทราบไว้ว่าสิทธิพิเศษที่แต่ละสายการบินมอบให้มักจะแตกต่างกัน และคะแนนไมล์สะสมของสายการบินอื่นในกลุ่มพันธมิตรเดียวกันอาจให้ผลตอบแทนที่เป็นประโยชน์มากกว่า
#          Target: Although you may think it is intuitive to join the airline you fly most, you should be aware that privileges offered are often different and frequent flyer points may be more generous under a different airline in the same alliance.
#
# Pair 20 - Source: หินบางชนิดที่หาได้ยากมากในโลก มีการขายตั้งแต่ราคา 11,000 ดอลลาร์สหรัฐไปจนถึง 22,500 ดอลลาร์สหรัฐต่อออนซ์ ซึ่งแพงกว่าราคาทองคำราวสิบเท่า
#          Target: Some of the rocks, which are very rare on Earth, are being sold from US$11,000 to $22,500 per ounce, which is about ten times more than the cost of gold.
#
# Pair 21 - Source: เนื่องจากด้านล่างของใบมีดโค้งเล็กน้อย เมื่อใบมีดเอียงไปด้านใดด้านหนึ่ง ขอบที่สัมผัสกับน้ำแข็งจึงโค้งเช่นกัน
#          Target: Because the bottom of the blade is slightly curved, as the blade tilts to one side or the other, the edge which is in contact with the ice also curves.
#
# Pair 22 - Source: อย่างไรก็ตาม ในปัจจุบันศิลปินกราฟฟิตีที่ได้รับการยอมรับ มีงานอีเวนต์กราฟฟิตี และกำแพง สำหรับวาดภาพกราฟฟิตีที่ "ถูกกฎหมาย" ภาพวาดกราฟฟิตีในบริบทนี้มักคล้ายกับงานศิลปะมากกว่าป้ายที่อ่านไม่ออก
#          Target: However, nowadays there are established graffiti artists, graffiti events and "legal" walls. Graffiti paintings in this context often resemble artworks rather than illegible tags.
#
# Pair 23 - Source: การที่วาล์วเปิดทำให้แรงดันถูกปล่อยออกจากระบบ แล้วน้ำมันก็ไหลไปตามรางสู่ถังที่มีความจุ 55,000 บาร์เรล (2.3 ล้านแกลลอน)
#          Target: The valves opening allowed a pressure release for the system and oil flowed on a pad to a tank that can hold 55,000 barrels (2.3 million gallons).
#
# Pair 24 - Source: ภาษาเสริมคือภาษาประดิษฐ์หรือภาษาที่สร้างขึ้นโดยมีวัตถุประสงค์เพื่ออำนวยความสะดวกในการสื่อสารระหว่างผู้คนที่อาจมีปัญหาในการสื่อสารหากไม่มีภาษานี้
#          Target: Auxiliary languages are artificial or constructed languages created with the intent of facilitating communication between peoples who would otherwise have difficulty communicating.
#
# Pair 25 - Source: โบเบ็ก เกิดในซาเกร็บซึ่งเป็นเมืองหลวงของโครเอเชียและมีชื่อเสียงขึ้นมาขณะเล่นให้กับปาร์ติซานเบลเกรด
#          Target: Born in the Croatian capital, Zagreb, Bobek gained fame while playing for Partizan Belgrade.
#
# Pair 26 - Source: นักวิทยาศาสตร์ได้ค้นพบรูปแบบของเปลือกโลกที่เรียกว่า lobate scarp กระจัดกระจายอยู่ทั่วพื้นผิวดวงจันทร์ ซึ่งปรากฏว่าเป็นผลมาจากการที่ดวงจันทร์หดตัวช้ามาก
#          Target: Scientists have discovered landforms littered across the moon's surface called lobate scarps that have apparently resulted from the moon's shrinking very slowly.
#
# Pair 27 - Source: ชูมัคเกอร์ซึ่งเกษียณในปี 2006 หลังจากที่คว้าแชมป์ฟอร์มูล่าวันไปเจ็ดครั้ง ต้องเข้ามาทำหน้าที่แทนเฟลิเป้ มาสซาซึ่งได้รับบาดเจ็บ
#          Target: Schumacher who retired in 2006 after winning the Formula 1 championship seven times, was due to replace the injured Felipe Massa.
#
# Pair 28 - Source: HK Management Inc. ซึ่งเป็นบริษัทจัดการของวงไม่ได้ให้เหตุผลเบื้องต้นตอนที่พวกเขายกเลิกในวันที่ 20 กันยายน แต่วันรุ่งขึ้นก็กล่าวโทษเหตุผลที่มีตรรกะต่าง ๆ
#          Target: The band's management company, HK Management Inc., gave no initial reason when they canceled on September 20, but blamed logistical reasons by the next day.
#
# Pair 29 - Source: มีค่าธรรมเนียมเพิ่มเติมสำหรับการเดินทางโดยมีผู้โดยสารมากกว่า 2 คน ตัวเลือกนี้จึงอาจมีราคาแพงกว่าที่จำเป็น
#          Target: There is a surcharge for having more than 2 passengers, so this option might be more expensive than necessary.
#
# Pair 30 - Source: กลุ่มเต้นรำ Fire of Anatolia ของตุรกี ได้แสดงการเต้นรำชุด "Troy" เพื่อจบการแสดง
#          Target: To finish, Turkish dance group Fire of Anatolia performed the show "Troy".
#
# Pair 31 - Source: บุคคลที่มีส่วนเกี่ยวข้องมาหลายสิบปีช่วยให้เราชื่นชมจุดแข็งและความหลงใหลของตัวเอง พร้อมทั้งประเมินความยากลำบากและกระทั่งความล้มเหลวอย่างตรงไปตรงมาในขณะเดียวกัน
#          Target: Individuals who had been involved for several decades helped us appreciate our strengths and passions while candidly assessing difficulties and even failures.
#
# Pair 32 - Source: แอปแปลข้อความตามเวลาจริง - แอปพลิเคชั่นที่สามารถแปลข้อความทั้งส่วนจากภาษาหนึ่งเป็นอีกภาษาได้โดยอัตโนมัติ
#          Target: Real-time text translator apps – applications that are capable of automatically translating whole segments of text from one language into another.
#
# Pair 33 - Source: ในกรณีนี้ การนึกถึงตัวอย่างพฤติกรรมแบบผู้บริหารและผลลัพธ์ความสำเร็จที่ตามมาช่วยให้ผู้คนเปิดรับความเปลี่ยนแปลงและแนวทางใหม่ๆ สำหรับคริสตจักรในท้องถิ่น
#          Target: In this instance, recalling previous instances of entrepreneurial behavior and resulting successes helped people to be open to new changes and new direction for the local church.
#
# Pair 34 - Source: หลังจากเกิดเพลิงไหม้ ป้อมปราการได้รับการอนุรักษ์และปกป้อง และยังคงเป็นสถานที่ท่องเที่ยวที่น่าตื่นตาตื่นใจที่สุดแห่งหนึ่งของภูฏาน
#          Target: After the fire, the fortress was preserved and protected, remaining to be one of Bhutan's most sensational attractions.
#
# Pair 35 - Source: โรงแรมหรือเจ้าบ้านของคุณ (กรณีที่คุณพักในเกสต์เฮาส์หรือบ้านส่วนตัว) มักจะมี wifi หรือคอมพิวเตอร์ที่ต่อกับอินเทอร์เน็ต และทุกชุมชนจะมีร้านอินเทอร์เน็ตหรือบางที่ก็มี wifi สาธารณะ
#          Target: Your hotel or hosts (if staying in a guesthouse or private home) will likely have wifi or an internet connected PC, and all settlements have an internet cafe or some location with public wifi.
#
# Pair 36 - Source: Lodin ยังกล่าวอีกว่าเจ้าหน้าที่ตัดสินใจยกเลิกการเลือกตั้งซ้ำเพื่อเป็นการประหยัดค่าใช้จ่ายและป้องกันความเสี่ยงด้านความปลอดภัยของการเลือกตั้งอื่นให้กับชาวอัฟกานิสถาน
#          Target: Lodin also said officials decided to cancel the runoff in order to save Afghans the expense and security risk of another election.
#
# Pair 37 - Source: ในบางประเทศที่มีรัฐบาลกลาง เช่น สหรัฐอเมริกา และแคนาดา จะมีการเรียกเก็บภาษีเงินได้ทั้งในระดับรัฐบาลกลางและในระดับท้องถิ่น ด้วยเหตุนี้ อัตราและขั้นภาษีอาจแตกต่างกันไปในแต่ละภูมิภาค
#          Target: In some federal countries, such as the United States and Canada, income tax is levied both at the federal level and at the local level, so the rates and brackets can vary from region to region.
#
# Pair 38 - Source: โดยทั่วไปคุณจะต้องประกาศการให้ความช่วยเหลือของคุณ เดินไปตามท่าเรือ เข้าหาผู้คนที่กำลังทำความสะอาดเรือยอตช์ พยายามติดต่อกับกะลาสีเรือในบาร์ และอื่น ๆ
#          Target: Basically you'll be putting up notices offering your help, pacing the docks, approaching people cleaning their yachts, trying to make contact with sailors in the bar, etc.
#
# Pair 39 - Source: ผู้ประท้วงหวังจะรวบรวมรายชื่อผู้ร้องเรียนได้ถึง 1.2 ล้านรายชื่อเพื่อเสนอต่อสภาคองเกรสในเดือนพฤศจิกายน
#          Target: Protesters hope to collect a petition of 1.2 million signatures to present to the National Congress in November.
#
# Pair 40 - Source: ธารน้ำแข็งไม่จับตัวแข็งมากนัก แต่มันไหลลงไปตามภูเขา ซึ่งเป็นสาเหตุของรอยแตกและรอยแยกของน้ำแข็งบนภูเขา ซึ่งอาจจะถูกสะพานหิมะปกคลุมไว้
#          Target: The glaciers are not stable, but flow down the mountain. This will cause cracks, crevasses, which may be obscured by snow bridges.
#
# Pair 41 - Source: Cinque Terre ซึ่งหมายความว่าห้าดินแดน ประกอบด้วยหมู่บ้านชายฝั่งห้าหมู่บ้าน ได้แก่ Riomaggiore, Manarola, Corniglia, Vernazza และ Monterosso ซึ่งตั้งอยู่ในแคว้น Liguria ประเทศอิตาลี
#          Target: Cinque Terre, which means Five Lands, comprises the five small coastal villages of Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso located in the Italian region of Liguria.
#
# Pair 42 - Source: แม้จะยังไม่ถึงขั้นเป็นปรากฏการณ์แห่งโลกยุคใหม่ แต่คนส่วนใหญ่ก็อาจเชื่อมโยงสิ่งนี้กับเยาวชนที่ใช้สีสเปรย์ฉีดทำลายทรัพย์สินสาธารณะและทรัพย์สินส่วนบุคคล
#          Target: While it's far from a modern phenomenon, most people probably associate it with youth vandalizing public and private property using spray paint.
#
# Pair 43 - Source: เรามีวิกฤตการณ์ทางการเงินตลอดทั้งปี ซึ่งเป็นช่วงเวลาที่เลวร้ายที่สุดในช่วงสองเดือนที่ผ่านมา และผมคิดว่าตอนนี้ตลาดการเงินกำลังเริ่มฟื้นตัวแล้ว "
#          Target: We have a year-long financial crisis, which has had its most acute moment in the past two months, and I think now the financial markets are beginning to recover."
#
# Pair 44 - Source: การเดินป่าในช่วงกลางวันมีตั้งแต่ระยะทางน้อยกว่าหนึ่งไมล์ไปจนถึงระยะทางไกลกว่าซึ่งสามารถเดินได้จบได้ในวันเดียว
#          Target: Day hiking involves distances of less than a mile up to longer distances that can be covered in a single day.
#
# Pair 45 - Source: อาจดูน่ากลัวเล็กน้อยเมื่อมองจากด้านล่างและเป็นทางขึ้นที่สูงชันและยากลำบาก แต่คนส่วนใหญ่ที่แข็งแรงพอควรจะขึ้นไปได้สำเร็จภายในเวลาประมาณ 45 นาที
#          Target: It looks a bit daunting from below, and it is a steep and difficult ascent, but most reasonably fit persons should be able to make it in about 45 minutes.
#
# Pair 46 - Source: ในช่วงฤดูร้อนต้องระวังยุงนอร์ดิกด้วย แม้ว่าพวกมันจะไม่ได้นำโรคใด ๆ แต่ก็อาจทำให้ระคายเคืองได้
#          Target: During the summer, also watch out for the Nordic mosquitoes. Although they do not transmit any diseases, they can be irritating.
#
# Pair 47 - Source: สถานที่หลายแห่งในโรโตรัวมีแฮงงิที่ทำจากพลังงานความร้อนใต้พิภพในขณะที่ แฮงงิประเภทอื่น ๆ จะสามารถลิ้มลองได้ในไครสต์เชิร์ช เวลลิงตัน และเมืองอื่น ๆ
#          Target: Several places in Rotorua offer geothermal hangi, while other hangi can be sampled in Christchurch, Wellington and elsewhere.
#
# Pair 48 - Source: ในศตวรรษที่ 18 กัมพูชารู้สึกว่าตนเองเปรียบเสมือนหญ้าแห้งที่อยู่ตรงกลางระหว่างช้างสองตัว คือ ประเทศไทยกับเวียดนาม
#          Target: During the 18th century Cambodia found itself squeezed between two powerful neighbors, Thailand and Vietnam.
#
# Pair 49 - Source: วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์ซ่าเมื่อสามฤดูกาลก่อน
#          Target: 28-year-old Vidal had joined Barça three seasons ago, from Sevilla.
#
# Pair 50 - Source: เจ้าหน้าที่ยังไม่รู้ชื่อของเขา รู้เพียงว่าเขาเป็นสมาชิกของกลุ่มชาติพันธุ์อุยกูร์
#          Target: His name is still unknown to authorities, although they do know he is a member of the Uighur ethnic group.
#
# Pair 51 - Source: โชคดีที่ฉันไม่เป็นอะไร แต่ก็ต้องเจอกับเหตุการณ์ขวัญผวาที่ได้เห็นผู้คนกำลังพยายามทุบทำลายหน้าต่างเพื่อหนีตายออกมาข้างนอก
#          Target: "Luckily nothing happened to me, but I saw a macabre scene, as people tried to break windows in order to get out.
#
# Pair 52 - Source: มีเพียงไม่กี่สายการบินเท่านั้นที่ยังคงเสนอค่าโดยสารเพื่อเยียวยาการสูญเสียที่จะช่วยลดค่าโดยสารเล็กน้อยให้ผู้ที่ต้องการเดินทางไปเข้าร่วมพิธีศพอย่างเร่งด่วน
#          Target: Only a few airlines still offer bereavement fares, which slightly discount the cost of last-minute funeral travel.
#
# Pair 53 - Source: เนื่องจากมีพื้นฐานมาจากการแข่งขัน Running Tours Barcelona ในเมืองบาร์เซโลนาและการแข่งขัน Running Copenhagen ในเมืองโคเปนเฮเกน จึงทำให้มีการนำการแข่งขัน Running Tours Prague ในกรุงปราก และการแข่งขันอื่น ๆ มาบรรจุอยู่ในเครือข่ายดังกล่าวอย่างรวดเร็ว
#          Target: With roots in Barcelona's Running Tours Barcelona and Copenhagen's Running Copenhagen, it was quickly joined by Running Tours Prague based in Prague and others.
#
# Pair 54 - Source: 2 ใน 3 ของชาวเวเนซุเอลาที่ทำงานทำงานในภาคบริการ เกือบ 1 ใน 4 ทำงานในภาคอุตสาหกรรม และ 1 ใน 5 ทำงานในภาคเกษตรกรรม
#          Target: Two thirds of Venezuelans who work do so in the service sector, nearly a quarter work in industry and a fifth work in agriculture.
#
# Pair 55 - Source: ก่อนที่ชาวสเปนจะมาที่นี่ในศตวรรษที่ 16 ตอนเหนือของชิลีอยู่ภายใต้การปกครองของจักรวรรดิอินคา ส่วนชนพื้นเมืองอาเรากานิอา (ชาวมาปูเช) อาศัยอยู่ในตอนกลางและตอนใต้ของชิลี
#          Target: Before the Spanish arrived in the 16th century, northern Chile was under Inca rule while the indigenous Araucanians (Mapuche) inhabited central and southern Chile.
#
# Pair 56 - Source: แคปซูลจะดูเหมือนดาวตกที่กำลังพุ่งข้ามฟากฟ้าอย่างมาก
#          Target: The capsule will look much like a shooting star going across the sky.
#
# Pair 57 - Source: ประมาณสิบนาทีก่อนถึงเวลาลงจอด เครื่องบินลำดังกล่าวหายไปเมื่อเข้าใกล้จุดหมายครั้งที่สอง
#          Target: About ten minutes before it was due to land from its second approach it disapeared.
#
# Pair 58 - Source: โดยทั่วไปแล้ว วีซ่านักเรียนจะมีข้อกำหนดและขั้นตอนการสมัครที่แตกต่างจากวีซ่านักท่องเที่ยวหรือวีซ่าธุรกิจแบบปกติ
#          Target: Student visas generally have different requirements and application procedures from normal tourist or business visas.
#
# Pair 59 - Source: การออกแบบเชิงโต้ตอบจำเป็นต้องให้ส่วนประกอบต่าง ๆ ของโปรเจ็กต์เชื่อมต่อกัน แต่ก็ใช้การได้ในฐานะเอนทิตีที่แยกต่างหากด้วยเช่นกัน
#          Target: Interactive design requires that components of a project connect to each other, but also make sense as a separate entity.
#
# Pair 60 - Source: มิตต์ รอมนี่ย์ (Mitt Romney) อดีตผู้ว่าการรัฐแมสซาชูเซตส์ชนะการเลือกตั้งขั้นต้นจากการลงชิงตำแหน่งประธานาธิบดีในนามพรรครีพับลิกันจากรัฐฟลอริดาเมื่อวันอังคารที่ผ่านมา ด้วยคะแนนเสียงมากกว่าร้อยละ 46
#          Target: Former Massachusetts governor Mitt Romney won the Florida Republican Party presidential primary election on Tuesday with over 46 percent of the vote.
#
# Pair 61 - Source: การบังคับโดรนให้บินใกล้ท่าอากาศยานหรือในฝูงชนแทบจะเป็นความคิดที่แย่อยู่เสมอ แม้ว่าการทำเช่นนี้จะไม่ผิดกฎหมายในพื้นที่ของคุณก็ตาม
#          Target: Flying a drone near an airport or over a crowd is almost always a bad idea, even if it's not illegal in your area.
#
# Pair 62 - Source: หากคุณต้องการบินรอบโลกในซีกโลกใต้อย่างสมบูรณ์ ตัวเลือกเที่ยวบินและจุดหมายปลายทางมีจำกัดเนื่องจากไม่มีเส้นทางที่ข้ามมหาสมุทร
#          Target: If you want to fly around the world completely in the Southern Hemisphere, the choice of flights and destinations is limited due to the lack of transoceanic routes.
#
# Pair 63 - Source: เซลล์เป็นหน่วยโครงสร้างที่มีหน้าที่ที่เล็กที่สุดของสิ่งมีชีวิต
#          Target: A cell is the smallest structural and functional unit of a living (things) organism.
#
# Pair 64 - Source: แนวคิดก็คือ ทุกประเทศในยุโรปต้องพยายามป้องกันไม่ให้ชาติใดชาติหนึ่งมีอำนาจเกินไป และด้วยเหตุนั้นรัฐบาลของชาติต่าง ๆ จึงมักสับเปลี่ยนพันธมิตรเพื่อรักษาสมดุลเอาไว้
#          Target: The concept was that all European nations had to seek to prevent one nation from becoming powerful, and thus national governments often changed their alliances in order to maintain the balance.
#
# Pair 65 - Source: เมืองนี้จะเป็นเมืองแรกในยุโรปตะวันออกเฉียงใต้ที่จัด CowParade ซึ่งเป็นงานศิลปะสาธารณะที่ใหญ่ที่สุดในโลก โดยจะจัดขึ้นในช่วงระหว่างเดือนมิถุนายนจนถึงสิงหาคมปีนี้
#          Target: The city will be the first in southeastern Europe to host CowParade, the world's largest public art event, between June and August this year.
#
# Pair 66 - Source: สเติร์นส์กำลังสืบสวนว่ามีการใช้ภาษีเพื่อสนับสนุนการทำแท้งผ่านองค์กร Planned Parenthood หรือไม่ ขณะที่สวมบทบาทประธานคณะอนุกรรมการกำกับดูแลและสืบสวน ซึ่งอยู่ภายใต้คณะกรรมาธิการพลังงานและการพาณิชย์
#          Target: Stearns is investigating whether taxes are used to fund abortions through Planned Parenthood in his role as chairman of the Oversight and Investigations Subcommittee, which is under the umbrella of the House Energy and Commerce Committee.
#
# Pair 67 - Source: ในปี พ.ศ. 2520 ดร.ดามาเดียนได้สร้างเครื่องสแกน MRI แบบ "ทั้งตัว" เป็นเครื่องแรก โดยเรียกมันว่า "เจ้าทรหดอดทน"
#          Target: In 1977, Dr. Damadian completed the construction of the first “whole-body” MRI scanner, which he called the ”Indomitable”.
#
# Pair 68 - Source: มีการเตรียมการที่จะนำทั้งกอล์ฟและรักบี้กลับไปแข่งขันในกีฬาโอลิมปิก
#          Target: Both golf and rugby are set to return to the Olympic Games.
#
# Pair 69 - Source: นายพล James Ewing จะนำทหาร 700 นายข้ามแม่น้ำที่ Trenton Ferry เข้ายึดสะพานข้ามลำห้วย Assunpink และป้องกันไม่ให้กองทหารข้าศึกหลบหนี
#          Target: General James Ewing would take 700 militia across the river at Trenton Ferry, seize the bridge over the Assunpink Creek and prevent any enemy troops from escaping.
#
# Pair 70 - Source: สัตว์เกิดขึ้นจากเซลล์จำนวนมาก พวกมันกินสิ่งต่าง ๆ และย่อยสิ่งเหล่านั้นภายในร่างกาย สัตว์ส่วนใหญ่เคลื่อนไหวได้
#          Target: Animals are made of many cells. They eat things and digest them inside. Most animals can move.
#
# Pair 71 - Source: นับตั้งแต่ก่อตั้งขึ้นมา The Onion ได้กลายเป็นอาณาจักรข่าวล้อเลียนที่แท้จริง โดยมีทั้งฉบับตีพิมพ์ เว็บไซต์ที่ดึงดูดผู้เข้าชมได้ถึง 5,000,000 คนในเดือนตุลาคม นอกจากนี้ยังมีโฆษณาส่วนบุคคล เครือข่ายข่าว 24 ชั่วโมง พอดแคสต์ และแผนที่โลกชื่อว่า Our Dumb World ที่เพิ่งเปิดตัวไปเมื่อไม่นานมานี้
#          Target: Since its inception, The Onion has become a veritable news parody empire, with a print edition, a website that drew 5,000,000 unique visitors in the month of October, personal ads, a 24 hour news network, podcasts, and a recently launched world atlas called Our Dumb World.
#
# Pair 72 - Source: พระชาวเยอรมันบางรูปปรารถนาที่จะให้พระเจ้าใกล้ชิดชาวพื้นเมืองมากขึ้นจึงได้คิดค้นภาษาเอสโตเนียขึ้นมา
#          Target: Some German monks wanted to bring God closer to the native people, so they invented the Estonian literal language.
#
# Pair 73 - Source: เอกวาดอร์มีข้อกำหนดให้พลเมืองคิวบาต้องได้รับหนังสือเชิญจึงจะสามารถเดินทางข้ามเข้าสู่เขตแดนเอกวาดอร์ผ่านสนามบินนานาชาติหรือด่านตรวจคนเข้าเมืองที่พรมแดน
#          Target: Ecuador requires that Cuban citizens receive an invitation letter prior to entering Ecuador through international airports or frontier admission points.
#
# Pair 74 - Source: การสื่อสารทางเดียวช่วยให้มีเวลาใช้ความคิดก่อนที่จะโต้ตอบผู้อื่น
#          Target: Asynchronous communication encourages time for reflection and reaction to others.
#
# Pair 75 - Source: เนื่องจากการโทรถูกส่งผ่านอินเทอร์เน็ต คุณจึงไม่จำเป็นต้องใช้บริษัทโทรศัพท์ที่ตั้งอยู่ในที่ที่อาศัยหรือที่ที่คุณเดินทางไป
#          Target: Because calls are routed over the Internet, you do not need to use a phone company located where you live or where you travel.
#
# Pair 76 - Source: เรือสำราญมากกว่า 60 ลำล่องไปตามน่านน้ำในกาลาปากอส โดยมีขนาดบรรทุกผู้โดยสารตั้งแต่ 8 ถึง 100 คน
#          Target: Over 60 cruise ships ply the Galapagos waters - ranging in size from 8 to 100 passengers.
#
# Pair 77 - Source: ข้อเท็จจริงที่ว่าหมู่บ้านจำนวนมากอยู่ห่างไกลแค่ไหน ทำให้คุณไม่สามารถพบเจอสถานบันเทิงยามค่ำคืนจำนวนมากโดยไม่เดินทางไปยังแอลบูเคอร์คีหรือซานตาเฟ่
#          Target: Given how remote many of the pueblos are, you won't be able to find a significant amount of nightlife without traveling to Albuquerque or Santa Fe.
#
# Pair 78 - Source: นอกจากนี้ ACMA ยังพบว่าแม้จะมีการสตรีมวิดีโอทางอินเทอร์เน็ต แต่บิกบราเธอร์ก็ไม่ได้ละเมิดกฎหมายการเซ็นเซอร์เนื้อหาออนไลน์ เนื่องจากสื่อดังกล่าวไม่ได้ถูกจัดเก็บไว้ในเว็บไซต์ของบิกบราเธอร์
#          Target: The ACMA also found that despite the video being streamed on the Internet, Big Brother had not breached online content censorship laws as the media had not been stored on Big Brother's website.
#
# Pair 79 - Source: หากคุณรักความเสี่ยงมากกว่านี้ ให้ใช้โอกาสนี้คั้นน้ำผลไม้หรือปั่นสมูทตี้ดูสิ:
#          Target: If you're feeling more adventurous, take the opportunity to juice or blend up some smoothies:
#
# Pair 80 - Source: มันช่วยให้นักเรียนสามารถทำงานได้ตามอัตราความเร็วของตนเอง รวมทั้งสามารถควบคุมอัตราเร็วของการให้ข้อมูลเชิงสอนได้
#          Target: It allows students the ability to work at their own pace and control the pace of instructional information.
#
# Pair 81 - Source: กรอบแว่นตาแบรนด์เนมระดับไฮเอนด์ที่มีขายอยู่ในพื้นที่เช่นนั้นอาจมีปัญหาได้สองอย่าง นั่นก็คือ บางกรอบอาจเป็นของปลอม ส่วนกรอบที่ได้มีการนำเข้ามาจริงก็อาจมีราคาแพงกว่าที่มีขายอยู่ในประเทศ
#          Target: High-end brand-name frames available in such areas may have two problems; some may be knock-offs, and the real imported ones may be more expensive than at home.
#
# Pair 82 - Source: อะตอมถือได้ว่าเป็นโครงสร้างพื้นฐานอย่างหนึ่งของทุกสสาร
#          Target: The atom can be considered to be one of the fundamental building blocks of all matter.
#
# Pair 83 - Source: อาการสมาธิสั้น "คือกลุ่มอาการทางระบบประสาทซึ่งอาการที่พบเป็นประจำ ได้แก่ หุนหันพลันแล่น วอกแวกง่าย อยู่ไม่นิ่ง หรือมีพลังงานมากเกิน"
#          Target: Attention Deficit Disorder "is a neurological syndrome whose classic defining triad of symptoms including impulsivity, distractibility, and hyperactivity or excess energy".
#
# Pair 84 - Source: เป็นที่เล่าขานกันมาว่าในปี ค.ศ. 1649 ท่านซับดรุง งาวัง นัมเยล (Zhabdrung Ngawang Namgyel) ได้สร้างป้อมปราการแห่งนี้ขึ้นเพื่อเป็นอนุสรณ์สถานแห่งชัยชนะของตนในการต่อต้านกองกำลังทิเบต-มองโกล
#          Target: It is said that in 1649, Zhabdrung Ngawang Namgyel created the fortress to commemorate his victory against the Tibetan-Mongol forces.
#
# Pair 85 - Source: บริษัทสื่อต่าง ๆ เหล่านี้มักไม่บอกจุดประสงค์ที่แท้จริงของการทำเช่นนี้ โดยอ้างว่าเป็นการ "ป้องกันการละเมิดลิขสิทธิ์"
#          Target: The media companies routinely lie about the purpose of this, claiming that it is to "prevent piracy".
#
# Pair 86 - Source: กีฬาชนิดนี้เล่นในรูปแบบการดวลเป็นสำคัญ โดยที่นักฟันดาบคนหนึ่งดวลกับนักฟันดาบอีกคนหนึ่ง
#          Target: The sport is primarily played in a duel format, one fencer dueling another.
#
# Pair 87 - Source: ในหลายประเทศที่มีกฎหมายดังกล่าว โรงแรมในท้องถิ่นจะจัดการเรื่องการลงทะเบียน (อย่าลืมสอบถาม)
#          Target: In many countries with such a law, local hotels will handle the registration (make sure to ask).
#
# Pair 88 - Source: แผนการของอเมริกาอาศัยการออกโจมตีพร้อมกันจากสามทิศทาง
#          Target: The American plan relied on launching coordinated attacks from three different directions.
#
# Pair 89 - Source: สิ่งปลูกสร้างหลายแห่งค่อนข้างสวยงามน่ามอง และทิวทัศน์จากตึกสูงหรือจากตำแหน่งหน้าต่างที่จัดวางไว้อย่างชาญฉลาดก็อาจเป็นความสวยงามที่มองเห็นได้
#          Target: Many buildings are quite beautiful to look at and the view from a tall building or from a cleverly-positioned window can be a beauty to behold.
#
# Pair 90 - Source: บรรยากาศมืดสลัวในบริเวณวัดและทิวทัศน์เหนือทะเลสาบโตนเลสาบทำให้การปีนขึ้นสู่เนินเขาเป็นเรื่องที่คุ้มค่า
#          Target: The gloomy atmosphere of the temple and the view over the Tonle Sap lake make the climb to the hill worthwhile.
#
# Pair 91 - Source: งานรวมศิลปินครั้งนี้ที่ยังเป็นส่วนหนึ่งของแคมเปญที่จัดโดยศาลาว่าการกรุงบูคาเรสต์ ในการพยายามสร้างภาพลักษณ์ของเมืองหลวงของโรมาเนียให้เป็นมหานครที่มีความสร้างสรรค์และมีสีสันอีกครั้ง
#          Target: The artistic event is also part of a campaign by the Bucharest City Hall that seeks to relaunch the image of the Romanian capital as a creative and colourful metropolis.
#
# Pair 92 - Source: เด็กเหล่านี้มักเผชิญกับปัญหามากมายเพราะพวกเขา "เข้าไปพัวพันกับพฤติกรรมเสี่ยง การต่อยตี และท้าทายเจ้าหน้าที่" เพื่อกระตุ้นสมองของตนเอง เนื่องจากสมองของพวกเขาไม่สามารถถูกกระตุ้นด้วยวิธีปกติได้
#          Target: These children tend to get into a lot of trouble, because they "engage in risky behaviors, get into fights, and challenge authority" in order to stimulate their brain, since their brain can not be stimulated by normal methods.
#
# Pair 93 - Source: มนุษย์ได้ผลิตและใช้เลนส์เพื่อประโยชน์ในการขยายภาพมานานหลายพันปีแล้ว
#          Target: Humans have been making and using lenses for magnification for thousands and thousands of years.
#
# Pair 94 - Source: การขว้างบูมเมอแรงคือทักษะยอดนิยมที่นักท่องเที่ยวหลายต่อหลายคนต้องการมี
#          Target: Boomerang throwing is a popular skill that many tourists want to acquire.
#
# Pair 95 - Source: กีฬาฟันดาบสมัยใหม่มีการแข่งขันกันในหลายระดับ ตั้งแต่ระดับนักศึกษามหาวิทยาลัยไปจนถึงระดับมืออาชีพและในกีฬาโอลิมปิก
#          Target: The modern sport of fencing is played at many levels, from students learning at a university to professional and Olympic competition.
#
# Pair 96 - Source: เขาเสียชีวิตที่โอซาก้าในวันอังคาร
#          Target: He died in Osaka on Tuesday.
#
# Pair 97 - Source: มีการจัดให้มีการสอบสวนเพื่อสืบสวน
#          Target: An inquiry was established to investigate.
#
# Pair 98 - Source: โรคติดต่อคือโรคชนิดหนึ่งที่แพร่เชื้อได้โดยง่ายเมื่ออยู่ใกล้ชิดกับผู้ติดเชื้อ
#          Target: A contagious disease is a disease which is easily transmitted by being in the vicinity of an infected person.
#
# Pair 99 - Source: ก๊าซจะเบาบางลงเมื่อเราเคลื่อนที่ไกลออกมาจากศูนย์กลางของดวงอาทิตย์
#          Target: The gas becomes thinner as you go farther from the center of the Sun.
#
# Pair 100 - Source: ปกติแล้วกิจกรรมเหล่านี้จะกินเวลาระหว่างสามถึงหกเดือนและจัดขึ้นในพื้นที่ซึ่งมีขนาดไม่เกิน 50 เฮกตาร์
#          Target: These events normally last anywhere between three and six months, and are held on sites no smaller than 50 hectares.

# %% [markdown]
# ### 2. Machine Translation with Seq2Seq model

# %% [markdown]
# **2.1 OPUS-MT**

# %%
# Import neccessary libraries for OPUS-MT
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
# load a pre-trained model and tokenizer for translation from Thai to English
opus_tokenizer = AutoTokenizer.from_pretrained('Helsinki-NLP/opus-mt-th-en')
opus_model = AutoModelForSeq2SeqLM.from_pretrained('Helsinki-NLP/opus-mt-th-en')

# %%
# Function for translation
def opus_translate_sentence(sentence, model, tokenizer):
    inputs = tokenizer(sentence, return_tensors="pt")
    outputs = model.generate(**inputs)
    translated_sentence = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return translated_sentence

# Define the list to store the translated sentences
opus_translated_sentences_list = []

# Perform translations on the 100 sentence pairs
for idx, (source_language, target_language) in enumerate(selected_pairs):
    # Translate from source to target
    opus_translated_sentence = opus_translate_sentence(source_language, opus_model, opus_tokenizer)

    # Add the sentence into the list
    opus_translated_sentences_list.append(opus_translated_sentence)

    # Display the results
    print(f"Pair {idx + 1}")
    print(f"Source: {source_language}")
    print(f"Target: {target_language}")
    print(f"Translated: {opus_translated_sentence}\n")
# Out:
# Pair 1
# Source: นี่ไม่ใช่กลุ่มอาการขาดทักษะด้านการเรียนรู้ แต่เป็นความผิดปกติทางการเรียนรู้ โรคนี้ "ส่งผลกระทบต่อเด็กร้อยละ 3 ถึง 5 ซึ่งอาจเป็นเด็กอเมริกันมากถึง 2 ล้านคน"
# Target: It is not a learning disability, it is a learning disorder; it "affects 3 to 5 percent of all children, perhaps as many as 2 million American children".
# Translated: This isn't a group of learning disability, it's a learning disorder, it's an effect on children from three to five, which is probably two million American children.
#
# Pair 2
# Source: ผู้ที่ไม่คุ้นเคยกับศัพท์เฉพาะทางการแพทย์คิดว่า คำว่าติดเชื้อและโรคติดต่อนั้นมีความหมายต่างกัน
# Target: For those unfamiliar with medical jargon, the words infectious and contagious have distinct meanings.
# Translated: Those who aren't familiar with medical terms think that infection and infectious diseases have different meanings.
#
# Pair 3
# Source: เขาตั้งข้อสังเกตว่า งานวิจัยบางชิ้นชี้ให้เห็นว่าโรคนี้จำเป็นต้องมีอันตรายน้อยลงก่อนที่มันจะแพร่ระบาดไปทั่วโลก
# Target: Some studies suggest that the disease must become less lethal before it can cause a global epidemic, he noted.
# Translated: He noted that some of the research suggests that it needs to be less dangerous before it spreads around the world.
#
# Pair 4
# Source: นักวิทยาศาสตร์รายอื่น ๆ แย้งว่าพืชเหล่านี้มีพิษร้ายแรง จึงไม่น่าเป็นไปได้ที่จะมีไดโนเสาร์ตัวใดกินพวกมันได้ แม้ว่าในปัจจุบันสลอธและสัตว์อื่น ๆ เช่น นกแก้ว (ลูกหลานของไดโนเสาร์) จะสามารถกินใบไม้หรือผลไม้มีพิษได้ก็ตาม
# Target: Other scientists argue that these plants are very poisonous so it is unlikely that any dinosaur ate them, even though today the sloth and other animals like the parrot (a descendant of the dinosaurs) can eat poisonous leaves or fruit.
# Translated: Other scientists argue that these plants are so toxic that there's no possibility that a dinosaur could eat them, although now Sloth and other animals, such as parrots, can eat leaves or poisonous fruit.
#
# Pair 5
# Source: ถึงแม้คุณอาจเคยได้ยินชาวกรีนแลนด์ใช้คำนี้ แต่ชาวต่างชาติไม่ควรใช้
# Target: While you may hear the word used by Greenlandic Natives, its use should be avoided by foreigners.
# Translated: Although you've probably heard of Greenlanders using that word, foreigners shouldn't use it.
#
# Pair 6
# Source: นอกจากนี้ยังไม่มีข้อกำหนดว่าคุณจะต้องwfhรับหมายเลขท้องถิ่นจากชุมชนที่คุณอาศัยอยู่ คุณสามารถรับการเชื่อมต่ออินเทอร์เน็ตผ่านดาวเทียมในชิกเก้นซึ่งเป็นเมืองที่ห่างไกลความเจริญในอลาสก้า และเลือกหมายเลขที่บ่งบอกว่าคุณอยู่ในแอริโซนาที่มีแสงแดดจ้า
# Target: There is also no requirement that you obtain a local number from the community in which you live; you can obtain a satellite Internet connection in the wilds of Chicken, Alaska and select a number which claims you're in sunny Arizona.
# Translated: There is no policy that you need to wffth to get local numbers from the community you live in, you can get Internet connections in Chicken, a remote town in Alaska, and pick numbers that indicate that you're in Arizona with bright sunlight.
#
# Pair 7
# Source: โฮสเทลแห่งหนึ่งถล่มในเมกกะซึ่งเป็นเมืองศักดิ์สิทธิ์ของศาสนาอิสลามเมื่อเวลาประมาณ 10 นาฬิกาของเช้าวันนี้ตามเวลาท้องถิ่น
# Target: A hostel collapsed in Mecca, the holy city of Islam at about 10 o'clock this morning local time.
# Translated: One of the Hostels collapsed in Megka, the holy city of Islam at about 10 o'clock in the morning, at local time.
#
# Pair 8
# Source: ถึงอย่างนั้นก็คาดได้เลยว่าจะต้องหายใจหอบ และต้องระวังในส่วนที่ลาดชันกว่าโดยเฉพาะเมื่อเปียก เนื่องจากอาจเกิดอันตรายได้อย่างรวดเร็ว
# Target: That said, expect to be out of breath, and take care in the steeper portions, especially when wet, as it can become dangerous quickly.
# Translated: Even so, it's expected to take a breath, and be careful of the steeper slopes, especially when we're wet, because they can be dangerous very quickly.
#
# Pair 9
# Source: ความเชื่อทางไสยศาสตร์สามารถจำแนกออกจากรูปแบบความเชื่อทางศาสนาและการบูชาอื่น ๆ ด้วยลักษณะที่เน้นในเรื่องประสบการณ์ตรงของการตระหนักรู้ในภาวะต่าง ๆ โดยเฉพาะภาวะของความรู้สึกสงบ การหยั่งรู้ ความผาสุก หรือแม้แต่ความปิติยินดีเหลือล้น
# Target: Mysticism can be distinguished from other forms of religious belief and worship by its emphasis on the direct personal experience of a unique state of consciousness, particularly those of a peaceful, insightful, blissful, or even ecstatic character.
# Translated: Hypocrisy can distinguish from religious and other religious forms of worship, with a feature that focuses on the accurate experience of awareness of conditions, especially the state of feeling calm, perception, joy, even extremism.
#
# Pair 10
# Source: สัตว์ป่าอาจขี้อายหรือก้าวร้าวก็ได้ สภาพแวดล้อมอาจเย็น ร้อน หรือยากลำบาก
# Target: Wild animals might either be shy or aggressive. The environment might be cold, hot, or otherwise hostile.
# Translated: The animal may be shy or aggressive, its environment may be cold, hot, or difficult.
#
# Pair 11
# Source: ปีเตอร์ เลนซ์ นักแข่งรถมอเตอร์ไซค์วัย 13 ปี เสียชีวิตหลังจากอยู่ในอุบัติเหตุรถชนกันที่อินเดียนาโปลิสมอเตอร์สปีดเวย์
# Target: Peter Lenz, a 13-year-old motorcycle racer, has died after being involved in a crash at the Indianapolis Motor Speedway.
# Translated: Peter Lance, a 13-year-old motorcycle racer, died after a car crash in Indianapolis, a speedway motor.
#
# Pair 12
# Source: ข่าวแพร่สะพัดในชุมชนเรดเลคในวันนี้ว่ามีนักเรียนอีกคนถูกจับุมจากการก่อเหตุกราดยิงในโรงเรียนเมื่อวันที่ 21 มีนาคม ขณะที่งานศพของ Jeff Weise และเหยื่อ 3 ใน 9 คนดำเนินอยู่
# Target: News spread in the Red Lake community today as funerals for Jeff Weise and three of the nine victims were held that another student was arrested in connection with the school shootings of March 21.
# Translated: The news spread in the Red Lake community today that another student was caught in a shooting in the school on March 21st, while Jeff Weise's funeral and 3 of the 9 victims were on the run.
#
# Pair 13
# Source: การปฏิบัติตามหลักการโภชนาการที่เหมาะสมแค่อย่างเดียวไม่สามารถช่วยให้เกิดสมรรถภาพระดับดีเลิศได้ แต่อาจส่งผลอย่างมากต่อสุขภาพโดยรวมของนักกีฬารุ่นเยาว์
# Target: Proper nutritional practices alone cannot generate elite performances, but they can significantly affect young athletes' overall wellness.
# Translated: Following just the right nutrition can't help to achieve excellent performance, but it can have a huge impact on the overall health of young athletes.
#
# Pair 14
# Source: พายุลูกนี้อยู่ห่างจากเมืองไมอามี่ในรัฐฟลอริดาราว 3,000 ไมล์โดยมีแรงลมสูงสุดอยู่ที่ 40 ไมล์/ชม. (64 กม./ชม.)
# Target: The storm, located approximately 3,000 miles from Miami, Florida, has maximum sustained winds of 40 mph (64 kph).
# Translated: This storm is 3,000 miles from Miami in Florida with the highest wind at 40 miles per hour.
#
# Pair 15
# Source: ทฤษฎีนี้ย้อนแย้งกับคำกล่าวอ้างที่ว่า ดวงจันทร์นั้นไม่มีความเคลื่อนไหวทางธรณีวิทยาเลยแม้แต่น้อย
# Target: This theory contradicts the claim that the moon is completely devoid of geologic activity.
# Translated: This theory contradicts the claim that the moon has no geological movement at all.
#
# Pair 16
# Source: การเข้าวัดจะต้องใช้บัตร Angkor Pass ดังนั้นเมื่อจะเดินทางไปโตนเลสาบ โปรดอย่าลืมนำหนังสือเดินทางติดตัวไปด้วย
# Target: The Angkor Pass is needed to enter the temple so do not forget to bring your passport along when heading to Tonle Sap.
# Translated: The measurement is required to use the Angkor Pass card, so on your way to Tonleucation, please remember to take your passport with you.
#
# Pair 17
# Source: เมื่อประชากรทั้งหมดมีลักษณะทางพันธุกรรมอย่างหนึ่งที่เหมือนกันก็จะถูกเรียกว่าโมโนมอร์ฟิก
# Target: When all individuals in a population are identical with regard to a particular phenotypic trait they are known as monomorphic.
# Translated: When the entire population has a genetic trait, it's called monomorphic.
#
# Pair 18
# Source: ส่วนใหญ่แล้วจะเกิดขึ้นกับคนที่ทำงานเกี่ยวข้องกับสัตว์ปีกมากกว่า แต่นักดูนกก็มีความเสี่ยงเช่นกัน
# Target: Most have involved people who work with poultry, but there is also some risk to birdwatchers.
# Translated: Most of the time, it happens to people who work with birds, but it's also at risk.
#
# Pair 19
# Source: แม้คุณอาจจะคิดว่าเป็นเรื่องดีที่จะใช้บริการสายการบินเดิม ๆ ที่คุณบินด้วยบ่อยที่สุด แต่ควรทราบไว้ว่าสิทธิพิเศษที่แต่ละสายการบินมอบให้มักจะแตกต่างกัน และคะแนนไมล์สะสมของสายการบินอื่นในกลุ่มพันธมิตรเดียวกันอาจให้ผลตอบแทนที่เป็นประโยชน์มากกว่า
# Target: Although you may think it is intuitive to join the airline you fly most, you should be aware that privileges offered are often different and frequent flyer points may be more generous under a different airline in the same alliance.
# Translated: Although you may think it's a good thing to use the same airline as you do most of the time, it's good to know that the privilege that each airline offers is often different and that the score of miles of other airlines in the same group may be more beneficial.
#
# Pair 20
# Source: หินบางชนิดที่หาได้ยากมากในโลก มีการขายตั้งแต่ราคา 11,000 ดอลลาร์สหรัฐไปจนถึง 22,500 ดอลลาร์สหรัฐต่อออนซ์ ซึ่งแพงกว่าราคาทองคำราวสิบเท่า
# Target: Some of the rocks, which are very rare on Earth, are being sold from US$11,000 to $22,500 per ounce, which is about ten times more than the cost of gold.
# Translated: Some of the most rare stones in the world are sold from $11,000 to 22,500 per ounce, which is about ten times the price of gold.
#
# Pair 21
# Source: เนื่องจากด้านล่างของใบมีดโค้งเล็กน้อย เมื่อใบมีดเอียงไปด้านใดด้านหนึ่ง ขอบที่สัมผัสกับน้ำแข็งจึงโค้งเช่นกัน
# Target: Because the bottom of the blade is slightly curved, as the blade tilts to one side or the other, the edge which is in contact with the ice also curves.
# Translated: Because the bottom of the blade is slightly curved, when the blade is tilted to either side, the edge that touches the ice is also curved.
#
# Pair 22
# Source: อย่างไรก็ตาม ในปัจจุบันศิลปินกราฟฟิตีที่ได้รับการยอมรับ มีงานอีเวนต์กราฟฟิตี และกำแพง สำหรับวาดภาพกราฟฟิตีที่ "ถูกกฎหมาย" ภาพวาดกราฟฟิตีในบริบทนี้มักคล้ายกับงานศิลปะมากกว่าป้ายที่อ่านไม่ออก
# Target: However, nowadays there are established graffiti artists, graffiti events and "legal" walls. Graffiti paintings in this context often resemble artworks rather than illegible tags.
# Translated: Now, however, the respected graphic artist has a fair event and a wall for drawing graphics at "lawful," a graphic picture in this context that is much more like an unreadable piece of art.
#
# Pair 23
# Source: การที่วาล์วเปิดทำให้แรงดันถูกปล่อยออกจากระบบ แล้วน้ำมันก็ไหลไปตามรางสู่ถังที่มีความจุ 55,000 บาร์เรล (2.3 ล้านแกลลอน)
# Target: The valves opening allowed a pressure release for the system and oil flowed on a pad to a tank that can hold 55,000 barrels (2.3 million gallons).
# Translated: The valve releases the pressure from the system, and then the oil leads to a tank with 55,000 barrels (.3 million gallons) in it.
#
# Pair 24
# Source: ภาษาเสริมคือภาษาประดิษฐ์หรือภาษาที่สร้างขึ้นโดยมีวัตถุประสงค์เพื่ออำนวยความสะดวกในการสื่อสารระหว่างผู้คนที่อาจมีปัญหาในการสื่อสารหากไม่มีภาษานี้
# Target: Auxiliary languages are artificial or constructed languages created with the intent of facilitating communication between peoples who would otherwise have difficulty communicating.
# Translated: It's an artificial language or a language built on purpose to accommodate communication between people who might have trouble communicating without it.
#
# Pair 25
# Source: โบเบ็ก เกิดในซาเกร็บซึ่งเป็นเมืองหลวงของโครเอเชียและมีชื่อเสียงขึ้นมาขณะเล่นให้กับปาร์ติซานเบลเกรด
# Target: Born in the Croatian capital, Zagreb, Bobek gained fame while playing for Partizan Belgrade.
# Translated: Bobek was born in Salem, which is the capital of Croatia and is famous for playing for the Partisan Belgrade.
#
# Pair 26
# Source: นักวิทยาศาสตร์ได้ค้นพบรูปแบบของเปลือกโลกที่เรียกว่า lobate scarp กระจัดกระจายอยู่ทั่วพื้นผิวดวงจันทร์ ซึ่งปรากฏว่าเป็นผลมาจากการที่ดวงจันทร์หดตัวช้ามาก
# Target: Scientists have discovered landforms littered across the moon's surface called lobate scarps that have apparently resulted from the moon's shrinking very slowly.
# Translated: Scientists have discovered a form of Earth's crust called the Lobeate Scar, scattered all over the surface of the moon, which appears to be the result of the very slow shrink of the moon.
#
# Pair 27
# Source: ชูมัคเกอร์ซึ่งเกษียณในปี 2006 หลังจากที่คว้าแชมป์ฟอร์มูล่าวันไปเจ็ดครั้ง ต้องเข้ามาทำหน้าที่แทนเฟลิเป้ มาสซาซึ่งได้รับบาดเจ็บ
# Target: Schumacher who retired in 2006 after winning the Formula 1 championship seven times, was due to replace the injured Felipe Massa.
# Translated: Schumacher, retired in 2006, after seven arrests of Formula Day, had to take over the injured Felicia Massa.
#
# Pair 28
# Source: HK Management Inc. ซึ่งเป็นบริษัทจัดการของวงไม่ได้ให้เหตุผลเบื้องต้นตอนที่พวกเขายกเลิกในวันที่ 20 กันยายน แต่วันรุ่งขึ้นก็กล่าวโทษเหตุผลที่มีตรรกะต่าง ๆ
# Target: The band's management company, HK Management Inc., gave no initial reason when they canceled on September 20, but blamed logistical reasons by the next day.
# Translated: HK Management Inc., which is a band management company, doesn't give them a preliminary reason when they cancel September 20th, but the next day, they blame them for various reasons.
#
# Pair 29
# Source: มีค่าธรรมเนียมเพิ่มเติมสำหรับการเดินทางโดยมีผู้โดยสารมากกว่า 2 คน ตัวเลือกนี้จึงอาจมีราคาแพงกว่าที่จำเป็น
# Target: There is a surcharge for having more than 2 passengers, so this option might be more expensive than necessary.
# Translated: With more than two passengers, this option may be more expensive than necessary.
#
# Pair 30
# Source: กลุ่มเต้นรำ Fire of Anatolia ของตุรกี ได้แสดงการเต้นรำชุด "Troy" เพื่อจบการแสดง
# Target: To finish, Turkish dance group Fire of Anatolia performed the show "Troy".
# Translated: The Fire of Antarctica dances of Turkey have performed a series of "Troy" dances to end the show.
#
# Pair 31
# Source: บุคคลที่มีส่วนเกี่ยวข้องมาหลายสิบปีช่วยให้เราชื่นชมจุดแข็งและความหลงใหลของตัวเอง พร้อมทั้งประเมินความยากลำบากและกระทั่งความล้มเหลวอย่างตรงไปตรงมาในขณะเดียวกัน
# Target: Individuals who had been involved for several decades helped us appreciate our strengths and passions while candidly assessing difficulties and even failures.
# Translated: Those who have been involved for decades have helped us to appreciate our strengths and our passions, with a straightforward assessment of our difficulties and even our failures at the same time.
#
# Pair 32
# Source: แอปแปลข้อความตามเวลาจริง - แอปพลิเคชั่นที่สามารถแปลข้อความทั้งส่วนจากภาษาหนึ่งเป็นอีกภาษาได้โดยอัตโนมัติ
# Target: Real-time text translator apps – applications that are capable of automatically translating whole segments of text from one language into another.
# Translated: Activating message at real time - apps can automatically translate text from one language into another.
#
# Pair 33
# Source: ในกรณีนี้ การนึกถึงตัวอย่างพฤติกรรมแบบผู้บริหารและผลลัพธ์ความสำเร็จที่ตามมาช่วยให้ผู้คนเปิดรับความเปลี่ยนแปลงและแนวทางใหม่ๆ สำหรับคริสตจักรในท้องถิ่น
# Target: In this instance, recalling previous instances of entrepreneurial behavior and resulting successes helped people to be open to new changes and new direction for the local church.
# Translated: In this case, thinking about the example of executive behavior and success that comes from helping people to embrace new changes and ways for local churches.
#
# Pair 34
# Source: หลังจากเกิดเพลิงไหม้ ป้อมปราการได้รับการอนุรักษ์และปกป้อง และยังคงเป็นสถานที่ท่องเที่ยวที่น่าตื่นตาตื่นใจที่สุดแห่งหนึ่งของภูฏาน
# Target: After the fire, the fortress was preserved and protected, remaining to be one of Bhutan's most sensational attractions.
# Translated: After the fire, the fortress was preserved and protected, and it was still one of the most amazing sights of the Bhutan.
#
# Pair 35
# Source: โรงแรมหรือเจ้าบ้านของคุณ (กรณีที่คุณพักในเกสต์เฮาส์หรือบ้านส่วนตัว) มักจะมี wifi หรือคอมพิวเตอร์ที่ต่อกับอินเทอร์เน็ต และทุกชุมชนจะมีร้านอินเทอร์เน็ตหรือบางที่ก็มี wifi สาธารณะ
# Target: Your hotel or hosts (if staying in a guesthouse or private home) will likely have wifi or an internet connected PC, and all settlements have an internet cafe or some location with public wifi.
# Translated: There's always a Wii or a computer connected to the Internet, and every community has an Internet or somewhere.
#
# Pair 36
# Source: Lodin ยังกล่าวอีกว่าเจ้าหน้าที่ตัดสินใจยกเลิกการเลือกตั้งซ้ำเพื่อเป็นการประหยัดค่าใช้จ่ายและป้องกันความเสี่ยงด้านความปลอดภัยของการเลือกตั้งอื่นให้กับชาวอัฟกานิสถาน
# Target: Lodin also said officials decided to cancel the runoff in order to save Afghans the expense and security risk of another election.
# Translated: Lotin also said that the authorities decided to cancel the election to save the cost and prevent the safety of other elections for the Afghanistanns.
#
# Pair 37
# Source: ในบางประเทศที่มีรัฐบาลกลาง เช่น สหรัฐอเมริกา และแคนาดา จะมีการเรียกเก็บภาษีเงินได้ทั้งในระดับรัฐบาลกลางและในระดับท้องถิ่น ด้วยเหตุนี้ อัตราและขั้นภาษีอาจแตกต่างกันไปในแต่ละภูมิภาค
# Target: In some federal countries, such as the United States and Canada, income tax is levied both at the federal level and at the local level, so the rates and brackets can vary from region to region.
# Translated: In some countries where the federal government, such as the United States and Canada, is required to collect taxes on both federal and local levels, thus maybe the rate and the tax level are different in each region.
#
# Pair 38
# Source: โดยทั่วไปคุณจะต้องประกาศการให้ความช่วยเหลือของคุณ เดินไปตามท่าเรือ เข้าหาผู้คนที่กำลังทำความสะอาดเรือยอตช์ พยายามติดต่อกับกะลาสีเรือในบาร์ และอื่น ๆ
# Target: Basically you'll be putting up notices offering your help, pacing the docks, approaching people cleaning their yachts, trying to make contact with sailors in the bar, etc.
# Translated: In general, you need to declare your aid, walking along the docks towards the people who are cleaning the yacht, trying to contact sailors in bars, and so forth.
#
# Pair 39
# Source: ผู้ประท้วงหวังจะรวบรวมรายชื่อผู้ร้องเรียนได้ถึง 1.2 ล้านรายชื่อเพื่อเสนอต่อสภาคองเกรสในเดือนพฤศจิกายน
# Target: Protesters hope to collect a petition of 1.2 million signatures to present to the National Congress in November.
# Translated: The protesters are hoping to gather 1.2 million complaints to the Congress in November.
#
# Pair 40
# Source: ธารน้ำแข็งไม่จับตัวแข็งมากนัก แต่มันไหลลงไปตามภูเขา ซึ่งเป็นสาเหตุของรอยแตกและรอยแยกของน้ำแข็งบนภูเขา ซึ่งอาจจะถูกสะพานหิมะปกคลุมไว้
# Target: The glaciers are not stable, but flow down the mountain. This will cause cracks, crevasses, which may be obscured by snow bridges.
# Translated: The glaciers aren't very solid, but they flow down the mountain, which causes cracks and ice cracks in the mountains, which may be covered by the snow bridge.
#
# Pair 41
# Source: Cinque Terre ซึ่งหมายความว่าห้าดินแดน ประกอบด้วยหมู่บ้านชายฝั่งห้าหมู่บ้าน ได้แก่ Riomaggiore, Manarola, Corniglia, Vernazza และ Monterosso ซึ่งตั้งอยู่ในแคว้น Liguria ประเทศอิตาลี
# Target: Cinque Terre, which means Five Lands, comprises the five small coastal villages of Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso located in the Italian region of Liguria.
# Translated: Cinque Terre, which means five lands consisting of five coastal villages, including Ryomagure, Manalola, Cornelius, Verza and Monteroso, which are located in Lyguria, Italy.
#
# Pair 42
# Source: แม้จะยังไม่ถึงขั้นเป็นปรากฏการณ์แห่งโลกยุคใหม่ แต่คนส่วนใหญ่ก็อาจเชื่อมโยงสิ่งนี้กับเยาวชนที่ใช้สีสเปรย์ฉีดทำลายทรัพย์สินสาธารณะและทรัพย์สินส่วนบุคคล
# Target: While it's far from a modern phenomenon, most people probably associate it with youth vandalizing public and private property using spray paint.
# Translated: Even though it's not yet a phenomenon of the modern world, most people might associate this with young people who use spray paint to destroy public property and personal property.
#
# Pair 43
# Source: เรามีวิกฤตการณ์ทางการเงินตลอดทั้งปี ซึ่งเป็นช่วงเวลาที่เลวร้ายที่สุดในช่วงสองเดือนที่ผ่านมา และผมคิดว่าตอนนี้ตลาดการเงินกำลังเริ่มฟื้นตัวแล้ว "
# Target: We have a year-long financial crisis, which has had its most acute moment in the past two months, and I think now the financial markets are beginning to recover."
# Translated: We have an annual financial crisis, which was the worst two months ago, and I think the financial market is starting to recover."
#
# Pair 44
# Source: การเดินป่าในช่วงกลางวันมีตั้งแต่ระยะทางน้อยกว่าหนึ่งไมล์ไปจนถึงระยะทางไกลกว่าซึ่งสามารถเดินได้จบได้ในวันเดียว
# Target: Day hiking involves distances of less than a mile up to longer distances that can be covered in a single day.
# Translated: Daywalks range from less than a mile to a longer distance, which can end in one day.
#
# Pair 45
# Source: อาจดูน่ากลัวเล็กน้อยเมื่อมองจากด้านล่างและเป็นทางขึ้นที่สูงชันและยากลำบาก แต่คนส่วนใหญ่ที่แข็งแรงพอควรจะขึ้นไปได้สำเร็จภายในเวลาประมาณ 45 นาที
# Target: It looks a bit daunting from below, and it is a steep and difficult ascent, but most reasonably fit persons should be able to make it in about 45 minutes.
# Translated: It's a little scary to look from the bottom and the steep and hard way up, but most of the people who are strong should be able to go up in about 45 minutes.
#
# Pair 46
# Source: ในช่วงฤดูร้อนต้องระวังยุงนอร์ดิกด้วย แม้ว่าพวกมันจะไม่ได้นำโรคใด ๆ แต่ก็อาจทำให้ระคายเคืองได้
# Target: During the summer, also watch out for the Nordic mosquitoes. Although they do not transmit any diseases, they can be irritating.
# Translated: During the summer, be careful of mosquitoes, even if they don't carry any diseases, it can be irritating.
#
# Pair 47
# Source: สถานที่หลายแห่งในโรโตรัวมีแฮงงิที่ทำจากพลังงานความร้อนใต้พิภพในขณะที่ แฮงงิประเภทอื่น ๆ จะสามารถลิ้มลองได้ในไครสต์เชิร์ช เวลลิงตัน และเมืองอื่น ๆ
# Target: Several places in Rotorua offer geothermal hangi, while other hangi can be sampled in Christchurch, Wellington and elsewhere.
# Translated: Many of the places in Rotoroy are filled with global warming, while others can be tasted in Christ's Church Wellington and other cities.
#
# Pair 48
# Source: ในศตวรรษที่ 18 กัมพูชารู้สึกว่าตนเองเปรียบเสมือนหญ้าแห้งที่อยู่ตรงกลางระหว่างช้างสองตัว คือ ประเทศไทยกับเวียดนาม
# Target: During the 18th century Cambodia found itself squeezed between two powerful neighbors, Thailand and Vietnam.
# Translated: In the 18th century, Cambodia felt like a dry grass in between two elephants: Thailand and Vietnam.
#
# Pair 49
# Source: วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์ซ่าเมื่อสามฤดูกาลก่อน
# Target: 28-year-old Vidal had joined Barça three seasons ago, from Sevilla.
# Translated: The 28-year-old Vidal moved from Sebija to join Barza three seasons ago.
#
# Pair 50
# Source: เจ้าหน้าที่ยังไม่รู้ชื่อของเขา รู้เพียงว่าเขาเป็นสมาชิกของกลุ่มชาติพันธุ์อุยกูร์
# Target: His name is still unknown to authorities, although they do know he is a member of the Uighur ethnic group.
# Translated: The authorities don't know his name yet, only that he's a member of the Uygure ethnic group.
#
# Pair 51
# Source: โชคดีที่ฉันไม่เป็นอะไร แต่ก็ต้องเจอกับเหตุการณ์ขวัญผวาที่ได้เห็นผู้คนกำลังพยายามทุบทำลายหน้าต่างเพื่อหนีตายออกมาข้างนอก
# Target: "Luckily nothing happened to me, but I saw a macabre scene, as people tried to break windows in order to get out.
# Translated: Luckily, I'm fine, but I've had a panic attack when people are trying to break windows to get out.
#
# Pair 52
# Source: มีเพียงไม่กี่สายการบินเท่านั้นที่ยังคงเสนอค่าโดยสารเพื่อเยียวยาการสูญเสียที่จะช่วยลดค่าโดยสารเล็กน้อยให้ผู้ที่ต้องการเดินทางไปเข้าร่วมพิธีศพอย่างเร่งด่วน
# Target: Only a few airlines still offer bereavement fares, which slightly discount the cost of last-minute funeral travel.
# Translated: There are only a few airlines still offering a fare to cure loss that will reduce the cost of a little fare for those who want to travel to the funeral in an emergency.
#
# Pair 53
# Source: เนื่องจากมีพื้นฐานมาจากการแข่งขัน Running Tours Barcelona ในเมืองบาร์เซโลนาและการแข่งขัน Running Copenhagen ในเมืองโคเปนเฮเกน จึงทำให้มีการนำการแข่งขัน Running Tours Prague ในกรุงปราก และการแข่งขันอื่น ๆ มาบรรจุอยู่ในเครือข่ายดังกล่าวอย่างรวดเร็ว
# Target: With roots in Barcelona's Running Tours Barcelona and Copenhagen's Running Copenhagen, it was quickly joined by Running Tours Prague based in Prague and others.
# Translated: Because it was based on the Running Times Barcelona competition in Barcelona and the Running Copenhagen in Copenhagen, it quickly led to bringing the Running Times Game in Prague and other competitions into the network.
#
# Pair 54
# Source: 2 ใน 3 ของชาวเวเนซุเอลาที่ทำงานทำงานในภาคบริการ เกือบ 1 ใน 4 ทำงานในภาคอุตสาหกรรม และ 1 ใน 5 ทำงานในภาคเกษตรกรรม
# Target: Two thirds of Venezuelans who work do so in the service sector, nearly a quarter work in industry and a fifth work in agriculture.
# Translated: 2 out of every 3 Venezuelans work in the Service Department, nearly 1 out of 4 works in the industrial sector, and 1 out of 5 works in agriculture.
#
# Pair 55
# Source: ก่อนที่ชาวสเปนจะมาที่นี่ในศตวรรษที่ 16 ตอนเหนือของชิลีอยู่ภายใต้การปกครองของจักรวรรดิอินคา ส่วนชนพื้นเมืองอาเรากานิอา (ชาวมาปูเช) อาศัยอยู่ในตอนกลางและตอนใต้ของชิลี
# Target: Before the Spanish arrived in the 16th century, northern Chile was under Inca rule while the indigenous Araucanians (Mapuche) inhabited central and southern Chile.
# Translated: Before the Spanish arrived here in the 16th century, northern Chile was ruled by the Inca Empire, and the Amencania natives lived in central and southern Chile.
#
# Pair 56
# Source: แคปซูลจะดูเหมือนดาวตกที่กำลังพุ่งข้ามฟากฟ้าอย่างมาก
# Target: The capsule will look much like a shooting star going across the sky.
# Translated: The capsule would look a lot like a meteor crossing the sky.
#
# Pair 57
# Source: ประมาณสิบนาทีก่อนถึงเวลาลงจอด เครื่องบินลำดังกล่าวหายไปเมื่อเข้าใกล้จุดหมายครั้งที่สอง
# Target: About ten minutes before it was due to land from its second approach it disapeared.
# Translated: About ten minutes before the landing, the plane disappeared as it approached its second destination.
#
# Pair 58
# Source: โดยทั่วไปแล้ว วีซ่านักเรียนจะมีข้อกำหนดและขั้นตอนการสมัครที่แตกต่างจากวีซ่านักท่องเที่ยวหรือวีซ่าธุรกิจแบบปกติ
# Target: Student visas generally have different requirements and application procedures from normal tourist or business visas.
# Translated: In general, student visas have a different policy and procedure than tourist visas or regular business visas.
#
# Pair 59
# Source: การออกแบบเชิงโต้ตอบจำเป็นต้องให้ส่วนประกอบต่าง ๆ ของโปรเจ็กต์เชื่อมต่อกัน แต่ก็ใช้การได้ในฐานะเอนทิตีที่แยกต่างหากด้วยเช่นกัน
# Target: Interactive design requires that components of a project connect to each other, but also make sense as a separate entity.
# Translated: Interactive design requires that the components of the project be connected, but it also works as a separate event.
#
# Pair 60
# Source: มิตต์ รอมนี่ย์ (Mitt Romney) อดีตผู้ว่าการรัฐแมสซาชูเซตส์ชนะการเลือกตั้งขั้นต้นจากการลงชิงตำแหน่งประธานาธิบดีในนามพรรครีพับลิกันจากรัฐฟลอริดาเมื่อวันอังคารที่ผ่านมา ด้วยคะแนนเสียงมากกว่าร้อยละ 46
# Target: Former Massachusetts governor Mitt Romney won the Florida Republican Party presidential primary election on Tuesday with over 46 percent of the vote.
# Translated: Mitt Romney, former governor of Massachusetts, won the first election for the presidential election from Florida last Tuesday, with over 46 percent of his votes.
#
# Pair 61
# Source: การบังคับโดรนให้บินใกล้ท่าอากาศยานหรือในฝูงชนแทบจะเป็นความคิดที่แย่อยู่เสมอ แม้ว่าการทำเช่นนี้จะไม่ผิดกฎหมายในพื้นที่ของคุณก็ตาม
# Target: Flying a drone near an airport or over a crowd is almost always a bad idea, even if it's not illegal in your area.
# Translated: Forcing drones to fly near airports or in the crowd is always a bad idea, even though doing so is not illegal in your area.
#
# Pair 62
# Source: หากคุณต้องการบินรอบโลกในซีกโลกใต้อย่างสมบูรณ์ ตัวเลือกเที่ยวบินและจุดหมายปลายทางมีจำกัดเนื่องจากไม่มีเส้นทางที่ข้ามมหาสมุทร
# Target: If you want to fly around the world completely in the Southern Hemisphere, the choice of flights and destinations is limited due to the lack of transoceanic routes.
# Translated: If you want to fly around the Earth completely, flight and destination choices are limited because there is no way across the ocean.
#
# Pair 63
# Source: เซลล์เป็นหน่วยโครงสร้างที่มีหน้าที่ที่เล็กที่สุดของสิ่งมีชีวิต
# Target: A cell is the smallest structural and functional unit of a living (things) organism.
# Translated: Cells are the smallest of life's structures.
#
# Pair 64
# Source: แนวคิดก็คือ ทุกประเทศในยุโรปต้องพยายามป้องกันไม่ให้ชาติใดชาติหนึ่งมีอำนาจเกินไป และด้วยเหตุนั้นรัฐบาลของชาติต่าง ๆ จึงมักสับเปลี่ยนพันธมิตรเพื่อรักษาสมดุลเอาไว้
# Target: The concept was that all European nations had to seek to prevent one nation from becoming powerful, and thus national governments often changed their alliances in order to maintain the balance.
# Translated: The idea is that every country in Europe has to try to prevent one nation from being too powerful, and that's why governments often swap allies to maintain balance.
#
# Pair 65
# Source: เมืองนี้จะเป็นเมืองแรกในยุโรปตะวันออกเฉียงใต้ที่จัด CowParade ซึ่งเป็นงานศิลปะสาธารณะที่ใหญ่ที่สุดในโลก โดยจะจัดขึ้นในช่วงระหว่างเดือนมิถุนายนจนถึงสิงหาคมปีนี้
# Target: The city will be the first in southeastern Europe to host CowParade, the world's largest public art event, between June and August this year.
# Translated: This city will be the first city in Southeast Europe to host the Showparade, the largest public art in the world, which will be held between June and August this year.
#
# Pair 66
# Source: สเติร์นส์กำลังสืบสวนว่ามีการใช้ภาษีเพื่อสนับสนุนการทำแท้งผ่านองค์กร Planned Parenthood หรือไม่ ขณะที่สวมบทบาทประธานคณะอนุกรรมการกำกับดูแลและสืบสวน ซึ่งอยู่ภายใต้คณะกรรมาธิการพลังงานและการพาณิชย์
# Target: Stearns is investigating whether taxes are used to fund abortions through Planned Parenthood in his role as chairman of the Oversight and Investigations Subcommittee, which is under the umbrella of the House Energy and Commerce Committee.
# Translated: Stearns is investigating whether there's a tax in support of an abortion through the Planned Parish, while playing the role of the President of the Administrative and Investigator, which is under the power and commercial commission of power.
#
# Pair 67
# Source: ในปี พ.ศ. 2520 ดร.ดามาเดียนได้สร้างเครื่องสแกน MRI แบบ "ทั้งตัว" เป็นเครื่องแรก โดยเรียกมันว่า "เจ้าทรหดอดทน"
# Target: In 1977, Dr. Damadian completed the construction of the first “whole-body” MRI scanner, which he called the ”Indomitable”.
# Translated: In 2002, Dr. Damadide created the first full MRI scanner, called "the tough one."
#
# Pair 68
# Source: มีการเตรียมการที่จะนำทั้งกอล์ฟและรักบี้กลับไปแข่งขันในกีฬาโอลิมปิก
# Target: Both golf and rugby are set to return to the Olympic Games.
# Translated: There's an arrangement to bring both golf and rugby back to the Olympics.
#
# Pair 69
# Source: นายพล James Ewing จะนำทหาร 700 นายข้ามแม่น้ำที่ Trenton Ferry เข้ายึดสะพานข้ามลำห้วย Assunpink และป้องกันไม่ให้กองทหารข้าศึกหลบหนี
# Target: General James Ewing would take 700 militia across the river at Trenton Ferry, seize the bridge over the Assunpink Creek and prevent any enemy troops from escaping.
# Translated: General James Eweing will lead 700 troops across the river at Trenton Fry to take the bridge across Assunlink and prevent enemy troops from escaping.
#
# Pair 70
# Source: สัตว์เกิดขึ้นจากเซลล์จำนวนมาก พวกมันกินสิ่งต่าง ๆ และย่อยสิ่งเหล่านั้นภายในร่างกาย สัตว์ส่วนใหญ่เคลื่อนไหวได้
# Target: Animals are made of many cells. They eat things and digest them inside. Most animals can move.
# Translated: Animals are made out of a lot of cells, they eat things and digest them inside of their bodies, most of them move.
#
# Pair 71
# Source: นับตั้งแต่ก่อตั้งขึ้นมา The Onion ได้กลายเป็นอาณาจักรข่าวล้อเลียนที่แท้จริง โดยมีทั้งฉบับตีพิมพ์ เว็บไซต์ที่ดึงดูดผู้เข้าชมได้ถึง 5,000,000 คนในเดือนตุลาคม นอกจากนี้ยังมีโฆษณาส่วนบุคคล เครือข่ายข่าว 24 ชั่วโมง พอดแคสต์ และแผนที่โลกชื่อว่า Our Dumb World ที่เพิ่งเปิดตัวไปเมื่อไม่นานมานี้
# Target: Since its inception, The Onion has become a veritable news parody empire, with a print edition, a website that drew 5,000,000 unique visitors in the month of October, personal ads, a 24 hour news network, podcasts, and a recently launched world atlas called Our Dumb World.
# Translated: Ever since the establishment, The Onion has become a real comic empire with a whole wide print of 5,000,000 visitors in October, also a personal advertisement, a 24-hour podcast network, and a map of the world called Order dub World, which has recently been launched.
#
# Pair 72
# Source: พระชาวเยอรมันบางรูปปรารถนาที่จะให้พระเจ้าใกล้ชิดชาวพื้นเมืองมากขึ้นจึงได้คิดค้นภาษาเอสโตเนียขึ้นมา
# Target: Some German monks wanted to bring God closer to the native people, so they invented the Estonian literal language.
# Translated: Some German priests wished that God would be closer to the natives, and they invented Estonian.
#
# Pair 73
# Source: เอกวาดอร์มีข้อกำหนดให้พลเมืองคิวบาต้องได้รับหนังสือเชิญจึงจะสามารถเดินทางข้ามเข้าสู่เขตแดนเอกวาดอร์ผ่านสนามบินนานาชาติหรือด่านตรวจคนเข้าเมืองที่พรมแดน
# Target: Ecuador requires that Cuban citizens receive an invitation letter prior to entering Ecuador through international airports or frontier admission points.
# Translated: Ecuador is scheduled to receive an invitation to travel across Ecuador through international airports or border patrols.
#
# Pair 74
# Source: การสื่อสารทางเดียวช่วยให้มีเวลาใช้ความคิดก่อนที่จะโต้ตอบผู้อื่น
# Target: Asynchronous communication encourages time for reflection and reaction to others.
# Translated: One way to communicate gives you time to think before you interact.
#
# Pair 75
# Source: เนื่องจากการโทรถูกส่งผ่านอินเทอร์เน็ต คุณจึงไม่จำเป็นต้องใช้บริษัทโทรศัพท์ที่ตั้งอยู่ในที่ที่อาศัยหรือที่ที่คุณเดินทางไป
# Target: Because calls are routed over the Internet, you do not need to use a phone company located where you live or where you travel.
# Translated: Because of the call being sent over the Internet, you don't need a mobile phone company that's located where you live or where you travel.
#
# Pair 76
# Source: เรือสำราญมากกว่า 60 ลำล่องไปตามน่านน้ำในกาลาปากอส โดยมีขนาดบรรทุกผู้โดยสารตั้งแต่ 8 ถึง 100 คน
# Target: Over 60 cruise ships ply the Galapagos waters - ranging in size from 8 to 100 passengers.
# Translated: More than 60 cruise ships sailed by sea in Galápagos, with the size of an eight to 100 passengers.
#
# Pair 77
# Source: ข้อเท็จจริงที่ว่าหมู่บ้านจำนวนมากอยู่ห่างไกลแค่ไหน ทำให้คุณไม่สามารถพบเจอสถานบันเทิงยามค่ำคืนจำนวนมากโดยไม่เดินทางไปยังแอลบูเคอร์คีหรือซานตาเฟ่
# Target: Given how remote many of the pueblos are, you won't be able to find a significant amount of nightlife without traveling to Albuquerque or Santa Fe.
# Translated: The fact that so many villages are so far away that you can't see so many night theaters without traveling to Albuquerque or Santa Fe.
#
# Pair 78
# Source: นอกจากนี้ ACMA ยังพบว่าแม้จะมีการสตรีมวิดีโอทางอินเทอร์เน็ต แต่บิกบราเธอร์ก็ไม่ได้ละเมิดกฎหมายการเซ็นเซอร์เนื้อหาออนไลน์ เนื่องจากสื่อดังกล่าวไม่ได้ถูกจัดเก็บไว้ในเว็บไซต์ของบิกบราเธอร์
# Target: The ACMA also found that despite the video being streamed on the Internet, Big Brother had not breached online content censorship laws as the media had not been stored on Big Brother's website.
# Translated: ACMA also found that despite the Internet video stream, Big Brother did not break the sensor law because the media was not listed on Big Brother's website.
#
# Pair 79
# Source: หากคุณรักความเสี่ยงมากกว่านี้ ให้ใช้โอกาสนี้คั้นน้ำผลไม้หรือปั่นสมูทตี้ดูสิ:
# Target: If you're feeling more adventurous, take the opportunity to juice or blend up some smoothies:
# Translated: If you love more risk, take this opportunity to squeeze a juice or spin a smoothie. Look:
#
# Pair 80
# Source: มันช่วยให้นักเรียนสามารถทำงานได้ตามอัตราความเร็วของตนเอง รวมทั้งสามารถควบคุมอัตราเร็วของการให้ข้อมูลเชิงสอนได้
# Target: It allows students the ability to work at their own pace and control the pace of instructional information.
# Translated: It allows students to work at their own pace, and it can control the speed of teaching information.
#
# Pair 81
# Source: กรอบแว่นตาแบรนด์เนมระดับไฮเอนด์ที่มีขายอยู่ในพื้นที่เช่นนั้นอาจมีปัญหาได้สองอย่าง นั่นก็คือ บางกรอบอาจเป็นของปลอม ส่วนกรอบที่ได้มีการนำเข้ามาจริงก็อาจมีราคาแพงกว่าที่มีขายอยู่ในประเทศ
# Target: High-end brand-name frames available in such areas may have two problems; some may be knock-offs, and the real imported ones may be more expensive than at home.
# Translated: The high-end brand brand name frames that are sold in that area may have two problems: that some of them may be fake, and the ones that have been imported may be more expensive than they are sold in the country.
#
# Pair 82
# Source: อะตอมถือได้ว่าเป็นโครงสร้างพื้นฐานอย่างหนึ่งของทุกสสาร
# Target: The atom can be considered to be one of the fundamental building blocks of all matter.
# Translated: Atom is considered to be one of the basic structures of all matter.
#
# Pair 83
# Source: อาการสมาธิสั้น "คือกลุ่มอาการทางระบบประสาทซึ่งอาการที่พบเป็นประจำ ได้แก่ หุนหันพลันแล่น วอกแวกง่าย อยู่ไม่นิ่ง หรือมีพลังงานมากเกิน"
# Target: Attention Deficit Disorder "is a neurological syndrome whose classic defining triad of symptoms including impulsivity, distractibility, and hyperactivity or excess energy".
# Translated: It's a group of neurotransmitters, which are common symptoms of impulsiveness, easily distractedness, insecurities, or over-encouragement.
#
# Pair 84
# Source: เป็นที่เล่าขานกันมาว่าในปี ค.ศ. 1649 ท่านซับดรุง งาวัง นัมเยล (Zhabdrung Ngawang Namgyel) ได้สร้างป้อมปราการแห่งนี้ขึ้นเพื่อเป็นอนุสรณ์สถานแห่งชัยชนะของตนในการต่อต้านกองกำลังทิเบต-มองโกล
# Target: It is said that in 1649, Zhabdrung Ngawang Namgyel created the fortress to commemorate his victory against the Tibetan-Mongol forces.
# Translated: It has been said that in 1649, the Sub-Sabdung Namyel built this fortress to commemorate his victory against the Tibetan forces.
#
# Pair 85
# Source: บริษัทสื่อต่าง ๆ เหล่านี้มักไม่บอกจุดประสงค์ที่แท้จริงของการทำเช่นนี้ โดยอ้างว่าเป็นการ "ป้องกันการละเมิดลิขสิทธิ์"
# Target: The media companies routinely lie about the purpose of this, claiming that it is to "prevent piracy".
# Translated: The media companies often don't give away the true purpose of doing this, claiming to be "protective of copyright violations."
#
# Pair 86
# Source: กีฬาชนิดนี้เล่นในรูปแบบการดวลเป็นสำคัญ โดยที่นักฟันดาบคนหนึ่งดวลกับนักฟันดาบอีกคนหนึ่ง
# Target: The sport is primarily played in a duel format, one fencer dueling another.
# Translated: This kind of sport plays an important duel, where one swordsman fights with another swordsman.
#
# Pair 87
# Source: ในหลายประเทศที่มีกฎหมายดังกล่าว โรงแรมในท้องถิ่นจะจัดการเรื่องการลงทะเบียน (อย่าลืมสอบถาม)
# Target: In many countries with such a law, local hotels will handle the registration (make sure to ask).
# Translated: In many countries where it's legal, local hotels will handle registration.
#
# Pair 88
# Source: แผนการของอเมริกาอาศัยการออกโจมตีพร้อมกันจากสามทิศทาง
# Target: The American plan relied on launching coordinated attacks from three different directions.
# Translated: America's plan is based on a coordinated attack from three different directions.
#
# Pair 89
# Source: สิ่งปลูกสร้างหลายแห่งค่อนข้างสวยงามน่ามอง และทิวทัศน์จากตึกสูงหรือจากตำแหน่งหน้าต่างที่จัดวางไว้อย่างชาญฉลาดก็อาจเป็นความสวยงามที่มองเห็นได้
# Target: Many buildings are quite beautiful to look at and the view from a tall building or from a cleverly-positioned window can be a beauty to behold.
# Translated: Many structures are quite beautiful, and the landscape from a tall building or from an intelligent window position could be a visible beauty.
#
# Pair 90
# Source: บรรยากาศมืดสลัวในบริเวณวัดและทิวทัศน์เหนือทะเลสาบโตนเลสาบทำให้การปีนขึ้นสู่เนินเขาเป็นเรื่องที่คุ้มค่า
# Target: The gloomy atmosphere of the temple and the view over the Tonle Sap lake make the climb to the hill worthwhile.
# Translated: The dim atmosphere in the temple area and the landscape above Lake Tonlech makes climbing up the hill worthwhile.
#
# Pair 91
# Source: งานรวมศิลปินครั้งนี้ที่ยังเป็นส่วนหนึ่งของแคมเปญที่จัดโดยศาลาว่าการกรุงบูคาเรสต์ ในการพยายามสร้างภาพลักษณ์ของเมืองหลวงของโรมาเนียให้เป็นมหานครที่มีความสร้างสรรค์และมีสีสันอีกครั้ง
# Target: The artistic event is also part of a campaign by the Bucharest City Hall that seeks to relaunch the image of the Romanian capital as a creative and colourful metropolis.
# Translated: This gathering of artists is also part of a campaign organized by the City Hall of Bucharest in an attempt to rebuild the image of Romania's capital as a creative and colorful city.
#
# Pair 92
# Source: เด็กเหล่านี้มักเผชิญกับปัญหามากมายเพราะพวกเขา "เข้าไปพัวพันกับพฤติกรรมเสี่ยง การต่อยตี และท้าทายเจ้าหน้าที่" เพื่อกระตุ้นสมองของตนเอง เนื่องจากสมองของพวกเขาไม่สามารถถูกกระตุ้นด้วยวิธีปกติได้
# Target: These children tend to get into a lot of trouble, because they "engage in risky behaviors, get into fights, and challenge authority" in order to stimulate their brain, since their brain can not be stimulated by normal methods.
# Translated: These kids often face a lot of problems because they're "involved with risky behavior, beatings and challenging officials" to stimulate their brains, because their brains can't be activated in a normal way.
#
# Pair 93
# Source: มนุษย์ได้ผลิตและใช้เลนส์เพื่อประโยชน์ในการขยายภาพมานานหลายพันปีแล้ว
# Target: Humans have been making and using lenses for magnification for thousands and thousands of years.
# Translated: Humans have been producing and using lens for thousands of years.
#
# Pair 94
# Source: การขว้างบูมเมอแรงคือทักษะยอดนิยมที่นักท่องเที่ยวหลายต่อหลายคนต้องการมี
# Target: Boomerang throwing is a popular skill that many tourists want to acquire.
# Translated: Throwing boomerang is the most popular skill many tourists want.
#
# Pair 95
# Source: กีฬาฟันดาบสมัยใหม่มีการแข่งขันกันในหลายระดับ ตั้งแต่ระดับนักศึกษามหาวิทยาลัยไปจนถึงระดับมืออาชีพและในกีฬาโอลิมปิก
# Target: The modern sport of fencing is played at many levels, from students learning at a university to professional and Olympic competition.
# Translated: Modern swordfights have many levels of competition, from university to professional and in the Olympics.
#
# Pair 96
# Source: เขาเสียชีวิตที่โอซาก้าในวันอังคาร
# Target: He died in Osaka on Tuesday.
# Translated: He died in Osaka on Tuesday.
#
# Pair 97
# Source: มีการจัดให้มีการสอบสวนเพื่อสืบสวน
# Target: An inquiry was established to investigate.
# Translated: There's been an investigation.
#
# Pair 98
# Source: โรคติดต่อคือโรคชนิดหนึ่งที่แพร่เชื้อได้โดยง่ายเมื่ออยู่ใกล้ชิดกับผู้ติดเชื้อ
# Target: A contagious disease is a disease which is easily transmitted by being in the vicinity of an infected person.
# Translated: Infection is a disease that can easily spread when it's close to the infected.
#
# Pair 99
# Source: ก๊าซจะเบาบางลงเมื่อเราเคลื่อนที่ไกลออกมาจากศูนย์กลางของดวงอาทิตย์
# Target: The gas becomes thinner as you go farther from the center of the Sun.
# Translated: The gas will be thinr as we move far from the center of the Sun.
#
# Pair 100
# Source: ปกติแล้วกิจกรรมเหล่านี้จะกินเวลาระหว่างสามถึงหกเดือนและจัดขึ้นในพื้นที่ซึ่งมีขนาดไม่เกิน 50 เฮกตาร์
# Target: These events normally last anywhere between three and six months, and are held on sites no smaller than 50 hectares.
# Translated: These activities usually take between three and six months and hold in an area that is no more than 50 hagtar.

# %%
# This is the code that I just practice to use Ctranslate2, I will set the codes as comments but not run it to show the result
# However, you can set it as a code and try to run to see the result
# Note: The final result will focus on the above method.
# !wget https://object.pouta.csc.fi/OPUS-MT-models/th-en/opus-2020-01-16.zip
# !unzip opus-2020-01-16.zip
# !ct2-opus-mt-converter --model_dir . --output_dir then_ctranslate2

# import ctranslate2
# import sentencepiece as spm

# sp = spm.SentencePieceProcessor()
# sp.load("source.spm")

# ctranslate2_list = []

# for idx, (source_language, target_language) in enumerate(selected_pairs):
#     source = sp.encode(source_language, out_type=str)
#     translator = ctranslate2.Translator("then_ctranslate2")
#     results = translator.translate_batch([source])
#     output = sp.decode(results[0].hypotheses[0]).replace("▁", " ")

#     # Add the sentence into the list
#     ctranslate2_list.append(output)

#     # Display the results
#     print(f"Pair {idx + 1}")
#     print(f"Source: {source_language}")
#     print(f"Target: {target_language}")
#     print(f"Translated: {output}\n")

# %% [markdown]
# **2.2 M2M-100**

# %%
# Import necessary library for M2M-100
from transformers import M2M100ForConditionalGeneration, M2M100Tokenizer

# %%
# load a pre-trained model and tokenizer for the M2M100 model
m2m_model = M2M100ForConditionalGeneration.from_pretrained("facebook/m2m100_418M")
m2m_tokenizer = M2M100Tokenizer.from_pretrained("facebook/m2m100_418M")

# %%
# Function for translation (Thai to English)
def m2m_translate_sentence(sentence, model, tokenizer):
    tokenizer.src_lang = "th"
    inputs = tokenizer(sentence, return_tensors="pt")
    outputs = model.generate(**inputs, forced_bos_token_id=tokenizer.get_lang_id("en"))
    translated_sentence = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return translated_sentence

# Define the list to store the length of the translated sentences
m2m_translated_sentences_list = []

# Perform translations on the 100 sentence pairs
for idx, (source_language, target_language) in enumerate(selected_pairs):
    # Translate from source to target
    m2m_translated_sentence = m2m_translate_sentence(source_language, m2m_model, m2m_tokenizer)

    # Add the sentence into the list
    m2m_translated_sentences_list.append(m2m_translated_sentence)

    # Display the results
    print(f"Pair {idx + 1}")
    print(f"Source: {source_language}")
    print(f"Target: {target_language}")
    print(f"Translated: {m2m_translated_sentence}\n")
# Out:
# Pair 1
# Source: นี่ไม่ใช่กลุ่มอาการขาดทักษะด้านการเรียนรู้ แต่เป็นความผิดปกติทางการเรียนรู้ โรคนี้ "ส่งผลกระทบต่อเด็กร้อยละ 3 ถึง 5 ซึ่งอาจเป็นเด็กอเมริกันมากถึง 2 ล้านคน"
# Target: It is not a learning disability, it is a learning disorder; it "affects 3 to 5 percent of all children, perhaps as many as 2 million American children".
# Translated: This is not a group of learning failure, but a learning disorder. This disease "affects 3 to 5 per child, which may be up to 2 million American children."
#
# Pair 2
# Source: ผู้ที่ไม่คุ้นเคยกับศัพท์เฉพาะทางการแพทย์คิดว่า คำว่าติดเชื้อและโรคติดต่อนั้นมีความหมายต่างกัน
# Target: For those unfamiliar with medical jargon, the words infectious and contagious have distinct meanings.
# Translated: People who are not familiar with the specific medical term think that the word infection and contact disease have different meanings.
#
# Pair 3
# Source: เขาตั้งข้อสังเกตว่า งานวิจัยบางชิ้นชี้ให้เห็นว่าโรคนี้จำเป็นต้องมีอันตรายน้อยลงก่อนที่มันจะแพร่ระบาดไปทั่วโลก
# Target: Some studies suggest that the disease must become less lethal before it can cause a global epidemic, he noted.
# Translated: He noted that some research suggests that the disease needs to be less dangerous before it spreads throughout the world.
#
# Pair 4
# Source: นักวิทยาศาสตร์รายอื่น ๆ แย้งว่าพืชเหล่านี้มีพิษร้ายแรง จึงไม่น่าเป็นไปได้ที่จะมีไดโนเสาร์ตัวใดกินพวกมันได้ แม้ว่าในปัจจุบันสลอธและสัตว์อื่น ๆ เช่น นกแก้ว (ลูกหลานของไดโนเสาร์) จะสามารถกินใบไม้หรือผลไม้มีพิษได้ก็ตาม
# Target: Other scientists argue that these plants are very poisonous so it is unlikely that any dinosaur ate them, even though today the sloth and other animals like the parrot (a descendant of the dinosaurs) can eat poisonous leaves or fruit.
# Translated: Other scientists say these plants are seriously poisonous. Therefore it is unlikely that any dinosaurs eat them. Although today slots and other animals, such as glass birds (the descendants of the dinosaurs), can eat toxic leaves or fruits.
#
# Pair 5
# Source: ถึงแม้คุณอาจเคยได้ยินชาวกรีนแลนด์ใช้คำนี้ แต่ชาวต่างชาติไม่ควรใช้
# Target: While you may hear the word used by Greenlandic Natives, its use should be avoided by foreigners.
# Translated: Although you may have heard Greek people use this word, foreigners should not use it.
#
# Pair 6
# Source: นอกจากนี้ยังไม่มีข้อกำหนดว่าคุณจะต้องwfhรับหมายเลขท้องถิ่นจากชุมชนที่คุณอาศัยอยู่ คุณสามารถรับการเชื่อมต่ออินเทอร์เน็ตผ่านดาวเทียมในชิกเก้นซึ่งเป็นเมืองที่ห่างไกลความเจริญในอลาสก้า และเลือกหมายเลขที่บ่งบอกว่าคุณอยู่ในแอริโซนาที่มีแสงแดดจ้า
# Target: There is also no requirement that you obtain a local number from the community in which you live; you can obtain a satellite Internet connection in the wilds of Chicken, Alaska and select a number which claims you're in sunny Arizona.
# Translated: There is also no requirement that you will have to wfh get a local number from the community you live. You can get a satellite Internet connection in Chicago, which is a remote city of prosperity in Alaska. And select a number that indicates that you are in Arizona with sunlight.
#
# Pair 7
# Source: โฮสเทลแห่งหนึ่งถล่มในเมกกะซึ่งเป็นเมืองศักดิ์สิทธิ์ของศาสนาอิสลามเมื่อเวลาประมาณ 10 นาฬิกาของเช้าวันนี้ตามเวลาท้องถิ่น
# Target: A hostel collapsed in Mecca, the holy city of Islam at about 10 o'clock this morning local time.
# Translated: One hostel in Mexico, which is the sacred city of Islam at about 10 a.m. this morning by local time.
#
# Pair 8
# Source: ถึงอย่างนั้นก็คาดได้เลยว่าจะต้องหายใจหอบ และต้องระวังในส่วนที่ลาดชันกว่าโดยเฉพาะเมื่อเปียก เนื่องจากอาจเกิดอันตรายได้อย่างรวดเร็ว
# Target: That said, expect to be out of breath, and take care in the steeper portions, especially when wet, as it can become dangerous quickly.
# Translated: In this case, it is expected to have to breathe and be careful in the more smooth areas, especially when wet. Because it can be damaged quickly.
#
# Pair 9
# Source: ความเชื่อทางไสยศาสตร์สามารถจำแนกออกจากรูปแบบความเชื่อทางศาสนาและการบูชาอื่น ๆ ด้วยลักษณะที่เน้นในเรื่องประสบการณ์ตรงของการตระหนักรู้ในภาวะต่าง ๆ โดยเฉพาะภาวะของความรู้สึกสงบ การหยั่งรู้ ความผาสุก หรือแม้แต่ความปิติยินดีเหลือล้น
# Target: Mysticism can be distinguished from other forms of religious belief and worship by its emphasis on the direct personal experience of a unique state of consciousness, particularly those of a peaceful, insightful, blissful, or even ecstatic character.
# Translated: Theological beliefs can be classified out of the forms of religious beliefs and other instinct with a character that focuses on the direct experience of consciousness in various conditions, in particular the state of sentimental calmness, discernment, discernment, or even untouched pleasure.
#
# Pair 10
# Source: สัตว์ป่าอาจขี้อายหรือก้าวร้าวก็ได้ สภาพแวดล้อมอาจเย็น ร้อน หรือยากลำบาก
# Target: Wild animals might either be shy or aggressive. The environment might be cold, hot, or otherwise hostile.
# Translated: Wild animals may be violent or aggressive. The environment may be cold, hot or difficult.
#
# Pair 11
# Source: ปีเตอร์ เลนซ์ นักแข่งรถมอเตอร์ไซค์วัย 13 ปี เสียชีวิตหลังจากอยู่ในอุบัติเหตุรถชนกันที่อินเดียนาโปลิสมอเตอร์สปีดเวย์
# Target: Peter Lenz, a 13-year-old motorcycle racer, has died after being involved in a crash at the Indianapolis Motor Speedway.
# Translated: Peter Lens, a 13-year-old motorcycle rider, has died after a crash in India's Polish Motorcycle Speedway.
#
# Pair 12
# Source: ข่าวแพร่สะพัดในชุมชนเรดเลคในวันนี้ว่ามีนักเรียนอีกคนถูกจับุมจากการก่อเหตุกราดยิงในโรงเรียนเมื่อวันที่ 21 มีนาคม ขณะที่งานศพของ Jeff Weise และเหยื่อ 3 ใน 9 คนดำเนินอยู่
# Target: News spread in the Red Lake community today as funerals for Jeff Weise and three of the nine victims were held that another student was arrested in connection with the school shootings of March 21.
# Translated: News spread in the Redleck community today that another student was arrested for a school massacre on March 21. While Jeff Weise's massacre and 3 in 9 victims are ongoing.
#
# Pair 13
# Source: การปฏิบัติตามหลักการโภชนาการที่เหมาะสมแค่อย่างเดียวไม่สามารถช่วยให้เกิดสมรรถภาพระดับดีเลิศได้ แต่อาจส่งผลอย่างมากต่อสุขภาพโดยรวมของนักกีฬารุ่นเยาว์
# Target: Proper nutritional practices alone cannot generate elite performances, but they can significantly affect young athletes' overall wellness.
# Translated: Compliance with the principles of proper nutrition in a single step can not contribute to an excellent performance level, but can greatly affect the overall health of young athletes.
#
# Pair 14
# Source: พายุลูกนี้อยู่ห่างจากเมืองไมอามี่ในรัฐฟลอริดาราว 3,000 ไมล์โดยมีแรงลมสูงสุดอยู่ที่ 40 ไมล์/ชม. (64 กม./ชม.)
# Target: The storm, located approximately 3,000 miles from Miami, Florida, has maximum sustained winds of 40 mph (64 kph).
# Translated: This bull is 3,000 miles away from Miami, Florida, with a maximum wind power of 40 miles/h. (64 km/h.)
#
# Pair 15
# Source: ทฤษฎีนี้ย้อนแย้งกับคำกล่าวอ้างที่ว่า ดวงจันทร์นั้นไม่มีความเคลื่อนไหวทางธรณีวิทยาเลยแม้แต่น้อย
# Target: This theory contradicts the claim that the moon is completely devoid of geologic activity.
# Translated: This theory is contrary to the claim that the moon has no geological movement at all, even a little.
#
# Pair 16
# Source: การเข้าวัดจะต้องใช้บัตร Angkor Pass ดังนั้นเมื่อจะเดินทางไปโตนเลสาบ โปรดอย่าลืมนำหนังสือเดินทางติดตัวไปด้วย
# Target: The Angkor Pass is needed to enter the temple so do not forget to bring your passport along when heading to Tonle Sap.
# Translated: Measurement requires an Angkor Pass card, so when you’re traveling to Tonnell, please don’t forget to bring your passport with you.
#
# Pair 17
# Source: เมื่อประชากรทั้งหมดมีลักษณะทางพันธุกรรมอย่างหนึ่งที่เหมือนกันก็จะถูกเรียกว่าโมโนมอร์ฟิก
# Target: When all individuals in a population are identical with regard to a particular phenotypic trait they are known as monomorphic.
# Translated: When all populations have the same genetic characteristics, it is called monomorphic.
#
# Pair 18
# Source: ส่วนใหญ่แล้วจะเกิดขึ้นกับคนที่ทำงานเกี่ยวข้องกับสัตว์ปีกมากกว่า แต่นักดูนกก็มีความเสี่ยงเช่นกัน
# Target: Most have involved people who work with poultry, but there is also some risk to birdwatchers.
# Translated: Mostly, it occurs with people who work more related to birds. But birds are also at risk.
#
# Pair 19
# Source: แม้คุณอาจจะคิดว่าเป็นเรื่องดีที่จะใช้บริการสายการบินเดิม ๆ ที่คุณบินด้วยบ่อยที่สุด แต่ควรทราบไว้ว่าสิทธิพิเศษที่แต่ละสายการบินมอบให้มักจะแตกต่างกัน และคะแนนไมล์สะสมของสายการบินอื่นในกลุ่มพันธมิตรเดียวกันอาจให้ผลตอบแทนที่เป็นประโยชน์มากกว่า
# Target: Although you may think it is intuitive to join the airline you fly most, you should be aware that privileges offered are often different and frequent flyer points may be more generous under a different airline in the same alliance.
# Translated: Even if you might think it’s good to use the original airline services you fly with the most frequently, it should be noted that the special benefits that each airline offers are often different. And the accumulated mile score of other airlines in the same group of partners may provide more profitable rewards.
#
# Pair 20
# Source: หินบางชนิดที่หาได้ยากมากในโลก มีการขายตั้งแต่ราคา 11,000 ดอลลาร์สหรัฐไปจนถึง 22,500 ดอลลาร์สหรัฐต่อออนซ์ ซึ่งแพงกว่าราคาทองคำราวสิบเท่า
# Target: Some of the rocks, which are very rare on Earth, are being sold from US$11,000 to $22,500 per ounce, which is about ten times more than the cost of gold.
# Translated: Some of the stones are very difficult to find in the world. They are sold from $11,000 to $22,500 per ounce, which is ten times more expensive than the gold price.
#
# Pair 21
# Source: เนื่องจากด้านล่างของใบมีดโค้งเล็กน้อย เมื่อใบมีดเอียงไปด้านใดด้านหนึ่ง ขอบที่สัมผัสกับน้ำแข็งจึงโค้งเช่นกัน
# Target: Because the bottom of the blade is slightly curved, as the blade tilts to one side or the other, the edge which is in contact with the ice also curves.
# Translated: Because the bottom of the knife is slightly curved. When the knife goes to any side, the ice-touched edge is also curved.
#
# Pair 22
# Source: อย่างไรก็ตาม ในปัจจุบันศิลปินกราฟฟิตีที่ได้รับการยอมรับ มีงานอีเวนต์กราฟฟิตี และกำแพง สำหรับวาดภาพกราฟฟิตีที่ "ถูกกฎหมาย" ภาพวาดกราฟฟิตีในบริบทนี้มักคล้ายกับงานศิลปะมากกว่าป้ายที่อ่านไม่ออก
# Target: However, nowadays there are established graffiti artists, graffiti events and "legal" walls. Graffiti paintings in this context often resemble artworks rather than illegible tags.
# Translated: However, at present, graphic artists are acknowledged with Events, graphic works and walls. For "legal" graphic drawings, graphic drawings in this context are often more similar to artwork than unread labels.
#
# Pair 23
# Source: การที่วาล์วเปิดทำให้แรงดันถูกปล่อยออกจากระบบ แล้วน้ำมันก็ไหลไปตามรางสู่ถังที่มีความจุ 55,000 บาร์เรล (2.3 ล้านแกลลอน)
# Target: The valves opening allowed a pressure release for the system and oil flowed on a pad to a tank that can hold 55,000 barrels (2.3 million gallons).
# Translated: The opening of the valve causes the pressure to be released from the system. Then the oil flows along the thread to a tank with a capacity of 55,000 barrel (2.3 million gallons).
#
# Pair 24
# Source: ภาษาเสริมคือภาษาประดิษฐ์หรือภาษาที่สร้างขึ้นโดยมีวัตถุประสงค์เพื่ออำนวยความสะดวกในการสื่อสารระหว่างผู้คนที่อาจมีปัญหาในการสื่อสารหากไม่มีภาษานี้
# Target: Auxiliary languages are artificial or constructed languages created with the intent of facilitating communication between peoples who would otherwise have difficulty communicating.
# Translated: Additional language is an artificial language or language created for the purpose of facilitating communication between people who may have trouble communicating without this language.
#
# Pair 25
# Source: โบเบ็ก เกิดในซาเกร็บซึ่งเป็นเมืองหลวงของโครเอเชียและมีชื่อเสียงขึ้นมาขณะเล่นให้กับปาร์ติซานเบลเกรด
# Target: Born in the Croatian capital, Zagreb, Bobek gained fame while playing for Partizan Belgrade.
# Translated: Bobby was born in Sakraba, which is the capital of Croatia and became famous as playing for Partisan Bell Grade.
#
# Pair 26
# Source: นักวิทยาศาสตร์ได้ค้นพบรูปแบบของเปลือกโลกที่เรียกว่า lobate scarp กระจัดกระจายอยู่ทั่วพื้นผิวดวงจันทร์ ซึ่งปรากฏว่าเป็นผลมาจากการที่ดวงจันทร์หดตัวช้ามาก
# Target: Scientists have discovered landforms littered across the moon's surface called lobate scarps that have apparently resulted from the moon's shrinking very slowly.
# Translated: Scientists have discovered a form of the globe, called the scarp lobate, which is spread throughout the moon's surface, which appears to be a result of the very slow moon shrinking.
#
# Pair 27
# Source: ชูมัคเกอร์ซึ่งเกษียณในปี 2006 หลังจากที่คว้าแชมป์ฟอร์มูล่าวันไปเจ็ดครั้ง ต้องเข้ามาทำหน้าที่แทนเฟลิเป้ มาสซาซึ่งได้รับบาดเจ็บ
# Target: Schumacher who retired in 2006 after winning the Formula 1 championship seven times, was due to replace the injured Felipe Massa.
# Translated: Chucker, who retired in 2006, after winning the championship for seven days. He must come to the post to replace Flippe Massa, who was injured.
#
# Pair 28
# Source: HK Management Inc. ซึ่งเป็นบริษัทจัดการของวงไม่ได้ให้เหตุผลเบื้องต้นตอนที่พวกเขายกเลิกในวันที่ 20 กันยายน แต่วันรุ่งขึ้นก็กล่าวโทษเหตุผลที่มีตรรกะต่าง ๆ
# Target: The band's management company, HK Management Inc., gave no initial reason when they canceled on September 20, but blamed logistical reasons by the next day.
# Translated: HK Management Inc., which is the group’s managing company, did not give any reason in advance when they withdrew on September 20, but tomorrow it will punish for various logical reasons.
#
# Pair 29
# Source: มีค่าธรรมเนียมเพิ่มเติมสำหรับการเดินทางโดยมีผู้โดยสารมากกว่า 2 คน ตัวเลือกนี้จึงอาจมีราคาแพงกว่าที่จำเป็น
# Target: There is a surcharge for having more than 2 passengers, so this option might be more expensive than necessary.
# Translated: There are additional fees for travel with more than 2 passengers. This option may be more expensive than necessary.
#
# Pair 30
# Source: กลุ่มเต้นรำ Fire of Anatolia ของตุรกี ได้แสดงการเต้นรำชุด "Troy" เพื่อจบการแสดง
# Target: To finish, Turkish dance group Fire of Anatolia performed the show "Troy".
# Translated: The Turkish Fire of Anatolia dance group showed the dance series "Troy" to finish the show.
#
# Pair 31
# Source: บุคคลที่มีส่วนเกี่ยวข้องมาหลายสิบปีช่วยให้เราชื่นชมจุดแข็งและความหลงใหลของตัวเอง พร้อมทั้งประเมินความยากลำบากและกระทั่งความล้มเหลวอย่างตรงไปตรงมาในขณะเดียวกัน
# Target: Individuals who had been involved for several decades helped us appreciate our strengths and passions while candidly assessing difficulties and even failures.
# Translated: The person involved for decades has helped us to appreciate our own strength and passion. At the same time, both assessing difficulties and even failures directly.
#
# Pair 32
# Source: แอปแปลข้อความตามเวลาจริง - แอปพลิเคชั่นที่สามารถแปลข้อความทั้งส่วนจากภาษาหนึ่งเป็นอีกภาษาได้โดยอัตโนมัติ
# Target: Real-time text translator apps – applications that are capable of automatically translating whole segments of text from one language into another.
# Translated: Real-time text translation app - an application that can automatically translate all parts of the text from one language to another.
#
# Pair 33
# Source: ในกรณีนี้ การนึกถึงตัวอย่างพฤติกรรมแบบผู้บริหารและผลลัพธ์ความสำเร็จที่ตามมาช่วยให้ผู้คนเปิดรับความเปลี่ยนแปลงและแนวทางใหม่ๆ สำหรับคริสตจักรในท้องถิ่น
# Target: In this instance, recalling previous instances of entrepreneurial behavior and resulting successes helped people to be open to new changes and new direction for the local church.
# Translated: In this case, considering the examples of managerial behavior and the followed success results helps people open up new changes and guidelines for the local church.
#
# Pair 34
# Source: หลังจากเกิดเพลิงไหม้ ป้อมปราการได้รับการอนุรักษ์และปกป้อง และยังคงเป็นสถานที่ท่องเที่ยวที่น่าตื่นตาตื่นใจที่สุดแห่งหนึ่งของภูฏาน
# Target: After the fire, the fortress was preserved and protected, remaining to be one of Bhutan's most sensational attractions.
# Translated: After a fire, the castle was preserved and protected. And remains one of the most amazing tourist attractions in the mountains.
#
# Pair 35
# Source: โรงแรมหรือเจ้าบ้านของคุณ (กรณีที่คุณพักในเกสต์เฮาส์หรือบ้านส่วนตัว) มักจะมี wifi หรือคอมพิวเตอร์ที่ต่อกับอินเทอร์เน็ต และทุกชุมชนจะมีร้านอินเทอร์เน็ตหรือบางที่ก็มี wifi สาธารณะ
# Target: Your hotel or hosts (if staying in a guesthouse or private home) will likely have wifi or an internet connected PC, and all settlements have an internet cafe or some location with public wifi.
# Translated: Your hotel or hostel (if you stay in a guest house or private house) usually has a wifi or a computer that connects to the internet. And every community has an internet store or some that has a public wifi.
#
# Pair 36
# Source: Lodin ยังกล่าวอีกว่าเจ้าหน้าที่ตัดสินใจยกเลิกการเลือกตั้งซ้ำเพื่อเป็นการประหยัดค่าใช้จ่ายและป้องกันความเสี่ยงด้านความปลอดภัยของการเลือกตั้งอื่นให้กับชาวอัฟกานิสถาน
# Target: Lodin also said officials decided to cancel the runoff in order to save Afghans the expense and security risk of another election.
# Translated: Lodin also said the officials decided to cancel the re-election to save costs and prevent the security risks of another election to the Afghan citizens.
#
# Pair 37
# Source: ในบางประเทศที่มีรัฐบาลกลาง เช่น สหรัฐอเมริกา และแคนาดา จะมีการเรียกเก็บภาษีเงินได้ทั้งในระดับรัฐบาลกลางและในระดับท้องถิ่น ด้วยเหตุนี้ อัตราและขั้นภาษีอาจแตกต่างกันไปในแต่ละภูมิภาค
# Target: In some federal countries, such as the United States and Canada, income tax is levied both at the federal level and at the local level, so the rates and brackets can vary from region to region.
# Translated: In some countries with central governments such as the United States and Canada, financial taxes will be charged both at the central and local level. Therefore, rates and taxes may vary in each region.
#
# Pair 38
# Source: โดยทั่วไปคุณจะต้องประกาศการให้ความช่วยเหลือของคุณ เดินไปตามท่าเรือ เข้าหาผู้คนที่กำลังทำความสะอาดเรือยอตช์ พยายามติดต่อกับกะลาสีเรือในบาร์ และอื่น ๆ
# Target: Basically you'll be putting up notices offering your help, pacing the docks, approaching people cleaning their yachts, trying to make contact with sailors in the bar, etc.
# Translated: In general, you have to announce your assistance. Go through the port. Find those who are cleaning the yacht. Try to contact the boats in the bar and so on.
#
# Pair 39
# Source: ผู้ประท้วงหวังจะรวบรวมรายชื่อผู้ร้องเรียนได้ถึง 1.2 ล้านรายชื่อเพื่อเสนอต่อสภาคองเกรสในเดือนพฤศจิกายน
# Target: Protesters hope to collect a petition of 1.2 million signatures to present to the National Congress in November.
# Translated: The opponents are hoping to collect up to 1.2 million lists of complaints to submit to the Senate in November.
#
# Pair 40
# Source: ธารน้ำแข็งไม่จับตัวแข็งมากนัก แต่มันไหลลงไปตามภูเขา ซึ่งเป็นสาเหตุของรอยแตกและรอยแยกของน้ำแข็งบนภูเขา ซึ่งอาจจะถูกสะพานหิมะปกคลุมไว้
# Target: The glaciers are not stable, but flow down the mountain. This will cause cracks, crevasses, which may be obscured by snow bridges.
# Translated: The ice sheet doesn’t catch so hard, but it flows down to the mountains, which is the cause of fractures and separation of the ice on the mountains. It may be covered by snow bridges.
#
# Pair 41
# Source: Cinque Terre ซึ่งหมายความว่าห้าดินแดน ประกอบด้วยหมู่บ้านชายฝั่งห้าหมู่บ้าน ได้แก่ Riomaggiore, Manarola, Corniglia, Vernazza และ Monterosso ซึ่งตั้งอยู่ในแคว้น Liguria ประเทศอิตาลี
# Target: Cinque Terre, which means Five Lands, comprises the five small coastal villages of Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso located in the Italian region of Liguria.
# Translated: Cinque Terre, which means five territories, consists of five coastal villages, including Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso, which are located in the Liguria square, Italy.
#
# Pair 42
# Source: แม้จะยังไม่ถึงขั้นเป็นปรากฏการณ์แห่งโลกยุคใหม่ แต่คนส่วนใหญ่ก็อาจเชื่อมโยงสิ่งนี้กับเยาวชนที่ใช้สีสเปรย์ฉีดทำลายทรัพย์สินสาธารณะและทรัพย์สินส่วนบุคคล
# Target: While it's far from a modern phenomenon, most people probably associate it with youth vandalizing public and private property using spray paint.
# Translated: Even though it is not yet a phenomenon of the new world, most people may link this to young people using spray, injection, destroying public property and personal property.
#
# Pair 43
# Source: เรามีวิกฤตการณ์ทางการเงินตลอดทั้งปี ซึ่งเป็นช่วงเวลาที่เลวร้ายที่สุดในช่วงสองเดือนที่ผ่านมา และผมคิดว่าตอนนี้ตลาดการเงินกำลังเริ่มฟื้นตัวแล้ว "
# Target: We have a year-long financial crisis, which has had its most acute moment in the past two months, and I think now the financial markets are beginning to recover."
# Translated: We have a financial crisis throughout the year, which is the worst time in the last two months. And I think now the financial markets are beginning to recover.”
#
# Pair 44
# Source: การเดินป่าในช่วงกลางวันมีตั้งแต่ระยะทางน้อยกว่าหนึ่งไมล์ไปจนถึงระยะทางไกลกว่าซึ่งสามารถเดินได้จบได้ในวันเดียว
# Target: Day hiking involves distances of less than a mile up to longer distances that can be covered in a single day.
# Translated: Walking in the middle of the day is from a distance less than one mile to a further distance that can be completed in a single day.
#
# Pair 45
# Source: อาจดูน่ากลัวเล็กน้อยเมื่อมองจากด้านล่างและเป็นทางขึ้นที่สูงชันและยากลำบาก แต่คนส่วนใหญ่ที่แข็งแรงพอควรจะขึ้นไปได้สำเร็จภายในเวลาประมาณ 45 นาที
# Target: It looks a bit daunting from below, and it is a steep and difficult ascent, but most reasonably fit persons should be able to make it in about 45 minutes.
# Translated: It may seem a little scary when looking from the bottom and upward to the high and difficult. But most strong people should get up successfully within about 45 minutes.
#
# Pair 46
# Source: ในช่วงฤดูร้อนต้องระวังยุงนอร์ดิกด้วย แม้ว่าพวกมันจะไม่ได้นำโรคใด ๆ แต่ก็อาจทำให้ระคายเคืองได้
# Target: During the summer, also watch out for the Nordic mosquitoes. Although they do not transmit any diseases, they can be irritating.
# Translated: During the summer it is necessary to be careful with. Although they don’t take any illness, it can cause discomfort.
#
# Pair 47
# Source: สถานที่หลายแห่งในโรโตรัวมีแฮงงิที่ทำจากพลังงานความร้อนใต้พิภพในขณะที่ แฮงงิประเภทอื่น ๆ จะสามารถลิ้มลองได้ในไครสต์เชิร์ช เวลลิงตัน และเมืองอื่น ๆ
# Target: Several places in Rotorua offer geothermal hangi, while other hangi can be sampled in Christchurch, Wellington and elsewhere.
# Translated: Many places in Rotowa have Hangzhou that is made of underwater thermal energy, while other types of Hangzhou can be tasted in Christchurch, Wellington and other cities.
#
# Pair 48
# Source: ในศตวรรษที่ 18 กัมพูชารู้สึกว่าตนเองเปรียบเสมือนหญ้าแห้งที่อยู่ตรงกลางระหว่างช้างสองตัว คือ ประเทศไทยกับเวียดนาม
# Target: During the 18th century Cambodia found itself squeezed between two powerful neighbors, Thailand and Vietnam.
# Translated: In the 18th century, the Kamboja felt that it was virtually compared to the dry grass that was in the middle of the two grasses: Thailand and Vietnam.
#
# Pair 49
# Source: วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์ซ่าเมื่อสามฤดูกาลก่อน
# Target: 28-year-old Vidal had joined Barça three seasons ago, from Sevilla.
# Translated: Viral, 28 years old, moved from Siberia and joined Barcelona for three seasons before.
#
# Pair 50
# Source: เจ้าหน้าที่ยังไม่รู้ชื่อของเขา รู้เพียงว่าเขาเป็นสมาชิกของกลุ่มชาติพันธุ์อุยกูร์
# Target: His name is still unknown to authorities, although they do know he is a member of the Uighur ethnic group.
# Translated: Officers don't know his name. Just know that he is a member of the Ujjjjjjjjjjjjjjjj
#
# Pair 51
# Source: โชคดีที่ฉันไม่เป็นอะไร แต่ก็ต้องเจอกับเหตุการณ์ขวัญผวาที่ได้เห็นผู้คนกำลังพยายามทุบทำลายหน้าต่างเพื่อหนีตายออกมาข้างนอก
# Target: "Luckily nothing happened to me, but I saw a macabre scene, as people tried to break windows in order to get out.
# Translated: Luckily I wasn’t anything, but I had to go through the fair gift event that saw people trying to break the windows to get dead out.
#
# Pair 52
# Source: มีเพียงไม่กี่สายการบินเท่านั้นที่ยังคงเสนอค่าโดยสารเพื่อเยียวยาการสูญเสียที่จะช่วยลดค่าโดยสารเล็กน้อยให้ผู้ที่ต้องการเดินทางไปเข้าร่วมพิธีศพอย่างเร่งด่วน
# Target: Only a few airlines still offer bereavement fares, which slightly discount the cost of last-minute funeral travel.
# Translated: There are only a few airlines that still offer the cost of the flight to reward the loss that will help reduce the cost of the flight to those who want to travel to attend the ceremony urgently.
#
# Pair 53
# Source: เนื่องจากมีพื้นฐานมาจากการแข่งขัน Running Tours Barcelona ในเมืองบาร์เซโลนาและการแข่งขัน Running Copenhagen ในเมืองโคเปนเฮเกน จึงทำให้มีการนำการแข่งขัน Running Tours Prague ในกรุงปราก และการแข่งขันอื่น ๆ มาบรรจุอยู่ในเครือข่ายดังกล่าวอย่างรวดเร็ว
# Target: With roots in Barcelona's Running Tours Barcelona and Copenhagen's Running Copenhagen, it was quickly joined by Running Tours Prague based in Prague and others.
# Translated: Because it is based on the Running Tours Barcelona in the city of Barcelona and the Running Copenhagen in the city of Copenhagen, it has led the Running Tours Prague in Prague and other competitions are packed in such a network quickly.
#
# Pair 54
# Source: 2 ใน 3 ของชาวเวเนซุเอลาที่ทำงานทำงานในภาคบริการ เกือบ 1 ใน 4 ทำงานในภาคอุตสาหกรรม และ 1 ใน 5 ทำงานในภาคเกษตรกรรม
# Target: Two thirds of Venezuelans who work do so in the service sector, nearly a quarter work in industry and a fifth work in agriculture.
# Translated: 2 in 3 of Venezuelans who work in the service sector. Nearly 1 in 4 work in the industry and 1 in 5 work in the agriculture sector.
#
# Pair 55
# Source: ก่อนที่ชาวสเปนจะมาที่นี่ในศตวรรษที่ 16 ตอนเหนือของชิลีอยู่ภายใต้การปกครองของจักรวรรดิอินคา ส่วนชนพื้นเมืองอาเรากานิอา (ชาวมาปูเช) อาศัยอยู่ในตอนกลางและตอนใต้ของชิลี
# Target: Before the Spanish arrived in the 16th century, northern Chile was under Inca rule while the indigenous Araucanians (Mapuche) inhabited central and southern Chile.
# Translated: Before the Spanish arrived here in the 16th century, the north of Chile was under the domination of the Inca Empire. The indigenous population of Aragon (Mapuches) lived in the middle and south of Chile.
#
# Pair 56
# Source: แคปซูลจะดูเหมือนดาวตกที่กำลังพุ่งข้ามฟากฟ้าอย่างมาก
# Target: The capsule will look much like a shooting star going across the sky.
# Translated: The capsule will look like a landing star that is travelling greatly.
#
# Pair 57
# Source: ประมาณสิบนาทีก่อนถึงเวลาลงจอด เครื่องบินลำดังกล่าวหายไปเมื่อเข้าใกล้จุดหมายครั้งที่สอง
# Target: About ten minutes before it was due to land from its second approach it disapeared.
# Translated: Approximately ten minutes before the landing time. The aircraft disappeared when it approached the second destination.
#
# Pair 58
# Source: โดยทั่วไปแล้ว วีซ่านักเรียนจะมีข้อกำหนดและขั้นตอนการสมัครที่แตกต่างจากวีซ่านักท่องเที่ยวหรือวีซ่าธุรกิจแบบปกติ
# Target: Student visas generally have different requirements and application procedures from normal tourist or business visas.
# Translated: Generally, the student visa will have different requirements and application procedures than the regular tourist visa or business visa.
#
# Pair 59
# Source: การออกแบบเชิงโต้ตอบจำเป็นต้องให้ส่วนประกอบต่าง ๆ ของโปรเจ็กต์เชื่อมต่อกัน แต่ก็ใช้การได้ในฐานะเอนทิตีที่แยกต่างหากด้วยเช่นกัน
# Target: Interactive design requires that components of a project connect to each other, but also make sense as a separate entity.
# Translated: The interactive design requires the different components of the project to connect to each other, but it also uses the capacity as a separate antenna.
#
# Pair 60
# Source: มิตต์ รอมนี่ย์ (Mitt Romney) อดีตผู้ว่าการรัฐแมสซาชูเซตส์ชนะการเลือกตั้งขั้นต้นจากการลงชิงตำแหน่งประธานาธิบดีในนามพรรครีพับลิกันจากรัฐฟลอริดาเมื่อวันอังคารที่ผ่านมา ด้วยคะแนนเสียงมากกว่าร้อยละ 46
# Target: Former Massachusetts governor Mitt Romney won the Florida Republican Party presidential primary election on Tuesday with over 46 percent of the vote.
# Translated: Mitt Romney, former president of Massachusetts, won the preliminary election after the presidential defeat on behalf of the Democratic Party of Florida last Tuesday, with over 46 percent of votes.
#
# Pair 61
# Source: การบังคับโดรนให้บินใกล้ท่าอากาศยานหรือในฝูงชนแทบจะเป็นความคิดที่แย่อยู่เสมอ แม้ว่าการทำเช่นนี้จะไม่ผิดกฎหมายในพื้นที่ของคุณก็ตาม
# Target: Flying a drone near an airport or over a crowd is almost always a bad idea, even if it's not illegal in your area.
# Translated: Forcing drones to fly near the airport or in the crowd is almost always a bad idea. Even though doing so is not illegal in your area.
#
# Pair 62
# Source: หากคุณต้องการบินรอบโลกในซีกโลกใต้อย่างสมบูรณ์ ตัวเลือกเที่ยวบินและจุดหมายปลายทางมีจำกัดเนื่องจากไม่มีเส้นทางที่ข้ามมหาสมุทร
# Target: If you want to fly around the world completely in the Southern Hemisphere, the choice of flights and destinations is limited due to the lack of transoceanic routes.
# Translated: If you want to fly around the world in the whole world, the flight options and destinations are limited because there are no transit routes.
#
# Pair 63
# Source: เซลล์เป็นหน่วยโครงสร้างที่มีหน้าที่ที่เล็กที่สุดของสิ่งมีชีวิต
# Target: A cell is the smallest structural and functional unit of a living (things) organism.
# Translated: Cell is a structural unit with the smallest function of an organism.
#
# Pair 64
# Source: แนวคิดก็คือ ทุกประเทศในยุโรปต้องพยายามป้องกันไม่ให้ชาติใดชาติหนึ่งมีอำนาจเกินไป และด้วยเหตุนั้นรัฐบาลของชาติต่าง ๆ จึงมักสับเปลี่ยนพันธมิตรเพื่อรักษาสมดุลเอาไว้
# Target: The concept was that all European nations had to seek to prevent one nation from becoming powerful, and thus national governments often changed their alliances in order to maintain the balance.
# Translated: The idea is that every country in Europe must strive to prevent any nation from having excessive power. And with the hurt, the governments of different nations are always changing allies to maintain balance.
#
# Pair 65
# Source: เมืองนี้จะเป็นเมืองแรกในยุโรปตะวันออกเฉียงใต้ที่จัด CowParade ซึ่งเป็นงานศิลปะสาธารณะที่ใหญ่ที่สุดในโลก โดยจะจัดขึ้นในช่วงระหว่างเดือนมิถุนายนจนถึงสิงหาคมปีนี้
# Target: The city will be the first in southeastern Europe to host CowParade, the world's largest public art event, between June and August this year.
# Translated: This city will be the first city in Southeast Europe to host CowParade, the largest public art event in the world. It will be held between June and August this year.
#
# Pair 66
# Source: สเติร์นส์กำลังสืบสวนว่ามีการใช้ภาษีเพื่อสนับสนุนการทำแท้งผ่านองค์กร Planned Parenthood หรือไม่ ขณะที่สวมบทบาทประธานคณะอนุกรรมการกำกับดูแลและสืบสวน ซึ่งอยู่ภายใต้คณะกรรมาธิการพลังงานและการพาณิชย์
# Target: Stearns is investigating whether taxes are used to fund abortions through Planned Parenthood in his role as chairman of the Oversight and Investigations Subcommittee, which is under the umbrella of the House Energy and Commerce Committee.
# Translated: Sturns is investigating whether tax is used to support interference through Planned Parenthood organizations or not. As he plays the role of Chairman of the Board of Supervisory and Investigative, which is under the Board of Energy and Commerce.
#
# Pair 67
# Source: ในปี พ.ศ. 2520 ดร.ดามาเดียนได้สร้างเครื่องสแกน MRI แบบ "ทั้งตัว" เป็นเครื่องแรก โดยเรียกมันว่า "เจ้าทรหดอดทน"
# Target: In 1977, Dr. Damadian completed the construction of the first “whole-body” MRI scanner, which he called the ”Indomitable”.
# Translated: In the year 2520 AD, D.D.D. created a "total" MRI scanner as the first machine, calling it "tolerant earthquake".
#
# Pair 68
# Source: มีการเตรียมการที่จะนำทั้งกอล์ฟและรักบี้กลับไปแข่งขันในกีฬาโอลิมปิก
# Target: Both golf and rugby are set to return to the Olympic Games.
# Translated: There is a preparation to bring both golf and lovers back to the Olympic Games.
#
# Pair 69
# Source: นายพล James Ewing จะนำทหาร 700 นายข้ามแม่น้ำที่ Trenton Ferry เข้ายึดสะพานข้ามลำห้วย Assunpink และป้องกันไม่ให้กองทหารข้าศึกหลบหนี
# Target: General James Ewing would take 700 militia across the river at Trenton Ferry, seize the bridge over the Assunpink Creek and prevent any enemy troops from escaping.
# Translated: Mr. James Ewing will lead 700 soldiers over the river to Trenton Ferry, climb the bridge over the Assunpink cave and prevent the army from escaping.
#
# Pair 70
# Source: สัตว์เกิดขึ้นจากเซลล์จำนวนมาก พวกมันกินสิ่งต่าง ๆ และย่อยสิ่งเหล่านั้นภายในร่างกาย สัตว์ส่วนใหญ่เคลื่อนไหวได้
# Target: Animals are made of many cells. They eat things and digest them inside. Most animals can move.
# Translated: Animals are formed from a lot of cells. They eat things and put them inside the body. The majority of animals are moving.
#
# Pair 71
# Source: นับตั้งแต่ก่อตั้งขึ้นมา The Onion ได้กลายเป็นอาณาจักรข่าวล้อเลียนที่แท้จริง โดยมีทั้งฉบับตีพิมพ์ เว็บไซต์ที่ดึงดูดผู้เข้าชมได้ถึง 5,000,000 คนในเดือนตุลาคม นอกจากนี้ยังมีโฆษณาส่วนบุคคล เครือข่ายข่าว 24 ชั่วโมง พอดแคสต์ และแผนที่โลกชื่อว่า Our Dumb World ที่เพิ่งเปิดตัวไปเมื่อไม่นานมานี้
# Target: Since its inception, The Onion has become a veritable news parody empire, with a print edition, a website that drew 5,000,000 unique visitors in the month of October, personal ads, a 24 hour news network, podcasts, and a recently launched world atlas called Our Dumb World.
# Translated: Since its establishment, The Onion has become a genuine news kingdom. The site has been published by a total of 5,000,000 visitors in October. It has also received personal advertising, 24-hour news networks, postcasts, and a world map called Our Dumb World, which has just been launched in recent years.
#
# Pair 72
# Source: พระชาวเยอรมันบางรูปปรารถนาที่จะให้พระเจ้าใกล้ชิดชาวพื้นเมืองมากขึ้นจึงได้คิดค้นภาษาเอสโตเนียขึ้นมา
# Target: Some German monks wanted to bring God closer to the native people, so they invented the Estonian literal language.
# Translated: Some Germans wanted to bring God closer to the native people, so they invented Estonian.
#
# Pair 73
# Source: เอกวาดอร์มีข้อกำหนดให้พลเมืองคิวบาต้องได้รับหนังสือเชิญจึงจะสามารถเดินทางข้ามเข้าสู่เขตแดนเอกวาดอร์ผ่านสนามบินนานาชาติหรือด่านตรวจคนเข้าเมืองที่พรมแดน
# Target: Ecuador requires that Cuban citizens receive an invitation letter prior to entering Ecuador through international airports or frontier admission points.
# Translated: Ecuador requires the citizens of Cuba to receive an invitation letter so they can travel through the Ecuador border through the international airport or the border crossing of immigrants.
#
# Pair 74
# Source: การสื่อสารทางเดียวช่วยให้มีเวลาใช้ความคิดก่อนที่จะโต้ตอบผู้อื่น
# Target: Asynchronous communication encourages time for reflection and reaction to others.
# Translated: Single communication allows you to take time to think before interacting with others.
#
# Pair 75
# Source: เนื่องจากการโทรถูกส่งผ่านอินเทอร์เน็ต คุณจึงไม่จำเป็นต้องใช้บริษัทโทรศัพท์ที่ตั้งอยู่ในที่ที่อาศัยหรือที่ที่คุณเดินทางไป
# Target: Because calls are routed over the Internet, you do not need to use a phone company located where you live or where you travel.
# Translated: Because the calls are transmitted through the Internet, you do not need to use the telephone company located in the place where you live or where you travel.
#
# Pair 76
# Source: เรือสำราญมากกว่า 60 ลำล่องไปตามน่านน้ำในกาลาปากอส โดยมีขนาดบรรทุกผู้โดยสารตั้งแต่ 8 ถึง 100 คน
# Target: Over 60 cruise ships ply the Galapagos waters - ranging in size from 8 to 100 passengers.
# Translated: More than 60 ships passed along the water valley in Galapagos. The size of the passenger cargo ranges from 8 to 100 people.
#
# Pair 77
# Source: ข้อเท็จจริงที่ว่าหมู่บ้านจำนวนมากอยู่ห่างไกลแค่ไหน ทำให้คุณไม่สามารถพบเจอสถานบันเทิงยามค่ำคืนจำนวนมากโดยไม่เดินทางไปยังแอลบูเคอร์คีหรือซานตาเฟ่
# Target: Given how remote many of the pueblos are, you won't be able to find a significant amount of nightlife without traveling to Albuquerque or Santa Fe.
# Translated: The fact of how many villages are far away makes it impossible to find a lot of night entertainment places without traveling to Albuquerque or Santa Fe.
#
# Pair 78
# Source: นอกจากนี้ ACMA ยังพบว่าแม้จะมีการสตรีมวิดีโอทางอินเทอร์เน็ต แต่บิกบราเธอร์ก็ไม่ได้ละเมิดกฎหมายการเซ็นเซอร์เนื้อหาออนไลน์ เนื่องจากสื่อดังกล่าวไม่ได้ถูกจัดเก็บไว้ในเว็บไซต์ของบิกบราเธอร์
# Target: The ACMA also found that despite the video being streamed on the Internet, Big Brother had not breached online content censorship laws as the media had not been stored on Big Brother's website.
# Translated: Furthermore, ACMA also found that even though there was internet video streaming, the Big Brother did not violate the online content censorship laws. Because such media was not stored on the Big Brother’s website.
#
# Pair 79
# Source: หากคุณรักความเสี่ยงมากกว่านี้ ให้ใช้โอกาสนี้คั้นน้ำผลไม้หรือปั่นสมูทตี้ดูสิ:
# Target: If you're feeling more adventurous, take the opportunity to juice or blend up some smoothies:
# Translated: If you love the risk more than this, take this opportunity, cut fruit juice or mouths, look at:
#
# Pair 80
# Source: มันช่วยให้นักเรียนสามารถทำงานได้ตามอัตราความเร็วของตนเอง รวมทั้งสามารถควบคุมอัตราเร็วของการให้ข้อมูลเชิงสอนได้
# Target: It allows students the ability to work at their own pace and control the pace of instructional information.
# Translated: It allows students to work according to their own speed rates. It can also control the speed of teaching information.
#
# Pair 81
# Source: กรอบแว่นตาแบรนด์เนมระดับไฮเอนด์ที่มีขายอยู่ในพื้นที่เช่นนั้นอาจมีปัญหาได้สองอย่าง นั่นก็คือ บางกรอบอาจเป็นของปลอม ส่วนกรอบที่ได้มีการนำเข้ามาจริงก็อาจมีราคาแพงกว่าที่มีขายอยู่ในประเทศ
# Target: High-end brand-name frames available in such areas may have two problems; some may be knock-offs, and the real imported ones may be more expensive than at home.
# Translated: Brands of high-end branding glasses that are sold in such a area may have two problems. That is, some frame may be false. The actual imported frame may be more expensive than it is sold in the country.
#
# Pair 82
# Source: อะตอมถือได้ว่าเป็นโครงสร้างพื้นฐานอย่างหนึ่งของทุกสสาร
# Target: The atom can be considered to be one of the fundamental building blocks of all matter.
# Translated: Atom is considered to be one of the basic structures of each substance.
#
# Pair 83
# Source: อาการสมาธิสั้น "คือกลุ่มอาการทางระบบประสาทซึ่งอาการที่พบเป็นประจำ ได้แก่ หุนหันพลันแล่น วอกแวกง่าย อยู่ไม่นิ่ง หรือมีพลังงานมากเกิน"
# Target: Attention Deficit Disorder "is a neurological syndrome whose classic defining triad of symptoms including impulsivity, distractibility, and hyperactivity or excess energy".
# Translated: Short meditation symptoms "is a group of nervous-system symptoms with regular symptoms, such as sudden, sudden, simple, low, or over-energy."
#
# Pair 84
# Source: เป็นที่เล่าขานกันมาว่าในปี ค.ศ. 1649 ท่านซับดรุง งาวัง นัมเยล (Zhabdrung Ngawang Namgyel) ได้สร้างป้อมปราการแห่งนี้ขึ้นเพื่อเป็นอนุสรณ์สถานแห่งชัยชนะของตนในการต่อต้านกองกำลังทิเบต-มองโกล
# Target: It is said that in 1649, Zhabdrung Ngawang Namgyel created the fortress to commemorate his victory against the Tibetan-Mongol forces.
# Translated: It is that in 1649 Zhabdrung Ngawang Namgyel built this castle as a memorial of his victory against the Tibetan-Mongol forces.
#
# Pair 85
# Source: บริษัทสื่อต่าง ๆ เหล่านี้มักไม่บอกจุดประสงค์ที่แท้จริงของการทำเช่นนี้ โดยอ้างว่าเป็นการ "ป้องกันการละเมิดลิขสิทธิ์"
# Target: The media companies routinely lie about the purpose of this, claiming that it is to "prevent piracy".
# Translated: These various media companies often don’t tell the real purpose of doing so by claiming to be a “protection of copyright infringement.”
#
# Pair 86
# Source: กีฬาชนิดนี้เล่นในรูปแบบการดวลเป็นสำคัญ โดยที่นักฟันดาบคนหนึ่งดวลกับนักฟันดาบอีกคนหนึ่ง
# Target: The sport is primarily played in a duel format, one fencer dueling another.
# Translated: This kind of sport plays in the form of the massage is important. By the one dentist to the other dentist.
#
# Pair 87
# Source: ในหลายประเทศที่มีกฎหมายดังกล่าว โรงแรมในท้องถิ่นจะจัดการเรื่องการลงทะเบียน (อย่าลืมสอบถาม)
# Target: In many countries with such a law, local hotels will handle the registration (make sure to ask).
# Translated: In many countries with such laws, local hotels will handle registration (do not forget to ask)
#
# Pair 88
# Source: แผนการของอเมริกาอาศัยการออกโจมตีพร้อมกันจากสามทิศทาง
# Target: The American plan relied on launching coordinated attacks from three different directions.
# Translated: U.S. plans to attack at the same time from three directions.
#
# Pair 89
# Source: สิ่งปลูกสร้างหลายแห่งค่อนข้างสวยงามน่ามอง และทิวทัศน์จากตึกสูงหรือจากตำแหน่งหน้าต่างที่จัดวางไว้อย่างชาญฉลาดก็อาจเป็นความสวยงามที่มองเห็นได้
# Target: Many buildings are quite beautiful to look at and the view from a tall building or from a cleverly-positioned window can be a beauty to behold.
# Translated: Many buildings are pretty beautiful and visible. And a view from a height or from a smartly placed window position may be a visible beauty.
#
# Pair 90
# Source: บรรยากาศมืดสลัวในบริเวณวัดและทิวทัศน์เหนือทะเลสาบโตนเลสาบทำให้การปีนขึ้นสู่เนินเขาเป็นเรื่องที่คุ้มค่า
# Target: The gloomy atmosphere of the temple and the view over the Tonle Sap lake make the climb to the hill worthwhile.
# Translated: The dark atmosphere in the area of the temple and the views on the north of the Boton Lake make climbing to the hill worth it.
#
# Pair 91
# Source: งานรวมศิลปินครั้งนี้ที่ยังเป็นส่วนหนึ่งของแคมเปญที่จัดโดยศาลาว่าการกรุงบูคาเรสต์ ในการพยายามสร้างภาพลักษณ์ของเมืองหลวงของโรมาเนียให้เป็นมหานครที่มีความสร้างสรรค์และมีสีสันอีกครั้ง
# Target: The artistic event is also part of a campaign by the Bucharest City Hall that seeks to relaunch the image of the Romanian capital as a creative and colourful metropolis.
# Translated: This group of artists is also part of a campaign organized by the devil as the Bucharest. In an attempt to create the image of the capital of Romania, it becomes a creative and colorful city again.
#
# Pair 92
# Source: เด็กเหล่านี้มักเผชิญกับปัญหามากมายเพราะพวกเขา "เข้าไปพัวพันกับพฤติกรรมเสี่ยง การต่อยตี และท้าทายเจ้าหน้าที่" เพื่อกระตุ้นสมองของตนเอง เนื่องจากสมองของพวกเขาไม่สามารถถูกกระตุ้นด้วยวิธีปกติได้
# Target: These children tend to get into a lot of trouble, because they "engage in risky behaviors, get into fights, and challenge authority" in order to stimulate their brain, since their brain can not be stimulated by normal methods.
# Translated: These children are often faced with a lot of problems because they are "in the middle of risk behavior, struggle, and challenge staff" to stimulate their own brains. Because their brains cannot be stimulated in a normal way.
#
# Pair 93
# Source: มนุษย์ได้ผลิตและใช้เลนส์เพื่อประโยชน์ในการขยายภาพมานานหลายพันปีแล้ว
# Target: Humans have been making and using lenses for magnification for thousands and thousands of years.
# Translated: Humans have produced and used lenses for the benefit of image expansion for thousands of years.
#
# Pair 94
# Source: การขว้างบูมเมอแรงคือทักษะยอดนิยมที่นักท่องเที่ยวหลายต่อหลายคนต้องการมี
# Target: Boomerang throwing is a popular skill that many tourists want to acquire.
# Translated: Strong booming is a popular skill that many tourists want to have.
#
# Pair 95
# Source: กีฬาฟันดาบสมัยใหม่มีการแข่งขันกันในหลายระดับ ตั้งแต่ระดับนักศึกษามหาวิทยาลัยไปจนถึงระดับมืออาชีพและในกีฬาโอลิมปิก
# Target: The modern sport of fencing is played at many levels, from students learning at a university to professional and Olympic competition.
# Translated: Modern shoe sports are competing on several levels. From college level to professional level and in the Olympic sports.
#
# Pair 96
# Source: เขาเสียชีวิตที่โอซาก้าในวันอังคาร
# Target: He died in Osaka on Tuesday.
# Translated: He died in Osaka on Tuesday.
#
# Pair 97
# Source: มีการจัดให้มีการสอบสวนเพื่อสืบสวน
# Target: An inquiry was established to investigate.
# Translated: There is an investigation to explore.
#
# Pair 98
# Source: โรคติดต่อคือโรคชนิดหนึ่งที่แพร่เชื้อได้โดยง่ายเมื่ออยู่ใกล้ชิดกับผู้ติดเชื้อ
# Target: A contagious disease is a disease which is easily transmitted by being in the vicinity of an infected person.
# Translated: Contact disease is a type of disease that is easily transmitted when close to an infected person.
#
# Pair 99
# Source: ก๊าซจะเบาบางลงเมื่อเราเคลื่อนที่ไกลออกมาจากศูนย์กลางของดวงอาทิตย์
# Target: The gas becomes thinner as you go farther from the center of the Sun.
# Translated: Gas becomes thin when we move far from the center of the sun.
#
# Pair 100
# Source: ปกติแล้วกิจกรรมเหล่านี้จะกินเวลาระหว่างสามถึงหกเดือนและจัดขึ้นในพื้นที่ซึ่งมีขนาดไม่เกิน 50 เฮกตาร์
# Target: These events normally last anywhere between three and six months, and are held on sites no smaller than 50 hectares.
# Translated: Normally, these activities take a period of three to six months and take place in an area of no more than 50 hectares.

# %% [markdown]
# **2.3 MBART-50**

# %%
# Import necessary libraries for MBART-50
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# %%
# load a pre-trained model and tokenizer for the MBART-50 model
mbart_model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
mbart_tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# %%
# Function for translation (Thai to English)
def mbart_translate_sentence(sentence, model, tokenizer):
    tokenizer.src_lang = "th_TH"
    inputs = tokenizer(sentence, return_tensors="pt")
    outputs = model.generate(**inputs, forced_bos_token_id=tokenizer.lang_code_to_id["en_XX"])
    translated_sentence = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    return translated_sentence

# Define the list to store the length of the translated sentences
mbart_translated_sentences_list = []

# Perform translations on the 100 sentence pairs
for idx, (source_language, target_language) in enumerate(selected_pairs):
    # Translate from source to target
    mbart_translated_sentence = mbart_translate_sentence(source_language, mbart_model, mbart_tokenizer)

    # Add the sentence into the list
    mbart_translated_sentences_list.append(mbart_translated_sentence)

    # Display the results
    print(f"Pair {idx + 1}")
    print(f"Source: {source_language}")
    print(f"Target: {target_language}")
    print(f"Translated: {mbart_translated_sentence}\n")
# Out:
# Pair 1
# Source: นี่ไม่ใช่กลุ่มอาการขาดทักษะด้านการเรียนรู้ แต่เป็นความผิดปกติทางการเรียนรู้ โรคนี้ "ส่งผลกระทบต่อเด็กร้อยละ 3 ถึง 5 ซึ่งอาจเป็นเด็กอเมริกันมากถึง 2 ล้านคน"
# Target: It is not a learning disability, it is a learning disorder; it "affects 3 to 5 percent of all children, perhaps as many as 2 million American children".
# Translated: We're talking about skills shortages, diseases, diseases that affect three to five percent of Americans, maybe two to two percent of Americans.
#
# Pair 2
# Source: ผู้ที่ไม่คุ้นเคยกับศัพท์เฉพาะทางการแพทย์คิดว่า คำว่าติดเชื้อและโรคติดต่อนั้นมีความหมายต่างกัน
# Target: For those unfamiliar with medical jargon, the words infectious and contagious have distinct meanings.
# Translated: It used to be synonymous with specialized medicines, and diseases were synonymous.
#
# Pair 3
# Source: เขาตั้งข้อสังเกตว่า งานวิจัยบางชิ้นชี้ให้เห็นว่าโรคนี้จำเป็นต้องมีอันตรายน้อยลงก่อนที่มันจะแพร่ระบาดไปทั่วโลก
# Target: Some studies suggest that the disease must become less lethal before it can cause a global epidemic, he noted.
# Translated: He looked at some of the research to see if there was a disease, if there was a danger, if there was an epidemic.
#
# Pair 4
# Source: นักวิทยาศาสตร์รายอื่น ๆ แย้งว่าพืชเหล่านี้มีพิษร้ายแรง จึงไม่น่าเป็นไปได้ที่จะมีไดโนเสาร์ตัวใดกินพวกมันได้ แม้ว่าในปัจจุบันสลอธและสัตว์อื่น ๆ เช่น นกแก้ว (ลูกหลานของไดโนเสาร์) จะสามารถกินใบไม้หรือผลไม้มีพิษได้ก็ตาม
# Target: Other scientists argue that these plants are very poisonous so it is unlikely that any dinosaur ate them, even though today the sloth and other animals like the parrot (a descendant of the dinosaurs) can eat poisonous leaves or fruit.
# Translated: The phytoplankton was a highly toxic plant, so any dinosaur that had them could eat them, and now the salmon and the birds could eat the leaves or the toxic plants.
#
# Pair 5
# Source: ถึงแม้คุณอาจเคยได้ยินชาวกรีนแลนด์ใช้คำนี้ แต่ชาวต่างชาติไม่ควรใช้
# Target: While you may hear the word used by Greenlandic Natives, its use should be avoided by foreigners.
# Translated: You may have heard of the Greek word for word, the Greek word for word.
#
# Pair 6
# Source: นอกจากนี้ยังไม่มีข้อกำหนดว่าคุณจะต้องwfhรับหมายเลขท้องถิ่นจากชุมชนที่คุณอาศัยอยู่ คุณสามารถรับการเชื่อมต่ออินเทอร์เน็ตผ่านดาวเทียมในชิกเก้นซึ่งเป็นเมืองที่ห่างไกลความเจริญในอลาสก้า และเลือกหมายเลขที่บ่งบอกว่าคุณอยู่ในแอริโซนาที่มีแสงแดดจ้า
# Target: There is also no requirement that you obtain a local number from the community in which you live; you can obtain a satellite Internet connection in the wilds of Chicken, Alaska and select a number which claims you're in sunny Arizona.
# Translated: You can get a city number from the community, you can get a satellite number from Chicago, you can get a city number from Las Vegas, and you can get a city number from Arizona for sunlight.
#
# Pair 7
# Source: โฮสเทลแห่งหนึ่งถล่มในเมกกะซึ่งเป็นเมืองศักดิ์สิทธิ์ของศาสนาอิสลามเมื่อเวลาประมาณ 10 นาฬิกาของเช้าวันนี้ตามเวลาท้องถิ่น
# Target: A hostel collapsed in Mecca, the holy city of Islam at about 10 o'clock this morning local time.
# Translated: Hostels in the Islamic city of Meghalaya, about 10 clock in the clock in the Islamic city.
#
# Pair 8
# Source: ถึงอย่างนั้นก็คาดได้เลยว่าจะต้องหายใจหอบ และต้องระวังในส่วนที่ลาดชันกว่าโดยเฉพาะเมื่อเปียก เนื่องจากอาจเกิดอันตรายได้อย่างรวดเร็ว
# Target: That said, expect to be out of breath, and take care in the steeper portions, especially when wet, as it can become dangerous quickly.
# Translated: It's important to be aware of the risks associated with breathing inhalation and, in particular, of the risks associated with lung cancer.
#
# Pair 9
# Source: ความเชื่อทางไสยศาสตร์สามารถจำแนกออกจากรูปแบบความเชื่อทางศาสนาและการบูชาอื่น ๆ ด้วยลักษณะที่เน้นในเรื่องประสบการณ์ตรงของการตระหนักรู้ในภาวะต่าง ๆ โดยเฉพาะภาวะของความรู้สึกสงบ การหยั่งรู้ ความผาสุก หรือแม้แต่ความปิติยินดีเหลือล้น
# Target: Mysticism can be distinguished from other forms of religious belief and worship by its emphasis on the direct personal experience of a unique state of consciousness, particularly those of a peaceful, insightful, blissful, or even ecstatic character.
# Translated: Religious teachings can distinguish between religious teachings and worships, the specific nature of religious teachings from the consciousness of a state of affairs, in particular, the state of peace, of mind, of appetite, or of pleasure.
#
# Pair 10
# Source: สัตว์ป่าอาจขี้อายหรือก้าวร้าวก็ได้ สภาพแวดล้อมอาจเย็น ร้อน หรือยากลำบาก
# Target: Wild animals might either be shy or aggressive. The environment might be cold, hot, or otherwise hostile.
# Translated: It can be embarrassing or it can be awkward or it can be awkward or it can be difficult.
#
# Pair 11
# Source: ปีเตอร์ เลนซ์ นักแข่งรถมอเตอร์ไซค์วัย 13 ปี เสียชีวิตหลังจากอยู่ในอุบัติเหตุรถชนกันที่อินเดียนาโปลิสมอเตอร์สปีดเวย์
# Target: Peter Lenz, a 13-year-old motorcycle racer, has died after being involved in a crash at the Indianapolis Motor Speedway.
# Translated: A 13-year-old driver died in a car accident in Indianapolis, Indiana.
#
# Pair 12
# Source: ข่าวแพร่สะพัดในชุมชนเรดเลคในวันนี้ว่ามีนักเรียนอีกคนถูกจับุมจากการก่อเหตุกราดยิงในโรงเรียนเมื่อวันที่ 21 มีนาคม ขณะที่งานศพของ Jeff Weise และเหยื่อ 3 ใน 9 คนดำเนินอยู่
# Target: News spread in the Red Lake community today as funerals for Jeff Weise and three of the nine victims were held that another student was arrested in connection with the school shootings of March 21.
# Translated: The protests raged in Red Lake County, where another student was caught in a school shooting on March 21, the funeral of Jeff Weise, and three out of nine people were executed.
#
# Pair 13
# Source: การปฏิบัติตามหลักการโภชนาการที่เหมาะสมแค่อย่างเดียวไม่สามารถช่วยให้เกิดสมรรถภาพระดับดีเลิศได้ แต่อาจส่งผลอย่างมากต่อสุขภาพโดยรวมของนักกีฬารุ่นเยาว์
# Target: Proper nutritional practices alone cannot generate elite performances, but they can significantly affect young athletes' overall wellness.
# Translated: Applying the principles of nutrition for excellence in performance could contribute to the overall health of young athletes.
#
# Pair 14
# Source: พายุลูกนี้อยู่ห่างจากเมืองไมอามี่ในรัฐฟลอริดาราว 3,000 ไมล์โดยมีแรงลมสูงสุดอยู่ที่ 40 ไมล์/ชม. (64 กม./ชม.)
# Target: The storm, located approximately 3,000 miles from Miami, Florida, has maximum sustained winds of 40 mph (64 kph).
# Translated: A hurricane hit the city of Miami, Florida, 3,000 times its peak winds of 40 kilometers an hour.
#
# Pair 15
# Source: ทฤษฎีนี้ย้อนแย้งกับคำกล่าวอ้างที่ว่า ดวงจันทร์นั้นไม่มีความเคลื่อนไหวทางธรณีวิทยาเลยแม้แต่น้อย
# Target: This theory contradicts the claim that the moon is completely devoid of geologic activity.
# Translated: The theory of geology and the words of geology, of geology, of geology.
#
# Pair 16
# Source: การเข้าวัดจะต้องใช้บัตร Angkor Pass ดังนั้นเมื่อจะเดินทางไปโตนเลสาบ โปรดอย่าลืมนำหนังสือเดินทางติดตัวไปด้วย
# Target: The Angkor Pass is needed to enter the temple so do not forget to bring your passport along when heading to Tonle Sap.
# Translated: If you want to take an Angkor Pass, or if you want to go to a picnic, please bring your passport with you.
#
# Pair 17
# Source: เมื่อประชากรทั้งหมดมีลักษณะทางพันธุกรรมอย่างหนึ่งที่เหมือนกันก็จะถูกเรียกว่าโมโนมอร์ฟิก
# Target: When all individuals in a population are identical with regard to a particular phenotypic trait they are known as monomorphic.
# Translated: The populations are genetically identical and are affected by the physics of their genomes.
#
# Pair 18
# Source: ส่วนใหญ่แล้วจะเกิดขึ้นกับคนที่ทำงานเกี่ยวข้องกับสัตว์ปีกมากกว่า แต่นักดูนกก็มีความเสี่ยงเช่นกัน
# Target: Most have involved people who work with poultry, but there is also some risk to birdwatchers.
# Translated: We're going to work with the industry, we're going to work with the wing industry, we're going to work with the bird watching industry, we're going to work with the industry.
#
# Pair 19
# Source: แม้คุณอาจจะคิดว่าเป็นเรื่องดีที่จะใช้บริการสายการบินเดิม ๆ ที่คุณบินด้วยบ่อยที่สุด แต่ควรทราบไว้ว่าสิทธิพิเศษที่แต่ละสายการบินมอบให้มักจะแตกต่างกัน และคะแนนไมล์สะสมของสายการบินอื่นในกลุ่มพันธมิตรเดียวกันอาจให้ผลตอบแทนที่เป็นประโยชน์มากกว่า
# Target: Although you may think it is intuitive to join the airline you fly most, you should be aware that privileges offered are often different and frequent flyer points may be more generous under a different airline in the same alliance.
# Translated: Maybe you want to know about the best practices of the old airlines, the airlines that have the special rights to provide services, and the accumulated scores of the airlines in the same alliance can be a reward for those practices.
#
# Pair 20
# Source: หินบางชนิดที่หาได้ยากมากในโลก มีการขายตั้งแต่ราคา 11,000 ดอลลาร์สหรัฐไปจนถึง 22,500 ดอลลาร์สหรัฐต่อออนซ์ ซึ่งแพงกว่าราคาทองคำราวสิบเท่า
# Target: Some of the rocks, which are very rare on Earth, are being sold from US$11,000 to $22,500 per ounce, which is about ten times more than the cost of gold.
# Translated: Some of the world's most precious rocks have sold for as much as 11,000 U.S. dollars, up to 22,500 U.S. dollars, expensive gold for 10 cents.
#
# Pair 21
# Source: เนื่องจากด้านล่างของใบมีดโค้งเล็กน้อย เมื่อใบมีดเอียงไปด้านใดด้านหนึ่ง ขอบที่สัมผัสกับน้ำแข็งจึงโค้งเช่นกัน
# Target: Because the bottom of the blade is slightly curved, as the blade tilts to one side or the other, the edge which is in contact with the ice also curves.
# Translated: The boundary of the leaf, the boundary of which is adjacent to the leaf, the boundary of the contact with the leaf, therefore the boundary.
#
# Pair 22
# Source: อย่างไรก็ตาม ในปัจจุบันศิลปินกราฟฟิตีที่ได้รับการยอมรับ มีงานอีเวนต์กราฟฟิตี และกำแพง สำหรับวาดภาพกราฟฟิตีที่ "ถูกกฎหมาย" ภาพวาดกราฟฟิตีในบริบทนี้มักคล้ายกับงานศิลปะมากกว่าป้ายที่อ่านไม่ออก
# Target: However, nowadays there are established graffiti artists, graffiti events and "legal" walls. Graffiti paintings in this context often resemble artworks rather than illegible tags.
# Translated: Nowadays, accepted graphic artists have works of graphic arts, and walls for legal graphic arts, graphic arts in the context of art are often excluded.
#
# Pair 23
# Source: การที่วาล์วเปิดทำให้แรงดันถูกปล่อยออกจากระบบ แล้วน้ำมันก็ไหลไปตามรางสู่ถังที่มีความจุ 55,000 บาร์เรล (2.3 ล้านแกลลอน)
# Target: The valves opening allowed a pressure release for the system and oil flowed on a pad to a tank that can hold 55,000 barrels (2.3 million gallons).
# Translated: The opening of the pressurized economy was driven out of the system by the flow of 55,000 gallons of gasoline into the bucket.
#
# Pair 24
# Source: ภาษาเสริมคือภาษาประดิษฐ์หรือภาษาที่สร้างขึ้นโดยมีวัตถุประสงค์เพื่ออำนวยความสะดวกในการสื่อสารระหว่างผู้คนที่อาจมีปัญหาในการสื่อสารหากไม่มีภาษานี้
# Target: Auxiliary languages are artificial or constructed languages created with the intent of facilitating communication between peoples who would otherwise have difficulty communicating.
# Translated: Auxiliary languages are languages, or languages with an auxiliary language that might be a problem if you're using a language.
#
# Pair 25
# Source: โบเบ็ก เกิดในซาเกร็บซึ่งเป็นเมืองหลวงของโครเอเชียและมีชื่อเสียงขึ้นมาขณะเล่นให้กับปาร์ติซานเบลเกรด
# Target: Born in the Croatian capital, Zagreb, Bobek gained fame while playing for Partizan Belgrade.
# Translated: Bobe was born in Zagreb, the capital city of Croatia, and he had a voice while he was in Bratislava.
#
# Pair 26
# Source: นักวิทยาศาสตร์ได้ค้นพบรูปแบบของเปลือกโลกที่เรียกว่า lobate scarp กระจัดกระจายอยู่ทั่วพื้นผิวดวงจันทร์ ซึ่งปรากฏว่าเป็นผลมาจากการที่ดวงจันทร์หดตัวช้ามาก
# Target: Scientists have discovered landforms littered across the moon's surface called lobate scarps that have apparently resulted from the moon's shrinking very slowly.
# Translated: The world's lobate scarp phenomenon has been disrupted by the spread of the sun's skin, resulting in a dramatic reduction in sunlight.
#
# Pair 27
# Source: ชูมัคเกอร์ซึ่งเกษียณในปี 2006 หลังจากที่คว้าแชมป์ฟอร์มูล่าวันไปเจ็ดครั้ง ต้องเข้ามาทำหน้าที่แทนเฟลิเป้ มาสซาซึ่งได้รับบาดเจ็บ
# Target: Schumacher who retired in 2006 after winning the Formula 1 championship seven times, was due to replace the injured Felipe Massa.
# Translated: She retired in 2006 from the World Health Organization on behalf of Falun Gong, Massachusetts.
#
# Pair 28
# Source: HK Management Inc. ซึ่งเป็นบริษัทจัดการของวงไม่ได้ให้เหตุผลเบื้องต้นตอนที่พวกเขายกเลิกในวันที่ 20 กันยายน แต่วันรุ่งขึ้นก็กล่าวโทษเหตุผลที่มีตรรกะต่าง ๆ
# Target: The band's management company, HK Management Inc., gave no initial reason when they canceled on September 20, but blamed logistical reasons by the next day.
# Translated: HK Management Inc., the parent company of the rationale movement, when they abolished the 20th of September as the day of rationale punishment.
#
# Pair 29
# Source: มีค่าธรรมเนียมเพิ่มเติมสำหรับการเดินทางโดยมีผู้โดยสารมากกว่า 2 คน ตัวเลือกนี้จึงอาจมีราคาแพงกว่าที่จำเป็น
# Target: There is a surcharge for having more than 2 passengers, so this option might be more expensive than necessary.
# Translated: There's an option for two-person travel, so the choice may be expensive.
#
# Pair 30
# Source: กลุ่มเต้นรำ Fire of Anatolia ของตุรกี ได้แสดงการเต้นรำชุด "Troy" เพื่อจบการแสดง
# Target: To finish, Turkish dance group Fire of Anatolia performed the show "Troy".
# Translated: Turkey's Fire of Anatolia performance of the "Troy" series ended.
#
# Pair 31
# Source: บุคคลที่มีส่วนเกี่ยวข้องมาหลายสิบปีช่วยให้เราชื่นชมจุดแข็งและความหลงใหลของตัวเอง พร้อมทั้งประเมินความยากลำบากและกระทั่งความล้มเหลวอย่างตรงไปตรงมาในขณะเดียวกัน
# Target: Individuals who had been involved for several decades helped us appreciate our strengths and passions while candidly assessing difficulties and even failures.
# Translated: For decades, people have been looking at our goals and our passions and assessing our difficulties and our failures in a very honest way.
#
# Pair 32
# Source: แอปแปลข้อความตามเวลาจริง - แอปพลิเคชั่นที่สามารถแปลข้อความทั้งส่วนจากภาษาหนึ่งเป็นอีกภาษาได้โดยอัตโนมัติ
# Target: Real-time text translator apps – applications that are capable of automatically translating whole segments of text from one language into another.
# Translated: Apple translates texts in real time — Apple automatically translates texts from one language into another.
#
# Pair 33
# Source: ในกรณีนี้ การนึกถึงตัวอย่างพฤติกรรมแบบผู้บริหารและผลลัพธ์ความสำเร็จที่ตามมาช่วยให้ผู้คนเปิดรับความเปลี่ยนแปลงและแนวทางใหม่ๆ สำหรับคริสตจักรในท้องถิ่น
# Target: In this instance, recalling previous instances of entrepreneurial behavior and resulting successes helped people to be open to new changes and new direction for the local church.
# Translated: In the case of the Church, the implications of the behavioral conventions and the religious conventions followed the opening up of the religious conventions and the religious guidelines for the church in the conventions.
#
# Pair 34
# Source: หลังจากเกิดเพลิงไหม้ ป้อมปราการได้รับการอนุรักษ์และปกป้อง และยังคงเป็นสถานที่ท่องเที่ยวที่น่าตื่นตาตื่นใจที่สุดแห่งหนึ่งของภูฏาน
# Target: After the fire, the fortress was preserved and protected, remaining to be one of Bhutan's most sensational attractions.
# Translated: After the fire, the government and industry protested, and continued to protest against the government of Bhutan.
#
# Pair 35
# Source: โรงแรมหรือเจ้าบ้านของคุณ (กรณีที่คุณพักในเกสต์เฮาส์หรือบ้านส่วนตัว) มักจะมี wifi หรือคอมพิวเตอร์ที่ต่อกับอินเทอร์เน็ต และทุกชุมชนจะมีร้านอินเทอร์เน็ตหรือบางที่ก็มี wifi สาธารณะ
# Target: Your hotel or hosts (if staying in a guesthouse or private home) will likely have wifi or an internet connected PC, and all settlements have an internet cafe or some location with public wifi.
# Translated: Your hotel, or your community, usually has a WiFi, or community with WiFi, and every community has a community with some public WiFi.
#
# Pair 36
# Source: Lodin ยังกล่าวอีกว่าเจ้าหน้าที่ตัดสินใจยกเลิกการเลือกตั้งซ้ำเพื่อเป็นการประหยัดค่าใช้จ่ายและป้องกันความเสี่ยงด้านความปลอดภัยของการเลือกตั้งอื่นให้กับชาวอัฟกานิสถาน
# Target: Lodin also said officials decided to cancel the runoff in order to save Afghans the expense and security risk of another election.
# Translated: Lodin also decided to abolish the economic and safety sanctions on the Afghan people.
#
# Pair 37
# Source: ในบางประเทศที่มีรัฐบาลกลาง เช่น สหรัฐอเมริกา และแคนาดา จะมีการเรียกเก็บภาษีเงินได้ทั้งในระดับรัฐบาลกลางและในระดับท้องถิ่น ด้วยเหตุนี้ อัตราและขั้นภาษีอาจแตกต่างกันไปในแต่ละภูมิภาค
# Target: In some federal countries, such as the United States and Canada, income tax is levied both at the federal level and at the local level, so the rates and brackets can vary from region to region.
# Translated: In some countries, the federal governments of the United States and Canada will have to charge taxes on the federal level and on the causes, and rates and taxes may go to the regional governments.
#
# Pair 38
# Source: โดยทั่วไปคุณจะต้องประกาศการให้ความช่วยเหลือของคุณ เดินไปตามท่าเรือ เข้าหาผู้คนที่กำลังทำความสะอาดเรือยอตช์ พยายามติดต่อกับกะลาสีเรือในบาร์ และอื่น ๆ
# Target: Basically you'll be putting up notices offering your help, pacing the docks, approaching people cleaning their yachts, trying to make contact with sailors in the bar, etc.
# Translated: You're going to announce your destination, you're going to go to the shipyard, you're going to look for a cleaner, you're going to try to get the paint on the ship, and so on.
#
# Pair 39
# Source: ผู้ประท้วงหวังจะรวบรวมรายชื่อผู้ร้องเรียนได้ถึง 1.2 ล้านรายชื่อเพื่อเสนอต่อสภาคองเกรสในเดือนพฤศจิกายน
# Target: Protesters hope to collect a petition of 1.2 million signatures to present to the National Congress in November.
# Translated: The protest hopes to collect 1.2 million views on Congressional proposals in May.
#
# Pair 40
# Source: ธารน้ำแข็งไม่จับตัวแข็งมากนัก แต่มันไหลลงไปตามภูเขา ซึ่งเป็นสาเหตุของรอยแตกและรอยแยกของน้ำแข็งบนภูเขา ซึ่งอาจจะถูกสะพานหิมะปกคลุมไว้
# Target: The glaciers are not stable, but flow down the mountain. This will cause cracks, crevasses, which may be obscured by snow bridges.
# Translated: The rainfall is so heavy that it flows down the mountains, causing cracks and fractures in the mountains, possibly covered by snow bridges.
#
# Pair 41
# Source: Cinque Terre ซึ่งหมายความว่าห้าดินแดน ประกอบด้วยหมู่บ้านชายฝั่งห้าหมู่บ้าน ได้แก่ Riomaggiore, Manarola, Corniglia, Vernazza และ Monterosso ซึ่งตั้งอยู่ในแคว้น Liguria ประเทศอิตาลี
# Target: Cinque Terre, which means Five Lands, comprises the five small coastal villages of Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso located in the Italian region of Liguria.
# Translated: Cinque Terre means land, men's land, Riomaggiore, Manarola, Corniglia, Vernazza and Monterosso, in the province of Liguria, Italy.
#
# Pair 42
# Source: แม้จะยังไม่ถึงขั้นเป็นปรากฏการณ์แห่งโลกยุคใหม่ แต่คนส่วนใหญ่ก็อาจเชื่อมโยงสิ่งนี้กับเยาวชนที่ใช้สีสเปรย์ฉีดทำลายทรัพย์สินสาธารณะและทรัพย์สินส่วนบุคคล
# Target: While it's far from a modern phenomenon, most people probably associate it with youth vandalizing public and private property using spray paint.
# Translated: It's a global phenomenon in the age of people, and it can affect young people, it can affect the destruction of public institutions and it can affect individuals.
#
# Pair 43
# Source: เรามีวิกฤตการณ์ทางการเงินตลอดทั้งปี ซึ่งเป็นช่วงเวลาที่เลวร้ายที่สุดในช่วงสองเดือนที่ผ่านมา และผมคิดว่าตอนนี้ตลาดการเงินกำลังเริ่มฟื้นตัวแล้ว "
# Target: We have a year-long financial crisis, which has had its most acute moment in the past two months, and I think now the financial markets are beginning to recover."
# Translated: We've got a financial crisis going on all year for two months, and I'm on the financial markets for the next two months."
#
# Pair 44
# Source: การเดินป่าในช่วงกลางวันมีตั้งแต่ระยะทางน้อยกว่าหนึ่งไมล์ไปจนถึงระยะทางไกลกว่าซึ่งสามารถเดินได้จบได้ในวันเดียว
# Target: Day hiking involves distances of less than a mile up to longer distances that can be covered in a single day.
# Translated: Walks during the day are longer than walking long distances, and can be completed in one day.
#
# Pair 45
# Source: อาจดูน่ากลัวเล็กน้อยเมื่อมองจากด้านล่างและเป็นทางขึ้นที่สูงชันและยากลำบาก แต่คนส่วนใหญ่ที่แข็งแรงพอควรจะขึ้นไปได้สำเร็จภายในเวลาประมาณ 45 นาที
# Target: It looks a bit daunting from below, and it is a steep and difficult ascent, but most reasonably fit persons should be able to make it in about 45 minutes.
# Translated: It can be fearful, looking from the side and looking up, and it's difficult, because people should be able to do it in about 45 minutes.
#
# Pair 46
# Source: ในช่วงฤดูร้อนต้องระวังยุงนอร์ดิกด้วย แม้ว่าพวกมันจะไม่ได้นำโรคใด ๆ แต่ก็อาจทำให้ระคายเคืองได้
# Target: During the summer, also watch out for the Nordic mosquitoes. Although they do not transmit any diseases, they can be irritating.
# Translated: It's the season for phytosanitary prevention, whether they're going to lead to any disease or whether they're going to be contagious.
#
# Pair 47
# Source: สถานที่หลายแห่งในโรโตรัวมีแฮงงิที่ทำจากพลังงานความร้อนใต้พิภพในขณะที่ แฮงงิประเภทอื่น ๆ จะสามารถลิ้มลองได้ในไครสต์เชิร์ช เวลลิงตัน และเมืองอื่น ๆ
# Target: Several places in Rotorua offer geothermal hangi, while other hangi can be sampled in Christchurch, Wellington and elsewhere.
# Translated: Many of the cities in Rotorua have hydroelectric power plants, while others will be able to try out Churchill Wellington and other cities.
#
# Pair 48
# Source: ในศตวรรษที่ 18 กัมพูชารู้สึกว่าตนเองเปรียบเสมือนหญ้าแห้งที่อยู่ตรงกลางระหว่างช้างสองตัว คือ ประเทศไทยกับเวียดนาม
# Target: During the 18th century Cambodia found itself squeezed between two powerful neighbors, Thailand and Vietnam.
# Translated: In the 18th century, Cambodia had its own province, which is like the middle of two provinces, Thailand and Vietnam.
#
# Pair 49
# Source: วิดัลวัย 28 ปี ย้ายจากเซบีญ่ามาเข้าร่วมกับบาร์ซ่าเมื่อสามฤดูกาลก่อน
# Target: 28-year-old Vidal had joined Barça three seasons ago, from Sevilla.
# Translated: Vidal is 28 years old, and he's been in the NBA for three seasons.
#
# Pair 50
# Source: เจ้าหน้าที่ยังไม่รู้ชื่อของเขา รู้เพียงว่าเขาเป็นสมาชิกของกลุ่มชาติพันธุ์อุยกูร์
# Target: His name is still unknown to authorities, although they do know he is a member of the Uighur ethnic group.
# Translated: He's a member of the U.S. National Security Council.
#
# Pair 51
# Source: โชคดีที่ฉันไม่เป็นอะไร แต่ก็ต้องเจอกับเหตุการณ์ขวัญผวาที่ได้เห็นผู้คนกำลังพยายามทุบทำลายหน้าต่างเพื่อหนีตายออกมาข้างนอก
# Target: "Luckily nothing happened to me, but I saw a macabre scene, as people tried to break windows in order to get out.
# Translated: Fortunately for me, I was faced with a desperate bankruptcy who was trying to take out a deadly loan.
#
# Pair 52
# Source: มีเพียงไม่กี่สายการบินเท่านั้นที่ยังคงเสนอค่าโดยสารเพื่อเยียวยาการสูญเสียที่จะช่วยลดค่าโดยสารเล็กน้อยให้ผู้ที่ต้องการเดินทางไปเข้าร่วมพิธีศพอย่างเร่งด่วน
# Target: Only a few airlines still offer bereavement fares, which slightly discount the cost of last-minute funeral travel.
# Translated: There are only a few airlines that still offer passengers compensation for the loss of passenger rights to travel to funerals.
#
# Pair 53
# Source: เนื่องจากมีพื้นฐานมาจากการแข่งขัน Running Tours Barcelona ในเมืองบาร์เซโลนาและการแข่งขัน Running Copenhagen ในเมืองโคเปนเฮเกน จึงทำให้มีการนำการแข่งขัน Running Tours Prague ในกรุงปราก และการแข่งขันอื่น ๆ มาบรรจุอยู่ในเครือข่ายดังกล่าวอย่างรวดเร็ว
# Target: With roots in Barcelona's Running Tours Barcelona and Copenhagen's Running Copenhagen, it was quickly joined by Running Tours Prague based in Prague and others.
# Translated: It's run by Running Tours Barcelona in Barcelona and Running Copenhagen in Copenhagen, so it's run by Running Tours Prague in Prague, and it's got all these different kinds of things.
#
# Pair 54
# Source: 2 ใน 3 ของชาวเวเนซุเอลาที่ทำงานทำงานในภาคบริการ เกือบ 1 ใน 4 ทำงานในภาคอุตสาหกรรม และ 1 ใน 5 ทำงานในภาคเกษตรกรรม
# Target: Two thirds of Venezuelans who work do so in the service sector, nearly a quarter work in industry and a fifth work in agriculture.
# Translated: Two-thirds of Venezuelans work in the services sector, almost one-fourth in industry and one-fifth in agriculture.
#
# Pair 55
# Source: ก่อนที่ชาวสเปนจะมาที่นี่ในศตวรรษที่ 16 ตอนเหนือของชิลีอยู่ภายใต้การปกครองของจักรวรรดิอินคา ส่วนชนพื้นเมืองอาเรากานิอา (ชาวมาปูเช) อาศัยอยู่ในตอนกลางและตอนใต้ของชิลี
# Target: Before the Spanish arrived in the 16th century, northern Chile was under Inca rule while the indigenous Araucanians (Mapuche) inhabited central and southern Chile.
# Translated: The Spanish arrived in the 16th century in northern Chile, under the rule of the Inca, in the city of Aragon, in central and eastern Chile.
#
# Pair 56
# Source: แคปซูลจะดูเหมือนดาวตกที่กำลังพุ่งข้ามฟากฟ้าอย่างมาก
# Target: The capsule will look much like a shooting star going across the sky.
# Translated: The capsule would look like a falling star, a falling farm.
#
# Pair 57
# Source: ประมาณสิบนาทีก่อนถึงเวลาลงจอด เครื่องบินลำดังกล่าวหายไปเมื่อเข้าใกล้จุดหมายครั้งที่สอง
# Target: About ten minutes before it was due to land from its second approach it disapeared.
# Translated: Approximately 10 minutes into the landing, the body disappeared from its second target.
#
# Pair 58
# Source: โดยทั่วไปแล้ว วีซ่านักเรียนจะมีข้อกำหนดและขั้นตอนการสมัครที่แตกต่างจากวีซ่านักท่องเที่ยวหรือวีซ่าธุรกิจแบบปกติ
# Target: Student visas generally have different requirements and application procedures from normal tourist or business visas.
# Translated: Students will be issued scholarships and scholarships from a regular business school or university.
#
# Pair 59
# Source: การออกแบบเชิงโต้ตอบจำเป็นต้องให้ส่วนประกอบต่าง ๆ ของโปรเจ็กต์เชื่อมต่อกัน แต่ก็ใช้การได้ในฐานะเอนทิตีที่แยกต่างหากด้วยเช่นกัน
# Target: Interactive design requires that components of a project connect to each other, but also make sense as a separate entity.
# Translated: Designing to respond to the critical components of a project as an entity, as a separate entity.
#
# Pair 60
# Source: มิตต์ รอมนี่ย์ (Mitt Romney) อดีตผู้ว่าการรัฐแมสซาชูเซตส์ชนะการเลือกตั้งขั้นต้นจากการลงชิงตำแหน่งประธานาธิบดีในนามพรรครีพับลิกันจากรัฐฟลอริดาเมื่อวันอังคารที่ผ่านมา ด้วยคะแนนเสียงมากกว่าร้อยละ 46
# Target: Former Massachusetts governor Mitt Romney won the Florida Republican Party presidential primary election on Tuesday with over 46 percent of the vote.
# Translated: Mitt Romney, the former governor of Massachusetts, won the presidential election on behalf of the Republicans in Florida on Tuesday by 46 votes.
#
# Pair 61
# Source: การบังคับโดรนให้บินใกล้ท่าอากาศยานหรือในฝูงชนแทบจะเป็นความคิดที่แย่อยู่เสมอ แม้ว่าการทำเช่นนี้จะไม่ผิดกฎหมายในพื้นที่ของคุณก็ตาม
# Target: Flying a drone near an airport or over a crowd is almost always a bad idea, even if it's not illegal in your area.
# Translated: Enforced airplane flights, or crowded airplane flights, almost always involves the idea of violating your country's laws.
#
# Pair 62
# Source: หากคุณต้องการบินรอบโลกในซีกโลกใต้อย่างสมบูรณ์ ตัวเลือกเที่ยวบินและจุดหมายปลายทางมีจำกัดเนื่องจากไม่มีเส้นทางที่ข้ามมหาสมุทร
# Target: If you want to fly around the world completely in the Southern Hemisphere, the choice of flights and destinations is limited due to the lack of transoceanic routes.
# Translated: If you're flying around the world in the world's oceans, the choices and destinations are limited.
#
# Pair 63
# Source: เซลล์เป็นหน่วยโครงสร้างที่มีหน้าที่ที่เล็กที่สุดของสิ่งมีชีวิต
# Target: A cell is the smallest structural and functional unit of a living (things) organism.
# Translated: The Committee on the Elimination of Discrimination against Women.
#
# Pair 64
# Source: แนวคิดก็คือ ทุกประเทศในยุโรปต้องพยายามป้องกันไม่ให้ชาติใดชาติหนึ่งมีอำนาจเกินไป และด้วยเหตุนั้นรัฐบาลของชาติต่าง ๆ จึงมักสับเปลี่ยนพันธมิตรเพื่อรักษาสมดุลเอาไว้
# Target: The concept was that all European nations had to seek to prevent one nation from becoming powerful, and thus national governments often changed their alliances in order to maintain the balance.
# Translated: The idea that every country in Europe is trying to compete with any nation that has too much power, and therefore the governments of the nations are often blocking the alliances for balance.
#
# Pair 65
# Source: เมืองนี้จะเป็นเมืองแรกในยุโรปตะวันออกเฉียงใต้ที่จัด CowParade ซึ่งเป็นงานศิลปะสาธารณะที่ใหญ่ที่สุดในโลก โดยจะจัดขึ้นในช่วงระหว่างเดือนมิถุนายนจนถึงสิงหาคมปีนี้
# Target: The city will be the first in southeastern Europe to host CowParade, the world's largest public art event, between June and August this year.
# Translated: The first city in Eastern Europe hosted the CowParade, a public art event, from June until August.
#
# Pair 66
# Source: สเติร์นส์กำลังสืบสวนว่ามีการใช้ภาษีเพื่อสนับสนุนการทำแท้งผ่านองค์กร Planned Parenthood หรือไม่ ขณะที่สวมบทบาทประธานคณะอนุกรรมการกำกับดูแลและสืบสวน ซึ่งอยู่ภายใต้คณะกรรมาธิการพลังงานและการพาณิชย์
# Target: Stearns is investigating whether taxes are used to fund abortions through Planned Parenthood in his role as chairman of the Oversight and Investigations Subcommittee, which is under the umbrella of the House Energy and Commerce Committee.
# Translated: Stevie is investigating tax issues, advocating for Planned Parenthood, acting as chairman of the Board of Directors and investigating the Energy and Taxation Commission.
#
# Pair 67
# Source: ในปี พ.ศ. 2520 ดร.ดามาเดียนได้สร้างเครื่องสแกน MRI แบบ "ทั้งตัว" เป็นเครื่องแรก โดยเรียกมันว่า "เจ้าทรหดอดทน"
# Target: In 1977, Dr. Damadian completed the construction of the first “whole-body” MRI scanner, which he called the ”Indomitable”.
# Translated: In the year 2520, Dr. Damian introduced the first "" individual "" MRI scan, which he called "" patient endurance.
#
# Pair 68
# Source: มีการเตรียมการที่จะนำทั้งกอล์ฟและรักบี้กลับไปแข่งขันในกีฬาโอลิมปิก
# Target: Both golf and rugby are set to return to the Olympic Games.
# Translated: There are preparations to bring Olympic athletes and fans back to the Olympic stadium.
#
# Pair 69
# Source: นายพล James Ewing จะนำทหาร 700 นายข้ามแม่น้ำที่ Trenton Ferry เข้ายึดสะพานข้ามลำห้วย Assunpink และป้องกันไม่ให้กองทหารข้าศึกหลบหนี
# Target: General James Ewing would take 700 militia across the river at Trenton Ferry, seize the bridge over the Assunpink Creek and prevent any enemy troops from escaping.
# Translated: General James Ewing would lead 700 troops on the Trenton Ferry, take over the Assunpink Bridge and force the troops to flee.
#
# Pair 70
# Source: สัตว์เกิดขึ้นจากเซลล์จำนวนมาก พวกมันกินสิ่งต่าง ๆ และย่อยสิ่งเหล่านั้นภายในร่างกาย สัตว์ส่วนใหญ่เคลื่อนไหวได้
# Target: Animals are made of many cells. They eat things and digest them inside. Most animals can move.
# Translated: A lot of government departments, they eat their own food, and they eat their own food within government departments.
#
# Pair 71
# Source: นับตั้งแต่ก่อตั้งขึ้นมา The Onion ได้กลายเป็นอาณาจักรข่าวล้อเลียนที่แท้จริง โดยมีทั้งฉบับตีพิมพ์ เว็บไซต์ที่ดึงดูดผู้เข้าชมได้ถึง 5,000,000 คนในเดือนตุลาคม นอกจากนี้ยังมีโฆษณาส่วนบุคคล เครือข่ายข่าว 24 ชั่วโมง พอดแคสต์ และแผนที่โลกชื่อว่า Our Dumb World ที่เพิ่งเปิดตัวไปเมื่อไม่นานมานี้
# Target: Since its inception, The Onion has become a veritable news parody empire, with a print edition, a website that drew 5,000,000 unique visitors in the month of October, personal ads, a 24 hour news network, podcasts, and a recently launched world atlas called Our Dumb World.
# Translated: In addition to the Onion campaign, the UK's copying campaign, which attracted 5 million people in October, there were personalized ads, 24-hour ads, podcasts, and the world's long-running Our Dumb World campaign.
#
# Pair 72
# Source: พระชาวเยอรมันบางรูปปรารถนาที่จะให้พระเจ้าใกล้ชิดชาวพื้นเมืองมากขึ้นจึงได้คิดค้นภาษาเอสโตเนียขึ้นมา
# Target: Some German monks wanted to bring God closer to the native people, so they invented the Estonian literal language.
# Translated: Some of the Germanic gods wanted people to think in Estonian.
#
# Pair 73
# Source: เอกวาดอร์มีข้อกำหนดให้พลเมืองคิวบาต้องได้รับหนังสือเชิญจึงจะสามารถเดินทางข้ามเข้าสู่เขตแดนเอกวาดอร์ผ่านสนามบินนานาชาติหรือด่านตรวจคนเข้าเมืองที่พรมแดน
# Target: Ecuador requires that Cuban citizens receive an invitation letter prior to entering Ecuador through international airports or frontier admission points.
# Translated: There's a visa requirement for Cuban citizens, so they can travel across borders, international airports, border checkpoints.
#
# Pair 74
# Source: การสื่อสารทางเดียวช่วยให้มีเวลาใช้ความคิดก่อนที่จะโต้ตอบผู้อื่น
# Target: Asynchronous communication encourages time for reflection and reaction to others.
# Translated: There's only one government that has time for thinking and responding.
#
# Pair 75
# Source: เนื่องจากการโทรถูกส่งผ่านอินเทอร์เน็ต คุณจึงไม่จำเป็นต้องใช้บริษัทโทรศัพท์ที่ตั้งอยู่ในที่ที่อาศัยหรือที่ที่คุณเดินทางไป
# Target: Because calls are routed over the Internet, you do not need to use a phone company located where you live or where you travel.
# Translated: You get a phone bill, you get a company phone bill, you get a housing bill, you get a travel bill.
#
# Pair 76
# Source: เรือสำราญมากกว่า 60 ลำล่องไปตามน่านน้ำในกาลาปากอส โดยมีขนาดบรรทุกผู้โดยสารตั้งแต่ 8 ถึง 100 คน
# Target: Over 60 cruise ships ply the Galapagos waters - ranging in size from 8 to 100 passengers.
# Translated: 60 cruise ships sail the waters of the Galapagos, carrying eight to 100 passengers.
#
# Pair 77
# Source: ข้อเท็จจริงที่ว่าหมู่บ้านจำนวนมากอยู่ห่างไกลแค่ไหน ทำให้คุณไม่สามารถพบเจอสถานบันเทิงยามค่ำคืนจำนวนมากโดยไม่เดินทางไปยังแอลบูเคอร์คีหรือซานตาเฟ่
# Target: Given how remote many of the pueblos are, you won't be able to find a significant amount of nightlife without traveling to Albuquerque or Santa Fe.
# Translated: The fact is that many countries are far away, so you can find many nightlife spots, so you can go to Albuquerque or Santa Fe.
#
# Pair 78
# Source: นอกจากนี้ ACMA ยังพบว่าแม้จะมีการสตรีมวิดีโอทางอินเทอร์เน็ต แต่บิกบราเธอร์ก็ไม่ได้ละเมิดกฎหมายการเซ็นเซอร์เนื้อหาออนไลน์ เนื่องจากสื่อดังกล่าวไม่ได้ถูกจัดเก็บไว้ในเว็บไซต์ของบิกบราเธอร์
# Target: The ACMA also found that despite the video being streamed on the Internet, Big Brother had not breached online content censorship laws as the media had not been stored on Big Brother's website.
# Translated: ACMA also ordered that any video of her violations of the laws of her country be streamed.
#
# Pair 79
# Source: หากคุณรักความเสี่ยงมากกว่านี้ ให้ใช้โอกาสนี้คั้นน้ำผลไม้หรือปั่นสมูทตี้ดูสิ:
# Target: If you're feeling more adventurous, take the opportunity to juice or blend up some smoothies:
# Translated: If you love entertainment, opportunity, entertainment or entertainment, look at this.
#
# Pair 80
# Source: มันช่วยให้นักเรียนสามารถทำงานได้ตามอัตราความเร็วของตนเอง รวมทั้งสามารถควบคุมอัตราเร็วของการให้ข้อมูลเชิงสอนได้
# Target: It allows students the ability to work at their own pace and control the pace of instructional information.
# Translated: It allows students to work on their own salary rates, and it allows them to control their teaching salary rates.
#
# Pair 81
# Source: กรอบแว่นตาแบรนด์เนมระดับไฮเอนด์ที่มีขายอยู่ในพื้นที่เช่นนั้นอาจมีปัญหาได้สองอย่าง นั่นก็คือ บางกรอบอาจเป็นของปลอม ส่วนกรอบที่ได้มีการนำเข้ามาจริงก็อาจมีราคาแพงกว่าที่มีขายอยู่ในประเทศ
# Target: High-end brand-name frames available in such areas may have two problems; some may be knock-offs, and the real imported ones may be more expensive than at home.
# Translated: High-quality meat labels, labels that sell meat may have two problems: Some labels may be fake labels, labels may be expensive to sell in the country.
#
# Pair 82
# Source: อะตอมถือได้ว่าเป็นโครงสร้างพื้นฐานอย่างหนึ่งของทุกสสาร
# Target: The atom can be considered to be one of the fundamental building blocks of all matter.
# Translated: Atoms hold the sovereignty of all matter.
#
# Pair 83
# Source: อาการสมาธิสั้น "คือกลุ่มอาการทางระบบประสาทซึ่งอาการที่พบเป็นประจำ ได้แก่ หุนหันพลันแล่น วอกแวกง่าย อยู่ไม่นิ่ง หรือมีพลังงานมากเกิน"
# Target: Attention Deficit Disorder "is a neurological syndrome whose classic defining triad of symptoms including impulsivity, distractibility, and hyperactivity or excess energy".
# Translated: Meditation: "It's a neurological condition, it's a constant state of agitation, of dizziness, of headaches, of hyperactivity."
#
# Pair 84
# Source: เป็นที่เล่าขานกันมาว่าในปี ค.ศ. 1649 ท่านซับดรุง งาวัง นัมเยล (Zhabdrung Ngawang Namgyel) ได้สร้างป้อมปราการแห่งนี้ขึ้นเพื่อเป็นอนุสรณ์สถานแห่งชัยชนะของตนในการต่อต้านกองกำลังทิเบต-มองโกล
# Target: It is said that in 1649, Zhabdrung Ngawang Namgyel created the fortress to commemorate his victory against the Tibetan-Mongol forces.
# Translated: In 1649, Zhabdrung Ngawang Namgyel celebrated his victory over the Tibetan Mongols.
#
# Pair 85
# Source: บริษัทสื่อต่าง ๆ เหล่านี้มักไม่บอกจุดประสงค์ที่แท้จริงของการทำเช่นนี้ โดยอ้างว่าเป็นการ "ป้องกันการละเมิดลิขสิทธิ์"
# Target: The media companies routinely lie about the purpose of this, claiming that it is to "prevent piracy".
# Translated: Companies are often referred to as "" violations "" by the authorities.
#
# Pair 86
# Source: กีฬาชนิดนี้เล่นในรูปแบบการดวลเป็นสำคัญ โดยที่นักฟันดาบคนหนึ่งดวลกับนักฟันดาบอีกคนหนึ่ง
# Target: The sport is primarily played in a duel format, one fencer dueling another.
# Translated: The sport is played in the form of a major swim, by dancers, swimmers and other dancers.
#
# Pair 87
# Source: ในหลายประเทศที่มีกฎหมายดังกล่าว โรงแรมในท้องถิ่นจะจัดการเรื่องการลงทะเบียน (อย่าลืมสอบถาม)
# Target: In many countries with such a law, local hotels will handle the registration (make sure to ask).
# Translated: In many countries, the legislation of the country, the legislation of the country, is governed by registration laws.
#
# Pair 88
# Source: แผนการของอเมริกาอาศัยการออกโจมตีพร้อมกันจากสามทิศทาง
# Target: The American plan relied on launching coordinated attacks from three different directions.
# Translated: America's plan was to launch a three-way assault.
#
# Pair 89
# Source: สิ่งปลูกสร้างหลายแห่งค่อนข้างสวยงามน่ามอง และทิวทัศน์จากตึกสูงหรือจากตำแหน่งหน้าต่างที่จัดวางไว้อย่างชาญฉลาดก็อาจเป็นความสวยงามที่มองเห็นได้
# Target: Many buildings are quite beautiful to look at and the view from a tall building or from a cleverly-positioned window can be a beauty to behold.
# Translated: Growing a lot of beautiful landscapes and viewing from high-rise buildings or from smart architecture, maybe it's beauty.
#
# Pair 90
# Source: บรรยากาศมืดสลัวในบริเวณวัดและทิวทัศน์เหนือทะเลสาบโตนเลสาบทำให้การปีนขึ้นสู่เนินเขาเป็นเรื่องที่คุ้มค่า
# Target: The gloomy atmosphere of the temple and the view over the Tonle Sap lake make the climb to the hill worthwhile.
# Translated: The dark atmosphere in the temple area and the views over Lake Tanganyika, the mountain climbing, the mountain climbing.
#
# Pair 91
# Source: งานรวมศิลปินครั้งนี้ที่ยังเป็นส่วนหนึ่งของแคมเปญที่จัดโดยศาลาว่าการกรุงบูคาเรสต์ ในการพยายามสร้างภาพลักษณ์ของเมืองหลวงของโรมาเนียให้เป็นมหานครที่มีความสร้างสรรค์และมีสีสันอีกครั้ง
# Target: The artistic event is also part of a campaign by the Bucharest City Hall that seeks to relaunch the image of the Romanian capital as a creative and colourful metropolis.
# Translated: It's a congress of artists from the capital city, organized by the city of Bucharest, to try to paint a portrait of the capital city of Romania, the capital city of Romania, in color.
#
# Pair 92
# Source: เด็กเหล่านี้มักเผชิญกับปัญหามากมายเพราะพวกเขา "เข้าไปพัวพันกับพฤติกรรมเสี่ยง การต่อยตี และท้าทายเจ้าหน้าที่" เพื่อกระตุ้นสมองของตนเอง เนื่องจากสมองของพวกเขาไม่สามารถถูกกระตุ้นด้วยวิธีปกติได้
# Target: These children tend to get into a lot of trouble, because they "engage in risky behaviors, get into fights, and challenge authority" in order to stimulate their brain, since their brain can not be stimulated by normal methods.
# Translated: The councils often have a lot of problems because they're dealing with their own behavior, their own fights, their own brains, their own way of doing things.
#
# Pair 93
# Source: มนุษย์ได้ผลิตและใช้เลนส์เพื่อประโยชน์ในการขยายภาพมานานหลายพันปีแล้ว
# Target: Humans have been making and using lenses for magnification for thousands and thousands of years.
# Translated: The industry has been producing and expanding for thousands of years.
#
# Pair 94
# Source: การขว้างบูมเมอแรงคือทักษะยอดนิยมที่นักท่องเที่ยวหลายต่อหลายคนต้องการมี
# Target: Boomerang throwing is a popular skill that many tourists want to acquire.
# Translated: Strong bowel movement is a very popular skill among many people.
#
# Pair 95
# Source: กีฬาฟันดาบสมัยใหม่มีการแข่งขันกันในหลายระดับ ตั้งแต่ระดับนักศึกษามหาวิทยาลัยไปจนถึงระดับมืออาชีพและในกีฬาโอลิมปิก
# Target: The modern sport of fencing is played at many levels, from students learning at a university to professional and Olympic competition.
# Translated: Ice hockey in the old days was played at a variety of levels, from university level to professional level and at the Olympics.
#
# Pair 96
# Source: เขาเสียชีวิตที่โอซาก้าในวันอังคาร
# Target: He died in Osaka on Tuesday.
# Translated: He died in Ossetia on Tuesday.
#
# Pair 97
# Source: มีการจัดให้มีการสอบสวนเพื่อสืบสวน
# Target: An inquiry was established to investigate.
# Translated: There was an investigation.
#
# Pair 98
# Source: โรคติดต่อคือโรคชนิดหนึ่งที่แพร่เชื้อได้โดยง่ายเมื่ออยู่ใกล้ชิดกับผู้ติดเชื้อ
# Target: A contagious disease is a disease which is easily transmitted by being in the vicinity of an infected person.
# Translated: Diseases are diseases that are caused by a combination of diseases and diseases.
#
# Pair 99
# Source: ก๊าซจะเบาบางลงเมื่อเราเคลื่อนที่ไกลออกมาจากศูนย์กลางของดวงอาทิตย์
# Target: The gas becomes thinner as you go farther from the center of the Sun.
# Translated: It will lighten us away from the center of the sun.
#
# Pair 100
# Source: ปกติแล้วกิจกรรมเหล่านี้จะกินเวลาระหว่างสามถึงหกเดือนและจัดขึ้นในพื้นที่ซึ่งมีขนาดไม่เกิน 50 เฮกตาร์
# Target: These events normally last anywhere between three and six months, and are held on sites no smaller than 50 hectares.
# Translated: Typically, the conferences are three to six months long, and the conferences are 50 hectares in size.

# %% [markdown]
# **2.4 Data statistics**
#
# Displaying the data statistics of the 100 sampled sentences

# %%
# Get the minimum length of the sentences
def min_length(sentences_list):

    min_length = len(sentences_list[0])

    for sentence in sentences_list:
        if min_length > len(sentence):
            min_length = len(sentence)

    return min_length

# Get the maximum length of the sentences
def max_length(sentences_list):

    max_length = len(sentences_list[0])

    for sentence in sentences_list:
        if max_length < len(sentence):
            max_length = len(sentence)

    return max_length

# Get the average length of the sentences
def avg_length(sentences_list):

    sum = 0

    for sentence in sentences_list:
        sum += len(sentence)

    avg_length = sum // len(sentences_list)

    return avg_length

import pandas as pd

# Define the columns and rows of the table containing the statistics of the source and target sentences
source_target_sentences_length_table = {
    'Sentences' : ['Source sentences',
                   'Target sentences'],
    'Minimum length of the sentences' : [min_length(source_sentences),
                                         min_length(target_sentences)],
    'Average length of the sentences' : [avg_length(source_sentences),
                                         avg_length(target_sentences)],
    'Maximum length of the sentences' : [max_length(source_sentences),
                                         max_length(target_sentences)],
}

# Create the dataframe of the statistics of the source and target sentences
source_target_sentences_statistics_table = pd.DataFrame(source_target_sentences_length_table)

# Define the columns and rows of the table containing the statistics of the translated sentences
translated_sentences_length_table = {
    'Models' : ['OPUS_MT',
                'M2M-100',
                'MBART-50'],
    'Minimum length of the translated sentences' : [min_length(opus_translated_sentences_list),
                                                    min_length(m2m_translated_sentences_list),
                                                    min_length(mbart_translated_sentences_list)],
    'Average length of the translated sentences' : [avg_length(opus_translated_sentences_list),
                                                    avg_length(m2m_translated_sentences_list),
                                                    avg_length(mbart_translated_sentences_list)],
    'Maximum length of the translated sentences' : [max_length(opus_translated_sentences_list),
                                                    max_length(m2m_translated_sentences_list),
                                                    max_length(mbart_translated_sentences_list)],
}

# Create the dataframe of the statistics of the translated sentences
translated_sentences_statistics_table = pd.DataFrame(translated_sentences_length_table)

# %%
source_target_sentences_statistics_table
# Out:
#           Sentences  Minimum length of the sentences  \
# 0  Source sentences                               33
# 1  Target sentences                               28
#
#    Average length of the sentences  Maximum length of the sentences
# 0                              126                              287
# 1                              132                              273

# %%
translated_sentences_statistics_table
# Out:
#      Models  Minimum length of the translated sentences  \
# 0   OPUS_MT                                          28
# 1   M2M-100                                          28
# 2  MBART-50                                          27
#
#    Average length of the translated sentences  \
# 0                                         128
# 1                                         143
# 2                                         115
#
#    Maximum length of the translated sentences
# 0                                         267
# 1                                         311
# 2                                         239

# %% [markdown]
# ### 3. Results analysis and evaluation

# %% [markdown]
# **3.1 Results of each model**

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.translate import bleu_score

target_ref = [[word_tokenize(sentence) for sentence in target_sentences] for reference in target_sentences]

# Perform evaluation for OPUS-MT model
# Tokenize the sentences using NLTK's word_tokenize
opus_predictions = [word_tokenize(sentence) for sentence in opus_translated_sentences_list]
# Compute BLEU scores
opus_bleu = bleu_score.corpus_bleu(target_ref, opus_predictions)
print("The BLEU score of OPUS-MT model:")
print(opus_bleu)

# Perform evaluation for M2M-100 model
m2m_predictions = [word_tokenize(sentence) for sentence in m2m_translated_sentences_list]
m2m_bleu = bleu_score.corpus_bleu(target_ref, m2m_predictions)
print("\nThe BLEU score of M2M-100 model:")
print(m2m_bleu)

# Perform evaluation for MBART-50 model
mbart_predictions = [word_tokenize(sentence) for sentence in mbart_translated_sentences_list]
mbart_bleu = bleu_score.corpus_bleu(target_ref, mbart_predictions)
print("\nThe BLEU score of MBART-50 model:")
print(mbart_bleu)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# The BLEU score of OPUS-MT model:
# 0.25161329155896006
#
# The BLEU score of M2M-100 model:
# 0.24422825751240484
#
# The BLEU score of MBART-50 model:
# 0.13185801454648585

# %% [markdown]
# **3.2 Results discussion**

# %% [markdown]
# - **OPUS-MT Model**
# <br>BLEU Score: 0.25, the OPUS-MT model provided the highest BLEU score among the three models, indicating better alignment with the reference translations. This model may have been well-trained on the specific language pair, resulting in more accurate translations.
#
# - **M2M-100 Model**
# <br>BLEU Score: 0.24, the M2M-100 model also performed well but slightly lower than OPUS-MT. This model may have faced challenges in certain language nuances or domain-specific differences compared to the evaluation set.
#
# - **MBART-50 Model**
# <br>BLEU Score: 0.13, the MBART-50 model provided the lowest BLEU score. This model may not be as well-suited for this specific language pair or may require additional fine-tuning.

# %% [markdown]
# **3.3 Examples of two data samples**

# %%
# Gett the data samples
source_two_samples = source_sentences[0:2]
target_two_samples = target_sentences[0:2]
opus_two_samples = opus_translated_sentences_list[0:2]
m2m_two_samples = m2m_translated_sentences_list[0:2]
mbart_two_samples = mbart_translated_sentences_list[0:2]

# Display the sampled sentences
print("The first sample")
print("Source:", source_two_samples[0])
print("Target:", target_two_samples[0])
print("OPUS-MT translated:", opus_two_samples[0])
print("M2M-100 translated:", m2m_two_samples[0])
print("MBART-50 translated:", mbart_two_samples[0])
print("\nThe second sample")
print("Source:", source_two_samples[1])
print("Target:", target_two_samples[1])
print("OPUS-MT translated:", opus_two_samples[1])
print("M2M-100 translated:", m2m_two_samples[1])
print("MBART-50 translated:", mbart_two_samples[1])
# Out:
# The first sample
# Source: นี่ไม่ใช่กลุ่มอาการขาดทักษะด้านการเรียนรู้ แต่เป็นความผิดปกติทางการเรียนรู้ โรคนี้ "ส่งผลกระทบต่อเด็กร้อยละ 3 ถึง 5 ซึ่งอาจเป็นเด็กอเมริกันมากถึง 2 ล้านคน"
# Target: It is not a learning disability, it is a learning disorder; it "affects 3 to 5 percent of all children, perhaps as many as 2 million American children".
# OPUS-MT translated: This isn't a group of learning disability, it's a learning disorder, it's an effect on children from three to five, which is probably two million American children.
# M2M-100 translated: This is not a group of learning failure, but a learning disorder. This disease "affects 3 to 5 per child, which may be up to 2 million American children."
# MBART-50 translated: We're talking about skills shortages, diseases, diseases that affect three to five percent of Americans, maybe two to two percent of Americans.
#
# The second sample
# Source: ผู้ที่ไม่คุ้นเคยกับศัพท์เฉพาะทางการแพทย์คิดว่า คำว่าติดเชื้อและโรคติดต่อนั้นมีความหมายต่างกัน
# Target: For those unfamiliar with medical jargon, the words infectious and contagious have distinct meanings.
# OPUS-MT translated: Those who aren't familiar with medical terms think that infection and infectious diseases have different meanings.
# M2M-100 translated: People who are not familiar with the specific medical term think that the word infection and contact disease have different meanings.
# MBART-50 translated: It used to be synonymous with specialized medicines, and diseases were synonymous.

# %% [markdown]
# From the output of each model translating the two sampled sentences,
#
# **Example 1:**
# - OPUS-MT: The translation is accurate but includes some inaccuracies in conveying the precise meaning of the source. It mentions "an effect on children from three to five" instead of the intended "affects 3 to 5 percent of all children."
# - M2M-100: The translation captures the essence but introduces a few errors, such as "learning failure" instead of "learning disability" and "3 to 5 per child" instead of "3 to 5 percent of all children."
# - MBART-50: The translation is quite different from the reference and introduces unrelated terms like "skills shortages." It fails to accurately convey the intended meaning.
#
# **Example 2:**
# - OPUS-MT: The translation provides a relatively accurate translation, capturing the intended meaning effectively.
# - M2M-100: The translation provides minor errors but conveys the main idea effectively.
# - MBART-50: The translation provides a translation that deviates significantly from the target meaning and provides unrelated terms.
#
# **Conclusion**
# - OPUS-MT: Generally provides more accurate translations but may have some inaccuracies.
# - M2M-100: Performs reasonably well, capturing the main ideas with occasional errors.
# - MBART-50: Shows more significant divergence from the intended meaning and introduces unrelated terms.
